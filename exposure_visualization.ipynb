# %% [markdown]
# # Load packages

# %%
# import xarray as xr
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import glob

# %load_ext autoreload
# %autoreload 2
import os
import random
import sqlite3 
import numpy as np
import json
import math
# from tqdm.notebook import tqdm
# from tqdm import tqdm
# tqdm.pandas()

# import jenkspy

# import Advan_operator as ad_op  
# import exposure_helper as helper

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Set data directories

# %%
data_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_data\Wild_fire\exposure'

# %% [markdown]
# # Load files

# %%
state_shp_fname = r'https://github.com/gladcolor/spatial_data/raw/master/cb_2019_us_state_20m.zip'
state_gdf = gpd.read_file(state_shp_fname)
state_gdf = state_gdf.rename(columns={"NAME":"state_name"})

state_gdf[['STATEFP', 'STUSPS', 'state_name']]
# Out:
#    STATEFP STUSPS            state_name
# 0       53     WA            Washington
# 1       72     PR           Puerto Rico
# 2       46     SD          South Dakota
# 3       39     OH                  Ohio
# 4       01     AL               Alabama
# 5       05     AR              Arkansas
# 6       35     NM            New Mexico
# 7       48     TX                 Texas
# 8       06     CA            California
# 9       21     KY              Kentucky
# 10      13     GA               Georgia
# 11      55     WI             Wisconsin
# 12      41     OR                Oregon
# 13      29     MO              Missouri
# 14      51     VA              Virginia
# 15      47     TN             Tennessee
# 16      22     LA             Louisiana
# 17      36     NY              New York
# 18      26     MI              Michigan
# 19      16     ID                 Idaho
# 20      12     FL               Florida
# 21      02     AK                Alaska
# 22      17     IL              Illinois
# 23      30     MT               Montana
# 24      27     MN             Minnesota
# 25      24     MD              Maryland
# 26      19     IA                  Iowa
# 27      10     DE              Delaware
# 28      31     NE              Nebraska
# 29      54     WV         West Virginia
# 30      18     IN               Indiana
# 31      25     MA         Massachusetts
# 32      42     PA          Pennsylvania
# 33      28     MS           Mississippi
# 34      08     CO              Colorado
# 35      20     KS                Kansas
# 36      32     NV                Nevada
# 37      50     VT               Vermont
# 38      09     CT           Connecticut
# 39      34     NJ            New Jersey
# 40      11     DC  District of Columbia
# 41      38     ND          North Dakota
# 42      45     SC        South Carolina
# 43      37     NC        North Carolina
# 44      49     UT                  Utah
# 45      40     OK              Oklahoma
# 46      56     WY               Wyoming
# 47      04     AZ               Arizona
# 48      44     RI          Rhode Island
# 49      23     ME                 Maine
# 50      15     HI                Hawaii
# 51      33     NH         New Hampshire

# %%
exposure_files = glob.glob(os.path.join(data_dir, 'exposure*.csv.zip'))
print("Found file count:", len(exposure_files))
# exposure_files
# Out:
# Found file count: 719

# %%
exposure_df = pd.concat([pd.read_csv(f) for f in exposure_files])
exposure_df['date_time'] = pd.to_datetime(exposure_df['date_time'])
exposure_df
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_3992\1721252382.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   exposure_df['date_time'] = pd.to_datetime(exposure_df['date_time'])
#         xy_label  weighted_popu  ACS_weighted_popu             x  \
# 0       1269_358      92.811240         100.918302  1.269255e+06
# 1       1269_361      92.811240         100.918302  1.269255e+06
# 2       1269_364      79.231112          85.823861  1.269255e+06
# 3       1269_367      48.406282          50.936750  1.269255e+06
# 4       1269_370      48.406282          50.936750  1.269255e+06
# ...          ...            ...                ...           ...
# 52586  2255_1160      13.443454          15.249024  2.255669e+06
# 52587  2255_1163      35.348288          40.095863  2.255669e+06
# 52588  2255_1166      37.099474          42.082249  2.255669e+06
# 52589  2255_1169      89.808680          80.928641  2.255669e+06
# 52590  2255_1172       0.000920           0.000805  2.255669e+06
#
#                   y  fused_data  MASSDEN  PM2_5_DRY_SFC  prediction  \
# 0      3.581268e+05   10.486976      0.0       3.612596   12.201368
# 1      3.610979e+05   11.964456      0.0       3.612596   12.201368
# 2      3.640691e+05   11.981960      0.0       3.733774   10.695792
# 3      3.670402e+05   11.474331      0.0       3.733774   10.695792
# 4      3.700113e+05   11.240396      0.0       3.733774   10.593472
# ...             ...         ...      ...            ...         ...
# 52586  1.160330e+06   27.434345      0.0       0.586093    3.070646
# 52587  1.163302e+06   27.426708      0.0       0.586093    3.070646
# 52588  1.166273e+06   27.494032      0.0       0.709779    3.070646
# 52589  1.169244e+06   27.654919      0.0       0.693913    3.070646
# 52590  1.172215e+06   28.118238      0.0       0.565536    3.070646
#
#        stations_interpolated  fused_data_exposure  ACS_fused_data_exposure  \
# 0                   8.276950           973.309221              1058.327778
# 1                   8.272281          1110.435967              1207.432544
# 2                   8.269268           949.344037              1028.338100
# 3                   8.268017           555.429692               584.465129
# 4                   8.268640           544.105797               572.549271
# ...                      ...                  ...                      ...
# 52586              14.794029           368.812354               418.346984
# 52587              15.072925           969.487187              1099.697546
# 52588              15.354659          1020.014134              1157.010691
# 52589              15.638247          2483.651732              2238.074996
# 52590              15.922723             0.025863                 0.022624
#
#        stations_interpolated_exposure  ACS_stations_interpolated_exposure  \
# 0                          768.193978                          835.295719
# 1                          767.760695                          834.824588
# 2                          655.183312                          709.700525
# 3                          400.223947                          421.145906
# 4                          400.254102                          421.177638
# ...                               ...                                 ...
# 52586                      198.882842                          225.594496
# 52587                      532.802096                          604.361940
# 52588                      569.649786                          646.158589
# 52589                     1404.450345                         1265.582110
# 52590                        0.014646                            0.012811
#
#        year  month  day  hour                 date_time
# 0      2023      6    1     1 2023-06-01 01:00:00+00:00
# 1      2023      6    1     1 2023-06-01 01:00:00+00:00
# 2      2023      6    1     1 2023-06-01 01:00:00+00:00
# 3      2023      6    1     1 2023-06-01 01:00:00+00:00
# 4      2023      6    1     1 2023-06-01 01:00:00+00:00
# ...     ...    ...  ...   ...                       ...
# 52586  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52587  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52588  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52589  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52590  2023      6   30    23 2023-06-30 23:00:00+00:00
#
# [37812929 rows x 19 columns]

# %% [markdown]
# # Entire study areas

# %%
group_sum = exposure_df.groupby('date_time')[['fused_data_exposure', 
                                  'ACS_fused_data_exposure', 
                                  'stations_interpolated_exposure', 
                                  'ACS_stations_interpolated_exposure']].sum()

# %%
group_sum.plot()
# Out:
# <Axes: xlabel='date_time'>

# %% [markdown]
# # County level

# %%
grid_to_county_mapping_fname = r"D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\Wild_fire\vectors\target_grid.shp"
print("loading grid to county mapping file form:", grid_to_county_mapping_fname)

grid_county_gdf = gpd.read_file(grid_to_county_mapping_fname )
grid_county_gdf[['xy_label', 'GEOID', 'NAME']]
# Out:
# loading grid to county mapping file form: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\Wild_fire\vectors\target_grid.shp
#         xy_label  GEOID        NAME
# 0       1269_607  42049        Erie
# 1       1269_604  42049        Erie
# 2       1269_601  42049        Erie
# 3       1269_598  39007   Ashtabula
# 4       1269_595  39007   Ashtabula
# ...          ...    ...         ...
# 53556  2255_1169   None        None
# 53557  2255_1166  23029  Washington
# 53558  2255_1163  23029  Washington
# 53559  2255_1160  23029  Washington
# 53560  2255_1157  23029  Washington
#
# [53561 rows x 3 columns]

# %%
grid_county_gdf.plot()
# Out:
# <Axes: >

# %%
exposure_df
# Out:
#         xy_label  weighted_popu  ACS_weighted_popu             x  \
# 0       1269_358      92.811240         100.918302  1.269255e+06
# 1       1269_361      92.811240         100.918302  1.269255e+06
# 2       1269_364      79.231112          85.823861  1.269255e+06
# 3       1269_367      48.406282          50.936750  1.269255e+06
# 4       1269_370      48.406282          50.936750  1.269255e+06
# ...          ...            ...                ...           ...
# 52586  2255_1160      13.443454          15.249024  2.255669e+06
# 52587  2255_1163      35.348288          40.095863  2.255669e+06
# 52588  2255_1166      37.099474          42.082249  2.255669e+06
# 52589  2255_1169      89.808680          80.928641  2.255669e+06
# 52590  2255_1172       0.000920           0.000805  2.255669e+06
#
#                   y  fused_data  MASSDEN  PM2_5_DRY_SFC  prediction  \
# 0      3.581268e+05   10.486976      0.0       3.612596   12.201368
# 1      3.610979e+05   11.964456      0.0       3.612596   12.201368
# 2      3.640691e+05   11.981960      0.0       3.733774   10.695792
# 3      3.670402e+05   11.474331      0.0       3.733774   10.695792
# 4      3.700113e+05   11.240396      0.0       3.733774   10.593472
# ...             ...         ...      ...            ...         ...
# 52586  1.160330e+06   27.434345      0.0       0.586093    3.070646
# 52587  1.163302e+06   27.426708      0.0       0.586093    3.070646
# 52588  1.166273e+06   27.494032      0.0       0.709779    3.070646
# 52589  1.169244e+06   27.654919      0.0       0.693913    3.070646
# 52590  1.172215e+06   28.118238      0.0       0.565536    3.070646
#
#        stations_interpolated  fused_data_exposure  ACS_fused_data_exposure  \
# 0                   8.276950           973.309221              1058.327778
# 1                   8.272281          1110.435967              1207.432544
# 2                   8.269268           949.344037              1028.338100
# 3                   8.268017           555.429692               584.465129
# 4                   8.268640           544.105797               572.549271
# ...                      ...                  ...                      ...
# 52586              14.794029           368.812354               418.346984
# 52587              15.072925           969.487187              1099.697546
# 52588              15.354659          1020.014134              1157.010691
# 52589              15.638247          2483.651732              2238.074996
# 52590              15.922723             0.025863                 0.022624
#
#        stations_interpolated_exposure  ACS_stations_interpolated_exposure  \
# 0                          768.193978                          835.295719
# 1                          767.760695                          834.824588
# 2                          655.183312                          709.700525
# 3                          400.223947                          421.145906
# 4                          400.254102                          421.177638
# ...                               ...                                 ...
# 52586                      198.882842                          225.594496
# 52587                      532.802096                          604.361940
# 52588                      569.649786                          646.158589
# 52589                     1404.450345                         1265.582110
# 52590                        0.014646                            0.012811
#
#        year  month  day  hour                 date_time
# 0      2023      6    1     1 2023-06-01 01:00:00+00:00
# 1      2023      6    1     1 2023-06-01 01:00:00+00:00
# 2      2023      6    1     1 2023-06-01 01:00:00+00:00
# 3      2023      6    1     1 2023-06-01 01:00:00+00:00
# 4      2023      6    1     1 2023-06-01 01:00:00+00:00
# ...     ...    ...  ...   ...                       ...
# 52586  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52587  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52588  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52589  2023      6   30    23 2023-06-30 23:00:00+00:00
# 52590  2023      6   30    23 2023-06-30 23:00:00+00:00
#
# [37812929 rows x 19 columns]

# %%
exposure_county_df = exposure_df.merge(grid_county_gdf[['xy_label', 'GEOID', 'NAME']], left_on='xy_label', right_on='xy_label')
exposure_county_df
# Out:
#            xy_label  weighted_popu  ACS_weighted_popu             x  \
# 0          1269_358      92.811240         100.918302  1.269255e+06
# 1          1269_358      93.677084         100.918302  1.269255e+06
# 2          1269_358      93.453873         100.918302  1.269255e+06
# 3          1269_358      91.854055         100.918302  1.269255e+06
# 4          1269_358      88.272438         100.918302  1.269255e+06
# ...             ...            ...                ...           ...
# 37812924  2255_1172       0.001207           0.000805  2.255669e+06
# 37812925  2255_1172       0.001317           0.000805  2.255669e+06
# 37812926  2255_1172       0.001411           0.000805  2.255669e+06
# 37812927  2255_1172       0.000663           0.000805  2.255669e+06
# 37812928  2255_1172       0.000920           0.000805  2.255669e+06
#
#                      y  fused_data  MASSDEN  PM2_5_DRY_SFC  prediction  \
# 0         3.581268e+05   10.486976      0.0       3.612596   12.201368
# 1         3.581268e+05    9.898472      0.0       3.757228   11.162226
# 2         3.581268e+05   11.101686      0.0       4.073213   10.157770
# 3         3.581268e+05   12.326789      0.0       4.262328    8.196183
# 4         3.581268e+05   11.844481      0.0       4.072906    8.307307
# ...                ...         ...      ...            ...         ...
# 37812924  1.172215e+06   21.134411      0.0       0.658506    3.656229
# 37812925  1.172215e+06   20.348957      0.0       0.624303    3.435581
# 37812926  1.172215e+06   22.003407      0.0       0.616643    3.151258
# 37812927  1.172215e+06   26.192684      0.0       0.588941    3.108058
# 37812928  1.172215e+06   28.118238      0.0       0.565536    3.070646
#
#           stations_interpolated  fused_data_exposure  ACS_fused_data_exposure  \
# 0                      8.276950           973.309221              1058.327778
# 1                      8.677151           927.259981               998.936970
# 2                      9.445171          1037.495595              1120.363349
# 3                     10.179861          1132.265543              1243.998605
# 4                     10.878913          1045.541256              1195.324958
# ...                         ...                  ...                      ...
# 37812924              17.590072             0.025499                 0.017005
# 37812925              17.853620             0.026791                 0.016373
# 37812926              17.034536             0.031045                 0.017704
# 37812927              16.487381             0.017366                 0.021075
# 37812928              15.922723             0.025863                 0.022624
#
#           stations_interpolated_exposure  ACS_stations_interpolated_exposure  \
# 0                             768.193978                          835.295719
# 1                             812.850214                          875.683354
# 2                             882.687851                          953.190666
# 3                             935.061485                         1027.334260
# 4                             960.308205                         1097.881464
# ...                                  ...                                 ...
# 37812924                        0.021223                            0.014153
# 37812925                        0.023505                            0.014365
# 37812926                        0.024034                            0.013706
# 37812927                        0.010931                            0.013266
# 37812928                        0.014646                            0.012811
#
#           year  month  day  hour                 date_time  GEOID    NAME
# 0         2023      6    1     1 2023-06-01 01:00:00+00:00  39111  Monroe
# 1         2023      6    1     2 2023-06-01 02:00:00+00:00  39111  Monroe
# 2         2023      6    1     3 2023-06-01 03:00:00+00:00  39111  Monroe
# 3         2023      6    1     4 2023-06-01 04:00:00+00:00  39111  Monroe
# 4         2023      6    1     5 2023-06-01 05:00:00+00:00  39111  Monroe
# ...        ...    ...  ...   ...                       ...    ...     ...
# 37812924  2023      6   30    19 2023-06-30 19:00:00+00:00   None    None
# 37812925  2023      6   30    20 2023-06-30 20:00:00+00:00   None    None
# 37812926  2023      6   30    21 2023-06-30 21:00:00+00:00   None    None
# 37812927  2023      6   30    22 2023-06-30 22:00:00+00:00   None    None
# 37812928  2023      6   30    23 2023-06-30 23:00:00+00:00   None    None
#
# [37812929 rows x 21 columns]

# %%
save_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_data\Wild_fire\exposure\visualization_county'

county_FIPSs = exposure_county_df['GEOID'].unique()
# county_FIPSs = sorted(county_FIPSs)

for idx, county_FIPS in enumerate(county_FIPSs):
    try:
        df = exposure_county_df.query(f"GEOID == '{county_FIPS}' ").copy()
        df['state_FIPS'] = df['GEOID'].str[:2]
        df = df.merge(state_gdf[['STATEFP', 'STUSPS', 'state_name']], left_on='state_FIPS', right_on='STATEFP')
        group_sum = df.groupby('date_time')[['fused_data_exposure', 
                                      'ACS_fused_data_exposure', 
                                      'stations_interpolated_exposure', 
                                      'ACS_stations_interpolated_exposure']].sum()
    
        fig, ax = plt.subplots(figsize=(20, 10))
        group_sum.plot(ax=ax)
        title = df.iloc[0]['NAME'] + ', ' + df.iloc[0]['STUSPS']
        print(f"Processing {idx + 1} / {len(county_FIPSs)}: {title}")
        
        ax.set_title(title)
    
        fname = os.path.join(save_dir, f"{title}.png")
        plt.savefig(fname, bbox_inches='tight', pad_inches=0.2)
        plt.close()
    except Exception as e:
        print(e)
        continue
    # break
# Out:
# Processing 1 / 255: Monroe, OH
# Processing 2 / 255: Belmont, OH
# Processing 3 / 255: Harrison, OH
# Processing 4 / 255: Jefferson, OH
# Processing 5 / 255: Columbiana, OH
# Processing 6 / 255: Mahoning, OH
# Processing 7 / 255: Trumbull, OH
# Processing 8 / 255: Ashtabula, OH
# Processing 9 / 255: Erie, PA
# Processing 10 / 255: Crawford, PA
# Processing 11 / 255: Mercer, PA
# Processing 12 / 255: Marshall, WV
# Processing 13 / 255: Hancock, WV
# Processing 14 / 255: Lawrence, PA
# Processing 15 / 255: Ohio, WV
# Processing 16 / 255: Brooke, WV
# Processing 17 / 255: Beaver, PA
# Processing 18 / 255: Washington, PA
# Processing 19 / 255: Greene, PA
# Processing 20 / 255: Allegheny, PA
# Processing 21 / 255: Butler, PA
# Processing 22 / 255: Venango, PA
# Processing 23 / 255: Monongalia, WV
# Processing 24 / 255: Chautauqua, NY
# Processing 25 / 255: Warren, PA
# Processing 26 / 255: Fayette, PA
# Processing 27 / 255: Armstrong, PA
# Processing 28 / 255: Clarion, PA
# Processing 29 / 255: Westmoreland, PA
# Processing 30 / 255: Forest, PA
# single positional indexer is out-of-bounds
# Processing 32 / 255: Niagara, NY
# Processing 33 / 255: Erie, NY
# Processing 34 / 255: Preston, WV
# Processing 35 / 255: Cattaraugus, NY
# Processing 36 / 255: Indiana, PA
# Processing 37 / 255: Jefferson, PA
# Processing 38 / 255: Garrett, MD
# Processing 39 / 255: Elk, PA
# Processing 40 / 255: Somerset, PA
# Processing 41 / 255: McKean, PA
# Processing 42 / 255: Orleans, NY
# Processing 43 / 255: Genesee, NY
# Processing 44 / 255: Wyoming, NY
# Processing 45 / 255: Cambria, PA
# Processing 46 / 255: Clearfield, PA
# Processing 47 / 255: Allegany, MD
# Processing 48 / 255: Allegany, NY
# Processing 49 / 255: Monroe, NY
# Processing 50 / 255: Cameron, PA
# Processing 51 / 255: Bedford, PA
# Processing 52 / 255: Mineral, WV
# Processing 53 / 255: Blair, PA
# Processing 54 / 255: Potter, PA
# Processing 55 / 255: Livingston, NY
# Processing 56 / 255: Hampshire, WV
# Processing 57 / 255: Centre, PA
# Processing 58 / 255: Huntingdon, PA
# Processing 59 / 255: Clinton, PA
# Processing 60 / 255: Morgan, WV
# Processing 61 / 255: Steuben, NY
# Processing 62 / 255: Fulton, PA
# Processing 63 / 255: Ontario, NY
# Processing 64 / 255: Washington, MD
# Processing 65 / 255: Wayne, NY
# Processing 66 / 255: Frederick, VA
# Processing 67 / 255: Tioga, PA
# Processing 68 / 255: Berkeley, WV
# Processing 69 / 255: Yates, NY
# Processing 70 / 255: Franklin, PA
# Processing 71 / 255: Mifflin, PA
# Processing 72 / 255: Lycoming, PA
# Processing 73 / 255: Juniata, PA
# Processing 74 / 255: Seneca, NY
# Processing 75 / 255: Jefferson, WV
# Processing 76 / 255: Perry, PA
# Processing 77 / 255: Schuyler, NY
# Processing 78 / 255: Cumberland, PA
# Processing 79 / 255: Cayuga, NY
# Processing 80 / 255: Union, PA
# Processing 81 / 255: Snyder, PA
# Processing 82 / 255: Chemung, NY
# Processing 83 / 255: Oswego, NY
# Processing 84 / 255: Jefferson, NY
# Processing 85 / 255: Frederick, MD
# Processing 86 / 255: Adams, PA
# Processing 87 / 255: Bradford, PA
# Processing 88 / 255: Tompkins, NY
# Processing 89 / 255: Onondaga, NY
# Processing 90 / 255: Sullivan, PA
# Processing 91 / 255: Carroll, MD
# Processing 92 / 255: Northumberland, PA
# Processing 93 / 255: Tioga, NY
# Processing 94 / 255: York, PA
# Processing 95 / 255: Dauphin, PA
# Processing 96 / 255: Montgomery, MD
# Processing 97 / 255: St. Lawrence, NY
# Processing 98 / 255: Montour, PA
# Processing 99 / 255: Cortland, NY
# Processing 100 / 255: Howard, MD
# Processing 101 / 255: Columbia, PA
# Processing 102 / 255: Lewis, NY
# Processing 103 / 255: Schuylkill, PA
# Processing 104 / 255: Madison, NY
# Processing 105 / 255: Lebanon, PA
# Processing 106 / 255: Oneida, NY
# Processing 107 / 255: Broome, NY
# Processing 108 / 255: Baltimore, MD
# Processing 109 / 255: Lancaster, PA
# Processing 110 / 255: Susquehanna, PA
# Processing 111 / 255: Luzerne, PA
# Processing 112 / 255: Wyoming, PA
# Processing 113 / 255: Chenango, NY
# Processing 114 / 255: Berks, PA
# Processing 115 / 255: Baltimore, MD
# Processing 116 / 255: Anne Arundel, MD
# Processing 117 / 255: Harford, MD
# Processing 118 / 255: Herkimer, NY
# Processing 119 / 255: Carbon, PA
# Processing 120 / 255: Lackawanna, PA
# Processing 121 / 255: Franklin, NY
# Processing 122 / 255: Cecil, MD
# Processing 123 / 255: Otsego, NY
# Processing 124 / 255: Delaware, NY
# Processing 125 / 255: Kent, MD
# Processing 126 / 255: Chester, PA
# Processing 127 / 255: Lehigh, PA
# Processing 128 / 255: Wayne, PA
# Processing 129 / 255: Hamilton, NY
# Processing 130 / 255: Monroe, PA
# Processing 131 / 255: Queen Anne's, MD
# Processing 132 / 255: Northampton, PA
# Processing 133 / 255: Montgomery, PA
# Processing 134 / 255: Pike, PA
# Processing 135 / 255: New Castle, DE
# Processing 136 / 255: Fulton, NY
# Processing 137 / 255: Sullivan, NY
# Processing 138 / 255: Montgomery, NY
# Processing 139 / 255: Caroline, MD
# Processing 140 / 255: Bucks, PA
# Processing 141 / 255: Clinton, NY
# Processing 142 / 255: Kent, DE
# Processing 143 / 255: Delaware, PA
# Processing 144 / 255: Essex, NY
# Processing 145 / 255: Schoharie, NY
# Processing 146 / 255: Salem, NJ
# Processing 147 / 255: Warren, NJ
# Processing 148 / 255: Gloucester, NJ
# Processing 149 / 255: Hunterdon, NJ
# Processing 150 / 255: Ulster, NY
# Processing 151 / 255: Warren, NY
# Processing 152 / 255: Sussex, NJ
# Processing 153 / 255: Philadelphia, PA
# Processing 154 / 255: Cumberland, NJ
# Processing 155 / 255: Orange, NY
# Processing 156 / 255: Greene, NY
# Processing 157 / 255: Saratoga, NY
# Processing 158 / 255: Schenectady, NY
# Processing 159 / 255: Camden, NJ
# Processing 160 / 255: Morris, NJ
# Processing 161 / 255: Burlington, NJ
# Processing 162 / 255: Mercer, NJ
# Processing 163 / 255: Albany, NY
# Processing 164 / 255: Grand Isle, VT
# Processing 165 / 255: Somerset, NJ
# Processing 166 / 255: Franklin, VT
# Processing 167 / 255: Atlantic, NJ
# Processing 168 / 255: Passaic, NJ
# Processing 169 / 255: Chittenden, VT
# Processing 170 / 255: Middlesex, NJ
# Processing 171 / 255: Washington, NY
# Processing 172 / 255: Addison, VT
# Processing 173 / 255: Cape May, NJ
# Processing 174 / 255: Monmouth, NJ
# Processing 175 / 255: Union, NJ
# Processing 176 / 255: Essex, NJ
# Processing 177 / 255: Bergen, NJ
# Processing 178 / 255: Rockland, NY
# Processing 179 / 255: Dutchess, NY
# Processing 180 / 255: Columbia, NY
# Processing 181 / 255: Rensselaer, NY
# Processing 182 / 255: Rutland, VT
# Processing 183 / 255: Ocean, NJ
# Processing 184 / 255: Putnam, NY
# Processing 185 / 255: Lamoille, VT
# Processing 186 / 255: Richmond, NY
# Processing 187 / 255: Hudson, NJ
# Processing 188 / 255: Westchester, NY
# Processing 189 / 255: Bennington, VT
# Processing 190 / 255: Washington, VT
# Processing 191 / 255: Kings, NY
# Processing 192 / 255: New York, NY
# Processing 193 / 255: Orleans, VT
# Processing 194 / 255: Windsor, VT
# Processing 195 / 255: Queens, NY
# Processing 196 / 255: Bronx, NY
# Processing 197 / 255: Litchfield, CT
# Processing 198 / 255: Berkshire, MA
# Processing 199 / 255: Fairfield, CT
# Processing 200 / 255: Orange, VT
# Processing 201 / 255: Nassau, NY
# Processing 202 / 255: Windham, VT
# Processing 203 / 255: Caledonia, VT
# Processing 204 / 255: Franklin, MA
# Processing 205 / 255: Hampshire, MA
# Processing 206 / 255: Suffolk, NY
# Processing 207 / 255: New Haven, CT
# Processing 208 / 255: Hampden, MA
# Processing 209 / 255: Hartford, CT
# Processing 210 / 255: Essex, VT
# Processing 211 / 255: Sullivan, NH
# Processing 212 / 255: Grafton, NH
# Processing 213 / 255: Cheshire, NH
# Processing 214 / 255: Middlesex, CT
# Processing 215 / 255: Coos, NH
# Processing 216 / 255: Merrimack, NH
# Processing 217 / 255: Tolland, CT
# Processing 218 / 255: Worcester, MA
# Processing 219 / 255: Hillsborough, NH
# Processing 220 / 255: New London, CT
# Processing 221 / 255: Oxford, ME
# Processing 222 / 255: Belknap, NH
# Processing 223 / 255: Carroll, NH
# Processing 224 / 255: Windham, CT
# Processing 225 / 255: Middlesex, MA
# Processing 226 / 255: Franklin, ME
# Processing 227 / 255: Somerset, ME
# Processing 228 / 255: Providence, RI
# Processing 229 / 255: Rockingham, NH
# Processing 230 / 255: Strafford, NH
# Processing 231 / 255: Aroostook, ME
# Processing 232 / 255: Kent, RI
# Processing 233 / 255: Washington, RI
# Processing 234 / 255: York, ME
# Processing 235 / 255: Cumberland, ME
# Processing 236 / 255: Norfolk, MA
# Processing 237 / 255: Essex, MA
# Processing 238 / 255: Piscataquis, ME
# Processing 239 / 255: Bristol, MA
# Processing 240 / 255: Bristol, RI
# Processing 241 / 255: Suffolk, MA
# Processing 242 / 255: Androscoggin, ME
# Processing 243 / 255: Newport, RI
# Processing 244 / 255: Plymouth, MA
# Processing 245 / 255: Kennebec, ME
# Processing 246 / 255: Sagadahoc, ME
# Processing 247 / 255: Dukes, MA
# Processing 248 / 255: Lincoln, ME
# Processing 249 / 255: Penobscot, ME
# Processing 250 / 255: Barnstable, MA
# Processing 251 / 255: Waldo, ME
# Processing 252 / 255: Knox, ME
# Processing 253 / 255: Nantucket, MA
# Processing 254 / 255: Hancock, ME
# Processing 255 / 255: Washington, ME

# %%
df.loc[:, 'state_FIPS'] = df['GEOID'].str[:2]#.to_list()
df = df.merge(state_gdf[['STATEFP', 'STUSPS', 'state_name']], left_on='state_FIPS', right_on='STATEFP')
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_3992\560376409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'state_FIPS'] = df['GEOID'].str[:2]#.to_list()

# %%
df = exposure_county_df.query("NAME == 'New York' ")

# %%
df
# Out:
#       xy_label  weighted_popu  ACS_weighted_popu             x              y  \
# 0     1824_569     207.629221         209.284794  1.824855e+06  569076.660171
# 1     1824_569     198.582559         209.284794  1.824855e+06  569076.660171
# 2     1824_569     190.839865         209.284794  1.824855e+06  569076.660171
# 3     1824_569     228.054248         209.284794  1.824855e+06  569076.660171
# 4     1824_569     277.178923         209.284794  1.824855e+06  569076.660171
# ...        ...            ...                ...           ...            ...
# 8623  1830_580  127884.903340      122427.599837  1.830798e+06  580961.158016
# 8624  1830_580  125562.092993      122427.599837  1.830798e+06  580961.158016
# 8625  1830_580  123247.195163      122427.599837  1.830798e+06  580961.158016
# 8626  1830_580  126878.324342      122427.599837  1.830798e+06  580961.158016
# 8627  1830_580  122336.572463      122427.599837  1.830798e+06  580961.158016
#
#       fused_data    MASSDEN  PM2_5_DRY_SFC  prediction  stations_interpolated  \
# 0      16.179698  59.604645      10.357073   17.604462              17.429490
# 1      16.247265  59.604645       9.708352   17.111018              18.793478
# 2      16.633902  59.604645       9.711841   16.197189              16.556831
# 3      15.149861   0.000000      11.598392   15.833117              16.212885
# 4      17.370854   0.000000      12.299698   17.037343              14.819690
# ...          ...        ...            ...         ...                    ...
# 8623   71.560019   0.000000      18.604456   79.059006              68.902325
# 8624   68.330056   0.000000      19.164976   82.860625              81.335964
# 8625   56.361323   0.000000      19.944267   71.531607              72.782235
# 8626   50.938495   0.000000      20.474546   52.024126              50.444961
# 8627   46.242291   0.000000      20.447023   42.947167              39.870604
#
#       fused_data_exposure  ACS_fused_data_exposure  \
# 0            3.359378e+03             3.386165e+03
# 1            3.226424e+03             3.400306e+03
# 2            3.174412e+03             3.481223e+03
# 3            3.454990e+03             3.170636e+03
# 4            4.814835e+03             3.635456e+03
# ...                   ...                      ...
# 8623         9.151446e+06             8.760921e+06
# 8624         8.579665e+06             8.365485e+06
# 8625         6.946375e+06             6.900182e+06
# 8626         6.462991e+06             6.236278e+06
# 8627         5.657123e+06             5.661333e+06
#
#       stations_interpolated_exposure  ACS_stations_interpolated_exposure  \
# 0                       3.618871e+03                        3.647727e+03
# 1                       3.732057e+03                        3.933189e+03
# 2                       3.159703e+03                        3.465093e+03
# 3                       3.697417e+03                        3.393110e+03
# 4                       4.107706e+03                        3.101536e+03
# ...                              ...                                 ...
# 8623                    8.811567e+06                        8.435546e+06
# 8624                    1.021271e+07                        9.957767e+06
# 8625                    8.970206e+06                        8.910554e+06
# 8626                    6.400372e+06                        6.175856e+06
# 8627                    4.877633e+06                        4.881262e+06
#
#       year  month  day  hour                 date_time  GEOID      NAME  \
# 0     2023      6    1     1 2023-06-01 01:00:00+00:00  36061  New York
# 1     2023      6    1     2 2023-06-01 02:00:00+00:00  36061  New York
# 2     2023      6    1     3 2023-06-01 03:00:00+00:00  36061  New York
# 3     2023      6    1     4 2023-06-01 04:00:00+00:00  36061  New York
# 4     2023      6    1     5 2023-06-01 05:00:00+00:00  36061  New York
# ...    ...    ...  ...   ...                       ...    ...       ...
# 8623  2023      6   30    19 2023-06-30 19:00:00+00:00  36061  New York
# 8624  2023      6   30    20 2023-06-30 20:00:00+00:00  36061  New York
# 8625  2023      6   30    21 2023-06-30 21:00:00+00:00  36061  New York
# 8626  2023      6   30    22 2023-06-30 22:00:00+00:00  36061  New York
# 8627  2023      6   30    23 2023-06-30 23:00:00+00:00  36061  New York
#
#      state_FIPS STATEFP STUSPS state_name
# 0            36      36     NY   New York
# 1            36      36     NY   New York
# 2            36      36     NY   New York
# 3            36      36     NY   New York
# 4            36      36     NY   New York
# ...         ...     ...    ...        ...
# 8623         36      36     NY   New York
# 8624         36      36     NY   New York
# 8625         36      36     NY   New York
# 8626         36      36     NY   New York
# 8627         36      36     NY   New York
#
# [8628 rows x 25 columns]

# %%
result = grouped.sort_values('sub_area', ascending=False).drop_duplicates(['xy_label'])
result
# Out:
#         xy_label county_FIP  sub_area
# 2740    1340_462      42003  8.827597
# 39215   1827_536      34025  8.827597
# 17809   1593_471      42041  8.827596
# 17195   1584_720      36109  8.827596
# 52767   2009_702      44009  8.827596
# ...          ...        ...       ...
# 51398  1994_1371      23003  0.000532
# 49018  1967_1216      23025  0.000185
# 56762  2059_1395      23003  0.000088
# 62195  2181_1237      23029  0.000078
# 62957  2255_1172      23029  0.000008
#
# [53411 rows x 3 columns]

# %%
grouped['xy_label'].nunique()
# Out:
# 53411

# %%
group_counties = exposure_df.groupby(['date_time', ''])[['fused_data_exposure', 
                                  'ACS_fused_data_exposure', 
                                  'stations_interpolated_exposure', 
                                  'ACS_stations_interpolated_exposure']].sum()
