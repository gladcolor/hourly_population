# %% [markdown]
# # Download

# %%
import os
import base64
import requests
import json
import base64 
import tempfile
from urllib.parse import urlparse
from urllib.parse import unquote

import pandas as pd
import numpy as np
from getpass import getpass
from glob import glob
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
import os
import random
import sqlite3 
import numpy as np
import json
import math
from tqdm.notebook import tqdm
from tqdm import tqdm
tqdm.pandas()

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import Advan_operator as ad_op  
from datetime import datetime


pd.set_option('display.max_columns', None)

access_token = 'ALtAyMZA.Y1sITQvTj6OXSr6XUz31P2ov3XvsdkhpbijDutzY0glCVNohhzM4okEe'

import logging
# Create a logger
logger_name = 'all_logger'
logger = logging.getLogger(logger_name)

# %% [markdown]
# # Neighborhood patterns

# %% [markdown]
# ## helper function

# %%
def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")

def combine_monthly_pattern_home_panel_summary(data_dir, extend='.csv.gz'):
    print(os.path.join(data_dir, f"*{extend}"))
    all_files = glob(os.path.join(data_dir, f"*{extend}"))

    df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])

    return df
    
    # print(all_files)

# Merge CSV files
# home_panel_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'
# home_panel_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23'
# df = combine_monthly_pattern_home_panel_summary(data_dir=home_panel_dir)
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)
# df

# %%
# neighborhood patterns:
# url = r'https://app.deweydata.io/external-api/v3/products/2dfcb598-6e30-49f1-bdba-1deae113a951/files'
# save_dir = r'K:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'   # Dell 2019
# save_dir = r'F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'  # Lenova 2018

# Lenovo
# save_dir = r'D:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  

# Desktop 2018
save_dir = r'E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  


# monthly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/5acc9f39-1ca6-4535-b3ff-38f6b9baf85e/files"
# save_dir = r'K:\SafeGraph\Advan_2024_API\Monthly_Patterns'

# # weekly patterns:
url = r"https://app.deweydata.io/external-api/v3/products/176f0262-c1f6-4dbe-be43-6a6eb21bcf8a/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Weekly_Patterns'
# save_dir = r'D:\SafeGraph\Advan_2024_API\Weekly_Patterns'    # Lenova 2018

# # hourly weather:
# url = r"https://app.deweydata.io/external-api/v3/products/a6be0385-8820-4943-a509-6eac4154b4f6/files"

# monthly home panel summary
# url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
# save_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'


os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# %%
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)

# %%
# df.sort_values(['YEAR', 'MON'])

# %%
def get_all_download_urls():
    total_pages = 1
    current_page = 0
    df_list = []
    while current_page <= total_pages:
        results = requests.get(url=PRODUCT_API_PATH,
                                   params={'page': current_page,
                                           'partition_key_after':  '2018-01-01',   # optionally set date value here
                                           'partition_key_before': '2024-07-31', 
                                          }, # optionally set date value here
                                   headers={'X-API-KEY': API_KEY,
                                            'accept': 'application/json'
                                           })
        response_json = results.json()
        total_pages = response_json['total_pages']
    
        df = pd.DataFrame(response_json)
        df_list.append(df)
        current_page += 1
            
    response_df = pd.concat(df_list)
    
    
    df_list2 = []
    for idx, row in response_df.iterrows():
        # print(row['download_links'])
        df = pd.DataFrame.from_dict([row['download_links']])
        for col, value in row.items():
            if col != 'download_links':
                df[col] = value
                
        df_list2.append(df)
        # break
        
    url_df = pd.concat(df_list2)
    # url_df = url_df.sort_values(["partition_key", 'file_name', 'file_size_bytes'])
    return response_df, url_df

current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime("%Y%m%d_%H%M")

response_df, url_df = get_all_download_urls()

url_df.to_csv(os.path.join(save_dir, f'download_urls_{formatted_datetime}.csv'), index=False)
url_df
# Out:
#                                                  link partition_key  \
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# ..                                                ...           ...
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
#
#                                             file_name file_extension  \
# 0   Weekly_Patterns_Foot_Traffic-0-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-1-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-2-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-3-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-4-DATE_RANGE_STAR...        .csv.gz
# ..                                                ...            ...
# 0   Weekly_Patterns_Foot_Traffic-326-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-327-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-328-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-329-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-330-DATE_RANGE_ST...        .csv.gz
#
#     file_size_bytes               modified_at
# 0         209760374  2023-12-07T23:48:41.183Z
# 0         209747233  2023-12-08T00:08:54.090Z
# 0         209735990  2023-12-08T00:09:59.509Z
# 0         209768862  2023-12-08T00:11:25.218Z
# 0         209763824  2023-12-08T00:12:41.071Z
# ..              ...                       ...
# 0         209730608  2024-01-03T05:08:47.403Z
# 0         209757477  2024-01-03T05:09:05.855Z
# 0         209750096  2024-01-03T05:09:24.274Z
# 0         209723254  2024-01-03T05:09:42.676Z
# 0         209734444  2024-01-03T05:10:00.875Z
#
# [6789 rows x 6 columns]

# %%
processed_cnt = 0

def formart_file_name(row, index):
    # remove file number in the middle
    file_name = row['file_name']
    file_extension = row['file_extension']
    hypen_pos_list = [p for p, char in enumerate(file_name) if char == '-']
    hyphen_pos1 = hypen_pos_list[0]
    hyphen_pos2 = hypen_pos_list[1]
    new_fname = file_name[:hyphen_pos1] + file_name[hyphen_pos2:]
    new_fname = new_fname[:-len(file_extension)] + f'_{index:02}' + file_extension
    return new_fname 
    
def formart_file_name_v2(row, index):
    # remove file number in the middle
    short_identifer = row['link'].split("?")[0].split("-")[-1]
    # print(short_identifer)
    file_name = row['file_name']
    file_extension = row['file_extension']
    hypen_pos_list = [p for p, char in enumerate(file_name) if char == '-']
    hyphen_pos1 = hypen_pos_list[0]
    hyphen_pos2 = hypen_pos_list[1]
    new_fname = file_name[:hyphen_pos1] + file_name[hyphen_pos2:]
    # new_fname = new_fname[:-len(file_extension)] + f'_{index:02}' + file_extension
    new_fname = new_fname[:-len(file_extension)] + f'_{short_identifer}' + file_extension
    return new_fname 

processed_cnt = 0
for partition_key, df in url_df.groupby('partition_key'):
   
    df = df.reset_index()
    
    for i, row in df.iterrows():
        try:
            
            # print(partition_key, i + 1)
            # print("Downloading: ", row['link'])
            date = row['partition_key']
            file_extension = row['file_extension']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
    
            # base_name = row['file_name']
            # base_name = row['file_name'][0:24] + row['file_name'][-35:-7] + f"_{i + 1}.csv.gz"
            # base_name = formart_file_name(row, i)
            base_name = formart_file_name_v2(row, i)
            # print("base_name:", base_name)
            
            file_name = os.path.join(file_dir, base_name)
             
            print(f'Downloading file {file_name}')

            processed_cnt += 1
            
            if os.path.exists(file_name):
                print(f"File exists, skip! The file is: {file_name} \n")
                continue
            
        
            # # loop through download links and save to your computer
            data = requests.get(row['link'], stream=True)
            safe_file_write(file_path=file_name, content=data.content)
             
            #  += 1
            
            print(f"    Processed {i + 1} / {len(df)} files for {partition_key}.")
            print(f"Processed {processed_cnt} / {len(url_df)} files in total.")
            # print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
            
            print()
        except Exception as e:
            print("Error:", e)
            continue


print("Done.")
# Out:
# Year, month, day: 2018 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-01-01_0b87016011de_2304_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-01-01.
# Processed 1 / 73 files in total.
#
# Year, month, day: 2018 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-02-01_0b87016011de_104_7_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-02-01.
# Processed 2 / 73 files in total.
#
# Year, month, day: 2018 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-03-01_0b87016011de_704_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-03-01.
# Processed 3 / 73 files in total.
#
# Year, month, day: 2018 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-04-01_0b87016011de_004_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-04-01.
# Processed 4 / 73 files in total.
#
# Year, month, day: 2018 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-05-01_0b87016011de_404_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-05-01.
# Processed 5 / 73 files in total.
#
# Year, month, day: 2018 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-06-01_0b87016011de_504_4_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-06-01.
# Processed 6 / 73 files in total.
#
# Year, month, day: 2018 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-07-01_0b87016011de_1204_7_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-07-01.
# Processed 7 / 73 files in total.
#
# Year, month, day: 2018 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-08-01_0b87016011de_804_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-08-01.
# Processed 8 / 73 files in total.
#
# Year, month, day: 2018 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-09-01_0b87016011de_2004_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-09-01.
# Processed 9 / 73 files in total.
#
# Year, month, day: 2018 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-10-01_0b87016011de_1704_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-10-01.
# Processed 10 / 73 files in total.
#
# Year, month, day: 2018 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-11-01_0b87016011de_2304_7_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-11-01.
# Processed 11 / 73 files in total.
#
# Year, month, day: 2018 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-12-01_0b87016011de_2004_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2018-12-01.
# Processed 12 / 73 files in total.
#
# Year, month, day: 2019 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-01-01_0b87016011de_1004_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-01-01.
# Processed 13 / 73 files in total.
#
# Year, month, day: 2019 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-02-01_0b87016011de_504_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-02-01.
# Processed 14 / 73 files in total.
#
# Year, month, day: 2019 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-03-01_0b87016011de_2004_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-03-01.
# Processed 15 / 73 files in total.
#
# Year, month, day: 2019 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-04-01_0b87016011de_1004_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-04-01.
# Processed 16 / 73 files in total.
#
# Year, month, day: 2019 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-05-01_0b87016011de_3004_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-05-01.
# Processed 17 / 73 files in total.
#
# Year, month, day: 2019 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-06-01_0b87016011de_1304_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-06-01.
# Processed 18 / 73 files in total.
#
# Year, month, day: 2019 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-07-01_0b87016011de_204_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-07-01.
# Processed 19 / 73 files in total.
#
# Year, month, day: 2019 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-08-01_0b87016011de_2404_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-08-01.
# Processed 20 / 73 files in total.
#
# Year, month, day: 2019 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-09-01_0b87016011de_1304_4_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-09-01.
# Processed 21 / 73 files in total.
#
# Year, month, day: 2019 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-10-01_0b87016011de_1204_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-10-01.
# Processed 22 / 73 files in total.
#
# Year, month, day: 2019 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-11-01_0b87016011de_2504_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-11-01.
# Processed 23 / 73 files in total.
#
# Year, month, day: 2019 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-12-01_0b87016011de_1204_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2019-12-01.
# Processed 24 / 73 files in total.
#
# Year, month, day: 2020 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-01-01_0b87016011de_604_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-01-01.
# Processed 25 / 73 files in total.
#
# Year, month, day: 2020 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-02-01_0b87016011de_004_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-02-01.
# Processed 26 / 73 files in total.
#
# Year, month, day: 2020 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-03-01_0b87016011de_2604_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-03-01.
# Processed 27 / 73 files in total.
#
# Year, month, day: 2020 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-04-01_0b87016011de_604_7_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-04-01.
# Processed 28 / 73 files in total.
#
# Year, month, day: 2020 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-05-01_0b87016011de_704_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-05-01.
# Processed 29 / 73 files in total.
#
# Year, month, day: 2020 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-06-01_0b87016011de_2004_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-06-01.
# Processed 30 / 73 files in total.
#
# Year, month, day: 2020 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-07-01_0b87016011de_2204_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-07-01.
# Processed 31 / 73 files in total.
#
# Year, month, day: 2020 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-08-01_0b87016011de_404_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-08-01.
# Processed 32 / 73 files in total.
#
# Year, month, day: 2020 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-09-01_0b87016011de_1104_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-09-01.
# Processed 33 / 73 files in total.
#
# Year, month, day: 2020 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-10-01_0b87016011de_004_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-10-01.
# Processed 34 / 73 files in total.
#
# Year, month, day: 2020 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-11-01_0b87016011de_204_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-11-01.
# Processed 35 / 73 files in total.
#
# Year, month, day: 2020 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-12-01_0b87016011de_804_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2020-12-01.
# Processed 36 / 73 files in total.
#
# Year, month, day: 2021 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-01-01_0b87016011de_2004_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-01-01.
# Processed 37 / 73 files in total.
#
# Year, month, day: 2021 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-02-01_0b87016011de_3104_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-02-01.
# Processed 38 / 73 files in total.
#
# Year, month, day: 2021 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-03-01_0b87016011de_304_7_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-03-01.
# Processed 39 / 73 files in total.
#
# Year, month, day: 2021 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-04-01_0b87016011de_404_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-04-01.
# Processed 40 / 73 files in total.
#
# Year, month, day: 2021 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-05-01_0b87016011de_2304_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-05-01.
# Processed 41 / 73 files in total.
#
# Year, month, day: 2021 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-06-01_0b87016011de_3004_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-06-01.
# Processed 42 / 73 files in total.
#
# Year, month, day: 2021 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-07-01_0b87016011de_204_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-07-01.
# Processed 43 / 73 files in total.
#
# Year, month, day: 2021 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-08-01_0b87016011de_1804_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-08-01.
# Processed 44 / 73 files in total.
#
# Year, month, day: 2021 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-09-01_0b87016011de_1704_4_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-09-01.
# Processed 45 / 73 files in total.
#
# Year, month, day: 2021 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-10-01_0b87016011de_1704_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-10-01.
# Processed 46 / 73 files in total.
#
# Year, month, day: 2021 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-11-01_0b87016011de_304_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-11-01.
# Processed 47 / 73 files in total.
#
# Year, month, day: 2021 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-12-01_0b87016011de_3104_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2021-12-01.
# Processed 48 / 73 files in total.
#
# Year, month, day: 2022 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-01-01_0b87016011de_3104_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-01-01.
# Processed 49 / 73 files in total.
#
# Year, month, day: 2022 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-02-01_0b87016011de_3104_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-02-01.
# Processed 50 / 73 files in total.
#
# Year, month, day: 2022 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-03-01_0b87016011de_2304_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-03-01.
# Processed 51 / 73 files in total.
#
# Year, month, day: 2022 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-04-01_0b87016011de_1704_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-04-01.
# Processed 52 / 73 files in total.
#
# Year, month, day: 2022 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-05-01_0b87016011de_2004_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-05-01.
# Processed 53 / 73 files in total.
#
# Year, month, day: 2022 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-06-01_0b87016011de_1104_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-06-01.
# Processed 54 / 73 files in total.
#
# Year, month, day: 2022 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-07-01_0b87016011de_904_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-07-01.
# Processed 55 / 73 files in total.
#
# Year, month, day: 2022 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-08-01_0b87016011de_1504_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-08-01.
# Processed 56 / 73 files in total.
#
# Year, month, day: 2022 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-09-01_0b87016011de_2604_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-09-01.
# Processed 57 / 73 files in total.
#
# Year, month, day: 2022 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-10-01_0b87016011de_2904_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-10-01.
# Processed 58 / 73 files in total.
#
# Year, month, day: 2022 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-11-01_0b87016011de_1204_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-11-01.
# Processed 59 / 73 files in total.
#
# Year, month, day: 2022 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-12-01_0b87016011de_2804_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2022-12-01.
# Processed 60 / 73 files in total.
#
# Year, month, day: 2023 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-01-01_0b87016011de_2304_4_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-01-01.
# Processed 61 / 73 files in total.
#
# Year, month, day: 2023 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-02-01_0b87016011de_2804_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-02-01.
# Processed 62 / 73 files in total.
#
# Year, month, day: 2023 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-03-01_0b87016011de_1504_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-03-01.
# Processed 63 / 73 files in total.
#
# Year, month, day: 2023 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-04-01_0b87016011de_2304_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-04-01.
# Processed 64 / 73 files in total.
#
# Year, month, day: 2023 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-05-01_0b87016011de_104_7_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-05-01.
# Processed 65 / 73 files in total.
#
# Year, month, day: 2023 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-06-01_0b87016011de_2104_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-06-01.
# Processed 66 / 73 files in total.
#
# Year, month, day: 2023 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-07-01_0b87016011de_1004_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-07-01.
# Processed 67 / 73 files in total.
#
# Year, month, day: 2023 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-08-01_0b87016011de_404_5_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-08-01.
# Processed 68 / 73 files in total.
#
# Year, month, day: 2023 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-09-01_0b87016011de_2104_3_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-09-01.
# Processed 69 / 73 files in total.
#
# Year, month, day: 2023 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-10-01_0b87016011de_604_0_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-10-01.
# Processed 70 / 73 files in total.
#
# Year, month, day: 2023 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-11-01_0b87016011de_2204_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-11-01.
# Processed 71 / 73 files in total.
#
# Year, month, day: 2023 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-12-01_0b87016011de_2804_7_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2023-12-01.
# Processed 72 / 73 files in total.
#
# Year, month, day: 2024 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2024\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2024-01-01_0b8701798076_104_1_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2024-01-01.
# Processed 73 / 73 files in total.
#
# Done.

# %%
Not used below

# %%
# downloaded_cnt = 0
# for partition_key, df in url_df.groupby('partition_key'):
   
#     df = df.reset_index()
#     for i, row in df.iterrows():
#         try:
#             # print(partition_key, i + 1)
#             # print("Downloading: ", row['link'])
#             date = row['partition_key']
#             year = date[:4]
#             month = date[5:7]
#             day = date[-2:]
#             file_dir = os.path.join(save_dir, year, month, day)
#             os.makedirs(file_dir, exist_ok=True)
#             print("Year, month, day:", year, month, day)
    
#             # base_name = row['file_name']
#             base_name = row['file_name'][0:24] + row['file_name'][-35:-7] + f"_{i + 1:02}.csv.gz"
#             # print("base_name:", base_name)
            
#             file_name = os.path.join(file_dir, base_name)
             
#             print(f'Downloading file {file_name}')
        
#             if os.path.exists(file_name):
#                 print(f"File exists, skip! The file is: {file_name} \n")
#                 continue
        
#             # # loop through download links and save to your computer
#             data = requests.get(row['link'], stream=True)
#             safe_file_write(file_path=file_name, content=data.content)
             
#             #  += 1
#             downloaded_cnt += 1
#             print(f"    Downloaded {i + 1} / {len(df)} files for {partition_key}.")
#             print(f"Downloaded {downloaded_cnt} / {len(url_df)} files in total.")
#             # print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
            
#             print()
#         except Exception as e:
#             print("Error:", e)
#             continue

# print("Done.")

# %%
STOP

Not used below

# %%
## api_key = r'J923tlBL.54vRQ2rAhcMc8nhb1v6IZyJwCWUkgG2LA33tHCpJJXhFwilrUhT1ckxJ'

 
# neighborhood patterns:
url = r'https://app.deweydata.io/external-api/v3/products/2dfcb598-6e30-49f1-bdba-1deae113a951/files'
# save_dir = r'K:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'   # Dell 2019
save_dir = r'F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'  # Lenova 2018

# monthly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/5acc9f39-1ca6-4535-b3ff-38f6b9baf85e/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Monthly_Patterns'

# # weekly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/176f0262-c1f6-4dbe-be43-6a6eb21bcf8a/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Weekly_Patterns'

# # hourly weather:
# url = r"https://app.deweydata.io/external-api/v3/products/a6be0385-8820-4943-a509-6eac4154b4f6/files"

# monthly home panel summary
# url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
# save_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'


os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# loop through all API result pages, keeping track of number of downloaded files
page = 1
download_count = 0

while True:
    # get results from API endpoint, using API key for authentication
    results = requests.get(url=PRODUCT_API_PATH,
                           params={'page': page,
                                   'partition_key_after': '2018-01-01',   # optionally set date value here
                                   'partition_key_before': '2023-12-31', 
                                  }, # optionally set date value here
                           headers={'X-API-KEY': API_KEY,
                                    'accept': 'application/json'
                                   })
    response_json = results.json()
    total_pages = response_json['total_pages']

    link_cnt = len(response_json['download_links'])
 
    # for each result page, loop through download links and save to your computer
    for idx, link_data in enumerate(response_json['download_links']):
        # create file name for each link
        print(f"Downloading {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloading {download_count} files in total, Page {page} / {total_pages}.")
        
        if response_json['partition_column']:
            date = link_data['partition_key']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
            # file_name = f"file-{download_count+1}-{response_json['partition_column']}-{link_data['partition_key']}.csv.gz" 
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            # base_name = unquote(base_name) 
            base_name = link_data['file_name']
            base_name = base_name[0:24] + base_name[-35:] 
            
            file_name = os.path.join(file_dir, base_name)
            
        else:
            # not tested
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            # base_name = unquote(base_name) 
            base_name = link_data['file_name']  
            # need to remove the numbers in the result: Neighborhood_Patterns_US-8-DATE_RANGE_START-2020-02-01.csv # 2024-01-05
            base_name = base_name[0:24] + base_name[-35:] 
            # print("base_name:", base_name)
            
            file_name = os.path.join(file_dir, base_name)
            
        print(f'Downloading file {file_name}')

        if os.path.exists(file_name):
            print(f"File exists, skip! The file is: {file_name} \n")
            continue

        # # loop through download links and save to your computer
        data = requests.get(link_data['link'], stream=True)
        safe_file_write(file_path=file_name, content=data.content)
        
  
        download_count += 1
        print(f"Downloaded {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
        
        print()

    # only continue if there are more result pages to process    
    if page >= total_pages:
        break
        
    page += 1
    
    

print(f"Successfully downloaded {download_count} files.")

print("Done")
# returns = results.json()
# print(returns.keys())
# print(len(returns['download_links']))
# del returns['download_links']
# returns

# %%
# response_json

# %% [markdown]
# # Download monthly patterns home panel summary

# %%
api_key = r'J923tlBL.54vRQ2rAhcMc8nhb1v6IZyJwCWUkgG2LA33tHCpJJXhFwilrUhT1ckxJ'

# monthly home panel summary
url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
save_dir = r'D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'
os.makedirs(save_dir, exist_ok=True)

# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# loop through all API result pages, keeping track of number of downloaded files
page = 1
download_count = 0

while True:
    # get results from API endpoint, using API key for authentication
    results = requests.get(url=PRODUCT_API_PATH,
                           params={'page': page,
                                   # 'partition_key_after': '2023-05-30',   # optionally set date value here
                                   # 'partition_key_before': '2023-09-01', 
                                  }, # optionally set date value here
                           headers={'X-API-KEY': API_KEY,
                                    'accept': 'application/json'
                                   })
    response_json = results.json()
    total_pages = response_json['total_pages']

    link_cnt = len(response_json['download_links'])
     
    # for each result page, loop through download links and save to your computer
    for idx, link_data in enumerate(response_json['download_links']):
        # create file name for each link
        print(f"Downloading {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloading {download_count} files in total, Page {page} / {total_pages}.")
        
        if response_json['partition_column']:
            date = link_data['partition_key']
            # year = date[:4]
            # month = date[5:7]
            # day = date[-2:]
     
            
            # print("Year, month, day:", year, month, day)
            # file_name = f"file-{download_count+1}-{response_json['partition_column']}-{link_data['partition_key']}.csv.gz" 
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            base_name = link_data['file_name']
            
            
            
        else:
            # not tested
            url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            base_name = link_data['file_name']
            file_name = os.path.join(save_dir, base_name)
            
            
        print(f'Downloading file {file_name}')

        if os.path.exists(file_name):
            print(f"File exists, skip! The file is: {file_name} \n")
            continue

        # # loop through download links and save to your computer
        data = requests.get(link_data['link'], stream=True)
        safe_file_write(file_path=file_name, content=data.content)
        
        
        # with open(file_name, 'wb') as file:            
        #     file.write(data.content)
             
        download_count += 1
        print(f"Downloaded {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
        
        print()

    # only continue if there are more result pages to process
    
    if page >= total_pages:
        break
        
    page += 1
    
    

print(f"Successfully downloaded {download_count} files.")

print("Done")
# returns = results.json()
# print(returns.keys())
# print(len(returns['download_links']))
# del returns['download_links']
# returns
# Out:
# Downloading 1 / 59 files, in Page 1.
# Downloading 0 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-0.csv.gz
# File successfully written.
# Downloaded 1 / 59 files, in Page 1.
# Downloaded 1 files in total, Page 1 / 1.
#
# Downloading 2 / 59 files, in Page 1.
# Downloading 1 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-1.csv.gz
# File successfully written.
# Downloaded 2 / 59 files, in Page 1.
# Downloaded 2 files in total, Page 1 / 1.
#
# Downloading 3 / 59 files, in Page 1.
# Downloading 2 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-2.csv.gz
# File successfully written.
# Downloaded 3 / 59 files, in Page 1.
# Downloaded 3 files in total, Page 1 / 1.
#
# Downloading 4 / 59 files, in Page 1.
# Downloading 3 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-3.csv.gz
# File successfully written.
# Downloaded 4 / 59 files, in Page 1.
# Downloaded 4 files in total, Page 1 / 1.
#
# Downloading 5 / 59 files, in Page 1.
# Downloading 4 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-4.csv.gz
# File successfully written.
# Downloaded 5 / 59 files, in Page 1.
# Downloaded 5 files in total, Page 1 / 1.
#
# Downloading 6 / 59 files, in Page 1.
# Downloading 5 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-5.csv.gz
# File successfully written.
# Downloaded 6 / 59 files, in Page 1.
# Downloaded 6 files in total, Page 1 / 1.
#
# Downloading 7 / 59 files, in Page 1.
# Downloading 6 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-6.csv.gz
# File successfully written.
# Downloaded 7 / 59 files, in Page 1.
# Downloaded 7 files in total, Page 1 / 1.
#
# Downloading 8 / 59 files, in Page 1.
# Downloading 7 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-7.csv.gz
# File successfully written.
# Downloaded 8 / 59 files, in Page 1.
# Downloaded 8 files in total, Page 1 / 1.
#
# Downloading 9 / 59 files, in Page 1.
# Downloading 8 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-8.csv.gz
# File successfully written.
# Downloaded 9 / 59 files, in Page 1.
# Downloaded 9 files in total, Page 1 / 1.
#
# Downloading 10 / 59 files, in Page 1.
# Downloading 9 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-9.csv.gz
# File successfully written.
# Downloaded 10 / 59 files, in Page 1.
# Downloaded 10 files in total, Page 1 / 1.
#
# Downloading 11 / 59 files, in Page 1.
# Downloading 10 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-10.csv.gz
# File successfully written.
# Downloaded 11 / 59 files, in Page 1.
# Downloaded 11 files in total, Page 1 / 1.
#
# Downloading 12 / 59 files, in Page 1.
# Downloading 11 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-11.csv.gz
# File successfully written.
# Downloaded 12 / 59 files, in Page 1.
# Downloaded 12 files in total, Page 1 / 1.
#
# Downloading 13 / 59 files, in Page 1.
# Downloading 12 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-12.csv.gz
# File successfully written.
# Downloaded 13 / 59 files, in Page 1.
# Downloaded 13 files in total, Page 1 / 1.
#
# Downloading 14 / 59 files, in Page 1.
# Downloading 13 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-13.csv.gz
# File successfully written.
# Downloaded 14 / 59 files, in Page 1.
# Downloaded 14 files in total, Page 1 / 1.
#
# Downloading 15 / 59 files, in Page 1.
# Downloading 14 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-14.csv.gz
# File successfully written.
# Downloaded 15 / 59 files, in Page 1.
# Downloaded 15 files in total, Page 1 / 1.
#
# Downloading 16 / 59 files, in Page 1.
# Downloading 15 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-15.csv.gz
# File successfully written.
# Downloaded 16 / 59 files, in Page 1.
# Downloaded 16 files in total, Page 1 / 1.
#
# Downloading 17 / 59 files, in Page 1.
# Downloading 16 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-16.csv.gz
# File successfully written.
# Downloaded 17 / 59 files, in Page 1.
# Downloaded 17 files in total, Page 1 / 1.
#
# Downloading 18 / 59 files, in Page 1.
# Downloading 17 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-17.csv.gz
# File successfully written.
# Downloaded 18 / 59 files, in Page 1.
# Downloaded 18 files in total, Page 1 / 1.
#
# Downloading 19 / 59 files, in Page 1.
# Downloading 18 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-18.csv.gz
# File successfully written.
# Downloaded 19 / 59 files, in Page 1.
# Downloaded 19 files in total, Page 1 / 1.
#
# Downloading 20 / 59 files, in Page 1.
# Downloading 19 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-19.csv.gz
# File successfully written.
# Downloaded 20 / 59 files, in Page 1.
# Downloaded 20 files in total, Page 1 / 1.
#
# Downloading 21 / 59 files, in Page 1.
# Downloading 20 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-20.csv.gz
# File successfully written.
# Downloaded 21 / 59 files, in Page 1.
# Downloaded 21 files in total, Page 1 / 1.
#
# Downloading 22 / 59 files, in Page 1.
# Downloading 21 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-21.csv.gz
# File successfully written.
# Downloaded 22 / 59 files, in Page 1.
# Downloaded 22 files in total, Page 1 / 1.
#
# Downloading 23 / 59 files, in Page 1.
# Downloading 22 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-22.csv.gz
# File successfully written.
# Downloaded 23 / 59 files, in Page 1.
# Downloaded 23 files in total, Page 1 / 1.
#
# Downloading 24 / 59 files, in Page 1.
# Downloading 23 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-23.csv.gz
# File successfully written.
# Downloaded 24 / 59 files, in Page 1.
# Downloaded 24 files in total, Page 1 / 1.
#
# Downloading 25 / 59 files, in Page 1.
# Downloading 24 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-24.csv.gz
# File successfully written.
# Downloaded 25 / 59 files, in Page 1.
# Downloaded 25 files in total, Page 1 / 1.
#
# Downloading 26 / 59 files, in Page 1.
# Downloading 25 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-25.csv.gz
# File successfully written.
# Downloaded 26 / 59 files, in Page 1.
# Downloaded 26 files in total, Page 1 / 1.
#
# Downloading 27 / 59 files, in Page 1.
# Downloading 26 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-26.csv.gz
# File successfully written.
# Downloaded 27 / 59 files, in Page 1.
# Downloaded 27 files in total, Page 1 / 1.
#
# Downloading 28 / 59 files, in Page 1.
# Downloading 27 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-27.csv.gz
# File successfully written.
# Downloaded 28 / 59 files, in Page 1.
# Downloaded 28 files in total, Page 1 / 1.
#
# Downloading 29 / 59 files, in Page 1.
# Downloading 28 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-28.csv.gz
# File successfully written.
# Downloaded 29 / 59 files, in Page 1.
# Downloaded 29 files in total, Page 1 / 1.
#
# Downloading 30 / 59 files, in Page 1.
# Downloading 29 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-29.csv.gz
# File successfully written.
# Downloaded 30 / 59 files, in Page 1.
# Downloaded 30 files in total, Page 1 / 1.
#
# Downloading 31 / 59 files, in Page 1.
# Downloading 30 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-30.csv.gz
# File successfully written.
# Downloaded 31 / 59 files, in Page 1.
# Downloaded 31 files in total, Page 1 / 1.
#
# Downloading 32 / 59 files, in Page 1.
# Downloading 31 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-31.csv.gz
# File successfully written.
# Downloaded 32 / 59 files, in Page 1.
# Downloaded 32 files in total, Page 1 / 1.
#
# Downloading 33 / 59 files, in Page 1.
# Downloading 32 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-32.csv.gz
# File successfully written.
# Downloaded 33 / 59 files, in Page 1.
# Downloaded 33 files in total, Page 1 / 1.
#
# Downloading 34 / 59 files, in Page 1.
# Downloading 33 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-33.csv.gz
# File successfully written.
# Downloaded 34 / 59 files, in Page 1.
# Downloaded 34 files in total, Page 1 / 1.
#
# Downloading 35 / 59 files, in Page 1.
# Downloading 34 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-34.csv.gz
# File successfully written.
# Downloaded 35 / 59 files, in Page 1.
# Downloaded 35 files in total, Page 1 / 1.
#
# Downloading 36 / 59 files, in Page 1.
# Downloading 35 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-35.csv.gz
# File successfully written.
# Downloaded 36 / 59 files, in Page 1.
# Downloaded 36 files in total, Page 1 / 1.
#
# Downloading 37 / 59 files, in Page 1.
# Downloading 36 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-36.csv.gz
# File successfully written.
# Downloaded 37 / 59 files, in Page 1.
# Downloaded 37 files in total, Page 1 / 1.
#
# Downloading 38 / 59 files, in Page 1.
# Downloading 37 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-37.csv.gz
# File successfully written.
# Downloaded 38 / 59 files, in Page 1.
# Downloaded 38 files in total, Page 1 / 1.
#
# Downloading 39 / 59 files, in Page 1.
# Downloading 38 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-38.csv.gz
# File successfully written.
# Downloaded 39 / 59 files, in Page 1.
# Downloaded 39 files in total, Page 1 / 1.
#
# Downloading 40 / 59 files, in Page 1.
# Downloading 39 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-39.csv.gz
# File successfully written.
# Downloaded 40 / 59 files, in Page 1.
# Downloaded 40 files in total, Page 1 / 1.
#
# Downloading 41 / 59 files, in Page 1.
# Downloading 40 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-40.csv.gz
# File successfully written.
# Downloaded 41 / 59 files, in Page 1.
# Downloaded 41 files in total, Page 1 / 1.
#
# Downloading 42 / 59 files, in Page 1.
# Downloading 41 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-41.csv.gz
# File successfully written.
# Downloaded 42 / 59 files, in Page 1.
# Downloaded 42 files in total, Page 1 / 1.
#
# Downloading 43 / 59 files, in Page 1.
# Downloading 42 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-42.csv.gz
# File successfully written.
# Downloaded 43 / 59 files, in Page 1.
# Downloaded 43 files in total, Page 1 / 1.
#
# Downloading 44 / 59 files, in Page 1.
# Downloading 43 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-43.csv.gz
# File successfully written.
# Downloaded 44 / 59 files, in Page 1.
# Downloaded 44 files in total, Page 1 / 1.
#
# Downloading 45 / 59 files, in Page 1.
# Downloading 44 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-44.csv.gz
# File successfully written.
# Downloaded 45 / 59 files, in Page 1.
# Downloaded 45 files in total, Page 1 / 1.
#
# Downloading 46 / 59 files, in Page 1.
# Downloading 45 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-45.csv.gz
# File successfully written.
# Downloaded 46 / 59 files, in Page 1.
# Downloaded 46 files in total, Page 1 / 1.
#
# Downloading 47 / 59 files, in Page 1.
# Downloading 46 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-46.csv.gz
# File successfully written.
# Downloaded 47 / 59 files, in Page 1.
# Downloaded 47 files in total, Page 1 / 1.
#
# Downloading 48 / 59 files, in Page 1.
# Downloading 47 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-47.csv.gz
# File successfully written.
# Downloaded 48 / 59 files, in Page 1.
# Downloaded 48 files in total, Page 1 / 1.
#
# Downloading 49 / 59 files, in Page 1.
# Downloading 48 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-48.csv.gz
# File successfully written.
# Downloaded 49 / 59 files, in Page 1.
# Downloaded 49 files in total, Page 1 / 1.
#
# Downloading 50 / 59 files, in Page 1.
# Downloading 49 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-49.csv.gz
# File successfully written.
# Downloaded 50 / 59 files, in Page 1.
# Downloaded 50 files in total, Page 1 / 1.
#
# Downloading 51 / 59 files, in Page 1.
# Downloading 50 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-50.csv.gz
# File successfully written.
# Downloaded 51 / 59 files, in Page 1.
# Downloaded 51 files in total, Page 1 / 1.
#
# Downloading 52 / 59 files, in Page 1.
# Downloading 51 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-51.csv.gz
# File successfully written.
# Downloaded 52 / 59 files, in Page 1.
# Downloaded 52 files in total, Page 1 / 1.
#
# Downloading 53 / 59 files, in Page 1.
# Downloading 52 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-52.csv.gz
# File successfully written.
# Downloaded 53 / 59 files, in Page 1.
# Downloaded 53 files in total, Page 1 / 1.
#
# Downloading 54 / 59 files, in Page 1.
# Downloading 53 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-53.csv.gz
# File successfully written.
# Downloaded 54 / 59 files, in Page 1.
# Downloaded 54 files in total, Page 1 / 1.
#
# Downloading 55 / 59 files, in Page 1.
# Downloading 54 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-54.csv.gz
# File successfully written.
# Downloaded 55 / 59 files, in Page 1.
# Downloaded 55 files in total, Page 1 / 1.
#
# Downloading 56 / 59 files, in Page 1.
# Downloading 55 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-55.csv.gz
# File successfully written.
# Downloaded 56 / 59 files, in Page 1.
# Downloaded 56 files in total, Page 1 / 1.
#
# Downloading 57 / 59 files, in Page 1.
# Downloading 56 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-56.csv.gz
# File successfully written.
# Downloaded 57 / 59 files, in Page 1.
# Downloaded 57 files in total, Page 1 / 1.
#
# Downloading 58 / 59 files, in Page 1.
# Downloading 57 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-57.csv.gz
# File successfully written.
# Downloaded 58 / 59 files, in Page 1.
# Downloaded 58 files in total, Page 1 / 1.
#
# Downloading 59 / 59 files, in Page 1.
# Downloading 58 files in total, Page 1 / 1.
# Downloading file D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_Home_Panel_Summary-58.csv.gz
# File successfully written.
# Downloaded 59 / 59 files, in Page 1.
# Downloaded 59 files in total, Page 1 / 1.
#
# Successfully downloaded 59 files.
# Done

# %% [markdown]
# # Merge monthly patterns home panel

# %%
folder = r'D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'

# %%
panel_df = ad_op.load_neighborhood_monthly_folder(folder,  extions=['gz'], start_str='Monthly_Patterns_Home_Panel_Summary', use_cols=None, verbose=True, test=False)
panel_df
# Out:
#         YEAR  MON REGION ISO_COUNTRY_CODE CENSUS_BLOCK_GROUP  \
# 0       2022   11     AB               CA        CA:48060918
# 1       2022   11     AB               CA        CA:48110839
# 2       2022   11     AB               CA        CA:48060442
# 3       2022   11     AB               CA        CA:48061273
# 4       2022   11     AB               CA        CA:48060836
# ...      ...  ...    ...              ...                ...
# 538040  2023    6     YT               CA        CA:60010194
# 538041  2023    6     YT               CA        CA:60010271
# 538042  2023    6     YT               CA        CA:60010242
# 538043  2023    6     YT               CA        CA:60010195
# 538044  2023    6     YT               CA        CA:60010304
#
#         NUMBER_DEVICES_RESIDING  NUMBER_DEVICES_PRIMARY_DAYTIME
# 0                           2.0                             NaN
# 1                           1.0                             NaN
# 2                           1.0                             NaN
# 3                           1.0                             NaN
# 4                           3.0                             NaN
# ...                         ...                             ...
# 538040                     23.0                            42.0
# 538041                     50.0                            44.0
# 538042                     39.0                            46.0
# 538043                     37.0                            48.0
# 538044                     54.0                            48.0
#
# [16466450 rows x 7 columns]

# %%
new_fname = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\Wild_fire\home_panel_summary_2019_2023_restated_20240119_v2.csv.gz'
panel_df.to_csv(new_fname, index=False)

# %%
len(panel_df.query(f"ISO_COUNTRY_CODE == 'US' ")) / 6 / 12
# Out:
# 184805.54166666666

# %%
monthly_device_cnt_df = panel_df.query(f"ISO_COUNTRY_CODE == 'US' ").groupby(['YEAR', 'MON'], as_index=True)['NUMBER_DEVICES_RESIDING'].sum() / 10**6
print("monthly_device_cnt_df   (million):" )
monthly_device_cnt_df.reset_index()
# Out:
# monthly_device_cnt_df   (million):
#     YEAR  MON  NUMBER_DEVICES_RESIDING
# 0   2019    1                66.145175
# 1   2019    2                62.823365
# 2   2019    3                66.860446
# 3   2019    4                40.499184
# 4   2019    5                41.970806
# ..   ...  ...                      ...
# 56  2023    9                15.949760
# 57  2023   10                14.554956
# 58  2023   11                13.205879
# 59  2023   12                13.545774
# 60  2024    1                14.507716
#
# [61 rows x 3 columns]

# %% [markdown]
# # Download Weekly Patterns Home Panel

# %%
import os
import base64
import requests
import json
import base64 
import tempfile
from urllib.parse import urlparse
from urllib.parse import unquote

import pandas as pd
import numpy as np
from getpass import getpass
from glob import glob
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
import os
import random
import sqlite3 
import numpy as np
import json
import math
from tqdm.notebook import tqdm
from tqdm import tqdm
tqdm.pandas()

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import Advan_operator as ad_op  
from datetime import datetime


pd.set_option('display.max_columns', None)

# access_token = 'ALtAyMZA.Y1sITQvTj6OXSr6XUz31P2ov3XvsdkhpbijDutzY0glCVNohhzM4okEe'
# access_token = 'ALtAyMZA.Y1sITQvTj6OXSr6XUz31P2ov3XvsdkhpbijDutzY0glCVNohhzM4okEe'
access_token = 'zF889gpF.nHzDh8gDQj7tsWDY7OzerICALSX0OvKDe7AM7Vrdu4b5SZRoo0OVr5KC'
import logging
# Create a logger
logger_name = 'all_logger'
logger = logging.getLogger(logger_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")

def combine_monthly_pattern_home_panel_summary(data_dir, extend='.csv.gz'):
    print(os.path.join(data_dir, f"*{extend}"))
    all_files = glob(os.path.join(data_dir, f"*{extend}"))

    df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])

    return df

# %%
# Lenovo
# save_dir = r'D:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  

# Desktop 2018
# save_dir = r'E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  

#  Dell 2019
save_dir = r'K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary'


# Weekly home panel summary
url = r'https://app.deweydata.io/external-api/v3/products/364d4770-9e54-45fc-9298-d669c0dff220/files'

os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# %% [markdown]
# ## Get all downloading URLs

# %%
def get_all_download_urls():
    total_pages = 1
    current_page = 1
    df_list = []
    while current_page <= total_pages:
        results = requests.get(url=PRODUCT_API_PATH,
                                   params={'page': current_page,
                                           'partition_key_after':  '2018-01-01',   # optionally set date value here
                                           'partition_key_before': '2024-12-31', 
                                          }, # optionally set date value here
                                   headers={'X-API-KEY': API_KEY,
                                            'accept': 'application/json'
                                           })
        response_json = results.json()
        # return response_json, response_json
        total_pages = response_json['total_pages']
    
        df = pd.DataFrame(response_json)
        df_list.append(df)
        current_page += 1
            
    response_df = pd.concat(df_list)
    
    
    df_list2 = []
    for idx, row in response_df.iterrows():
        # print(row['download_links'])
        df = pd.DataFrame.from_dict([row['download_links']])
        for col, value in row.items():
            if col != 'download_links':
                df[col] = value
        df_list2.append(df)
        # break
        
    url_df = pd.concat(df_list2)
    # url_df = url_df.sort_values(["partition_key", 'file_name', 'file_size_bytes'])
    return response_df, url_df

current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime("%Y%m%d_%H%M")

response_df, url_df = get_all_download_urls()

url_df.to_csv(os.path.join(save_dir, f'download_urls_{formatted_datetime}.csv'), index=False)
url_df
# Out:
#                                                  link partition_key  \
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2018-01-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2018-02-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2018-03-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2018-04-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2018-05-01
# ..                                                ...           ...
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-11-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2024-01-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2024-02-01
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2024-03-01
#
#                                             file_name file_extension  \
# 0   Weekly_Patterns_Home_Panel_Summary-0-DATE_RANG...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-1-DATE_RANG...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-2-DATE_RANG...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-3-DATE_RANG...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-4-DATE_RANG...        .csv.gz
# ..                                                ...            ...
# 0   Weekly_Patterns_Home_Panel_Summary-70-DATE_RAN...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-71-DATE_RAN...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-72-DATE_RAN...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-73-DATE_RAN...        .csv.gz
# 0   Weekly_Patterns_Home_Panel_Summary-74-DATE_RAN...        .csv.gz
#
#     file_size_bytes               modified_at  page  number_of_files_for_page  \
# 0          11659298  2024-01-19T22:13:47.729Z     1                        75
# 0           9363738  2024-01-19T22:13:47.925Z     1                        75
# 0           9762571  2024-01-19T22:13:47.681Z     1                        75
# 0          12516422  2024-01-19T22:13:47.676Z     1                        75
# 0           9740165  2024-01-19T22:13:47.687Z     1                        75
# ..              ...                       ...   ...                       ...
# 0           7743606  2024-01-19T22:13:47.678Z     1                        75
# 0           7283982  2024-01-19T22:13:47.678Z     1                        75
# 0           9944797  2024-02-14T03:41:48.860Z     1                        75
# 0           7961715  2024-03-13T03:42:04.002Z     1                        75
# 0           1925319  2024-03-20T03:41:42.295Z     1                        75
#
#     avg_file_size_for_page  partition_column  total_files  total_pages  \
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
# ..                     ...               ...          ...          ...
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
# 0                8806818.6  DATE_RANGE_START           75            1
#
#     total_size                expires_at
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
# ..         ...                       ...
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
# 0    660511397  2024-03-23T16:28:12.718Z
#
# [75 rows x 14 columns]

# %%
# response_df

# %%
processed_cnt = 0

def formart_file_name(row, index):
    # remove file number in the middle
    file_name = row['file_name']
    file_extension = row['file_extension']
    hypen_pos_list = [p for p, char in enumerate(file_name) if char == '-']
    hyphen_pos1 = hypen_pos_list[0]
    hyphen_pos2 = hypen_pos_list[1]
    new_fname = file_name[:hyphen_pos1] + file_name[hyphen_pos2:]
    new_fname = new_fname[:-len(file_extension)] + f'_{index:02}' + file_extension
    return new_fname 
    
def formart_file_name_v2(row, index):
    # remove file number in the middle
    short_identifer = row['link'].split("?")[0].split("-")[-1]
    # print(short_identifer)
    file_name = row['file_name']
    file_extension = row['file_extension']
    hypen_pos_list = [p for p, char in enumerate(file_name) if char == '-']
    hyphen_pos1 = hypen_pos_list[0]
    hyphen_pos2 = hypen_pos_list[1]
    new_fname = file_name[:hyphen_pos1] + file_name[hyphen_pos2:]
    # new_fname = new_fname[:-len(file_extension)] + f'_{index:02}' + file_extension
    new_fname = new_fname[:-len(file_extension)] + f'_{short_identifer}' + file_extension
    return new_fname 

processed_cnt = 0
for partition_key, df in url_df.groupby('partition_key'):
   
    df = df.reset_index()
    
    for i, row in df.iterrows():
        try:
            
            # print(partition_key, i + 1)
            # print("Downloading: ", row['link'])
            date = row['partition_key']
            file_extension = row['file_extension']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
    
            # base_name = row['file_name']
            # base_name = row['file_name'][0:24] + row['file_name'][-35:-7] + f"_{i + 1}.csv.gz"
            # base_name = formart_file_name(row, i)
            base_name = formart_file_name_v2(row, i)
            # print("base_name:", base_name)
            
            file_name = os.path.join(file_dir, base_name)
             
            print(f'Downloading file {file_name}')

            processed_cnt += 1
            
            if os.path.exists(file_name):
                print(f"File exists, skip! The file is: {file_name} \n")
                continue
            
        
            # # loop through download links and save to your computer
            data = requests.get(row['link'], stream=True)
            safe_file_write(file_path=file_name, content=data.content)
             
            #  += 1
            
            print(f"    Processed {i + 1} / {len(df)} files for {partition_key}.")
            print(f"Processed {processed_cnt} / {len(url_df)} files in total.")
            # print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
            
            print()
        except Exception as e:
            print("Error:", e)
            continue


print("Done.")
# Out:
# Year, month, day: 2018 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-01-01_0b87016011de_2304_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-01-01_0b87016011de_2304_0_0.csv.gz.csv.gz
#
# Year, month, day: 2018 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-02-01_0b87016011de_104_7_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-02-01_0b87016011de_104_7_0.csv.gz.csv.gz
#
# Year, month, day: 2018 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-03-01_0b87016011de_704_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-03-01_0b87016011de_704_3_0.csv.gz.csv.gz
#
# Year, month, day: 2018 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-04-01_0b87016011de_004_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-04-01_0b87016011de_004_3_0.csv.gz.csv.gz
#
# Year, month, day: 2018 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-05-01_0b87016011de_404_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-05-01_0b87016011de_404_0_0.csv.gz.csv.gz
#
# Year, month, day: 2018 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-06-01_0b87016011de_504_4_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-06-01_0b87016011de_504_4_0.csv.gz.csv.gz
#
# Year, month, day: 2018 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-07-01_0b87016011de_1204_7_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-07-01_0b87016011de_1204_7_0.csv.gz.csv.gz
#
# Year, month, day: 2018 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-08-01_0b87016011de_804_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-08-01_0b87016011de_804_3_0.csv.gz.csv.gz
#
# Year, month, day: 2018 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-09-01_0b87016011de_2004_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-09-01_0b87016011de_2004_2_0.csv.gz.csv.gz
#
# Year, month, day: 2018 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-10-01_0b87016011de_1704_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-10-01_0b87016011de_1704_2_0.csv.gz.csv.gz
#
# Year, month, day: 2018 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-11-01_0b87016011de_2304_7_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-11-01_0b87016011de_2304_7_0.csv.gz.csv.gz
#
# Year, month, day: 2018 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-12-01_0b87016011de_2004_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2018\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2018-12-01_0b87016011de_2004_3_0.csv.gz.csv.gz
#
# Year, month, day: 2019 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-01-01_0b87016011de_1004_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-01-01_0b87016011de_1004_3_0.csv.gz.csv.gz
#
# Year, month, day: 2019 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-02-01_0b87016011de_504_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-02-01_0b87016011de_504_0_0.csv.gz.csv.gz
#
# Year, month, day: 2019 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-03-01_0b87016011de_2004_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-03-01_0b87016011de_2004_6_0.csv.gz.csv.gz
#
# Year, month, day: 2019 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-04-01_0b87016011de_1004_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-04-01_0b87016011de_1004_5_0.csv.gz.csv.gz
#
# Year, month, day: 2019 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-05-01_0b87016011de_3004_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-05-01_0b87016011de_3004_2_0.csv.gz.csv.gz
#
# Year, month, day: 2019 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-06-01_0b87016011de_1304_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-06-01_0b87016011de_1304_1_0.csv.gz.csv.gz
#
# Year, month, day: 2019 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-07-01_0b87016011de_204_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-07-01_0b87016011de_204_0_0.csv.gz.csv.gz
#
# Year, month, day: 2019 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-08-01_0b87016011de_2404_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-08-01_0b87016011de_2404_6_0.csv.gz.csv.gz
#
# Year, month, day: 2019 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-09-01_0b87016011de_1304_4_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-09-01_0b87016011de_1304_4_0.csv.gz.csv.gz
#
# Year, month, day: 2019 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-10-01_0b87016011de_1204_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-10-01_0b87016011de_1204_1_0.csv.gz.csv.gz
#
# Year, month, day: 2019 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-11-01_0b87016011de_2504_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-11-01_0b87016011de_2504_2_0.csv.gz.csv.gz
#
# Year, month, day: 2019 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-12-01_0b87016011de_1204_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2019\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2019-12-01_0b87016011de_1204_0_0.csv.gz.csv.gz
#
# Year, month, day: 2020 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-01-01_0b87016011de_604_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-01-01_0b87016011de_604_2_0.csv.gz.csv.gz
#
# Year, month, day: 2020 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-02-01_0b87016011de_004_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-02-01_0b87016011de_004_0_0.csv.gz.csv.gz
#
# Year, month, day: 2020 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-03-01_0b87016011de_2604_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-03-01_0b87016011de_2604_3_0.csv.gz.csv.gz
#
# Year, month, day: 2020 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-04-01_0b87016011de_604_7_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-04-01_0b87016011de_604_7_0.csv.gz.csv.gz
#
# Year, month, day: 2020 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-05-01_0b87016011de_704_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-05-01_0b87016011de_704_2_0.csv.gz.csv.gz
#
# Year, month, day: 2020 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-06-01_0b87016011de_2004_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-06-01_0b87016011de_2004_1_0.csv.gz.csv.gz
#
# Year, month, day: 2020 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-07-01_0b87016011de_2204_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-07-01_0b87016011de_2204_1_0.csv.gz.csv.gz
#
# Year, month, day: 2020 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-08-01_0b87016011de_404_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-08-01_0b87016011de_404_2_0.csv.gz.csv.gz
#
# Year, month, day: 2020 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-09-01_0b87016011de_1104_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-09-01_0b87016011de_1104_1_0.csv.gz.csv.gz
#
# Year, month, day: 2020 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-10-01_0b87016011de_004_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-10-01_0b87016011de_004_6_0.csv.gz.csv.gz
#
# Year, month, day: 2020 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-11-01_0b87016011de_204_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-11-01_0b87016011de_204_6_0.csv.gz.csv.gz
#
# Year, month, day: 2020 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-12-01_0b87016011de_804_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2020\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2020-12-01_0b87016011de_804_5_0.csv.gz.csv.gz
#
# Year, month, day: 2021 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-01-01_0b87016011de_2004_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-01-01_0b87016011de_2004_6_0.csv.gz.csv.gz
#
# Year, month, day: 2021 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-02-01_0b87016011de_3104_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-02-01_0b87016011de_3104_5_0.csv.gz.csv.gz
#
# Year, month, day: 2021 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-03-01_0b87016011de_304_7_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-03-01_0b87016011de_304_7_0.csv.gz.csv.gz
#
# Year, month, day: 2021 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-04-01_0b87016011de_404_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-04-01_0b87016011de_404_1_0.csv.gz.csv.gz
#
# Year, month, day: 2021 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-05-01_0b87016011de_2304_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-05-01_0b87016011de_2304_3_0.csv.gz.csv.gz
#
# Year, month, day: 2021 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-06-01_0b87016011de_3004_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-06-01_0b87016011de_3004_3_0.csv.gz.csv.gz
#
# Year, month, day: 2021 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-07-01_0b87016011de_204_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-07-01_0b87016011de_204_3_0.csv.gz.csv.gz
#
# Year, month, day: 2021 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-08-01_0b87016011de_1804_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-08-01_0b87016011de_1804_2_0.csv.gz.csv.gz
#
# Year, month, day: 2021 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-09-01_0b87016011de_1704_4_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-09-01_0b87016011de_1704_4_0.csv.gz.csv.gz
#
# Year, month, day: 2021 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-10-01_0b87016011de_1704_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-10-01_0b87016011de_1704_5_0.csv.gz.csv.gz
#
# Year, month, day: 2021 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-11-01_0b87016011de_304_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-11-01_0b87016011de_304_2_0.csv.gz.csv.gz
#
# Year, month, day: 2021 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-12-01_0b87016011de_3104_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2021\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2021-12-01_0b87016011de_3104_5_0.csv.gz.csv.gz
#
# Year, month, day: 2022 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-01-01_0b87016011de_3104_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-01-01_0b87016011de_3104_0_0.csv.gz.csv.gz
#
# Year, month, day: 2022 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-02-01_0b87016011de_3104_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-02-01_0b87016011de_3104_2_0.csv.gz.csv.gz
#
# Year, month, day: 2022 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-03-01_0b87016011de_2304_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-03-01_0b87016011de_2304_6_0.csv.gz.csv.gz
#
# Year, month, day: 2022 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-04-01_0b87016011de_1704_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-04-01_0b87016011de_1704_2_0.csv.gz.csv.gz
#
# Year, month, day: 2022 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-05-01_0b87016011de_2004_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-05-01_0b87016011de_2004_5_0.csv.gz.csv.gz
#
# Year, month, day: 2022 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-06-01_0b87016011de_1104_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-06-01_0b87016011de_1104_6_0.csv.gz.csv.gz
#
# Year, month, day: 2022 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-07-01_0b87016011de_904_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-07-01_0b87016011de_904_1_0.csv.gz.csv.gz
#
# Year, month, day: 2022 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-08-01_0b87016011de_1504_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-08-01_0b87016011de_1504_0_0.csv.gz.csv.gz
#
# Year, month, day: 2022 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-09-01_0b87016011de_2604_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-09-01_0b87016011de_2604_2_0.csv.gz.csv.gz
#
# Year, month, day: 2022 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-10-01_0b87016011de_2904_2_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-10-01_0b87016011de_2904_2_0.csv.gz.csv.gz
#
# Year, month, day: 2022 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-11-01_0b87016011de_1204_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-11-01_0b87016011de_1204_6_0.csv.gz.csv.gz
#
# Year, month, day: 2022 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-12-01_0b87016011de_2804_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2022\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2022-12-01_0b87016011de_2804_1_0.csv.gz.csv.gz
#
# Year, month, day: 2023 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-01-01_0b87016011de_2304_4_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-01-01_0b87016011de_2304_4_0.csv.gz.csv.gz
#
# Year, month, day: 2023 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-02-01_0b87016011de_2804_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-02-01_0b87016011de_2804_3_0.csv.gz.csv.gz
#
# Year, month, day: 2023 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-03-01_0b87016011de_1504_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-03-01_0b87016011de_1504_5_0.csv.gz.csv.gz
#
# Year, month, day: 2023 04 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-04-01_0b87016011de_2304_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\04\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-04-01_0b87016011de_2304_5_0.csv.gz.csv.gz
#
# Year, month, day: 2023 05 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-05-01_0b87016011de_104_7_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\05\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-05-01_0b87016011de_104_7_0.csv.gz.csv.gz
#
# Year, month, day: 2023 06 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-06-01_0b87016011de_2104_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\06\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-06-01_0b87016011de_2104_1_0.csv.gz.csv.gz
#
# Year, month, day: 2023 07 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-07-01_0b87016011de_1004_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\07\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-07-01_0b87016011de_1004_3_0.csv.gz.csv.gz
#
# Year, month, day: 2023 08 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-08-01_0b87016011de_404_5_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\08\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-08-01_0b87016011de_404_5_0.csv.gz.csv.gz
#
# Year, month, day: 2023 09 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-09-01_0b87016011de_2104_3_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\09\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-09-01_0b87016011de_2104_3_0.csv.gz.csv.gz
#
# Year, month, day: 2023 10 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-10-01_0b87016011de_604_0_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\10\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-10-01_0b87016011de_604_0_0.csv.gz.csv.gz
#
# Year, month, day: 2023 11 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-11-01_0b87016011de_2204_6_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\11\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-11-01_0b87016011de_2204_6_0.csv.gz.csv.gz
#
# Year, month, day: 2023 12 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-12-01_0b87016011de_2804_7_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2023\12\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2023-12-01_0b87016011de_2804_7_0.csv.gz.csv.gz
#
# Year, month, day: 2024 01 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2024\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2024-01-01_0b8701798076_104_1_0.csv.gz.csv.gz
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2024\01\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2024-01-01_0b8701798076_104_1_0.csv.gz.csv.gz
#
# Year, month, day: 2024 02 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2024\02\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2024-02-01_0b87019b71be_004_6_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2024-02-01.
# Processed 74 / 75 files in total.
#
# Year, month, day: 2024 03 01
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_home_panel_summary\2024\03\01\Weekly_Patterns_Home_Panel_Summary-DATE_RANGE_START-2024-03-01_0b8701a26dca_104_2_0.csv.gz.csv.gz
# File successfully written.
#     Processed 1 / 1 files for 2024-03-01.
# Processed 75 / 75 files in total.
#
# Done.

# %% [markdown]
# # Download Weekly Patterns visit Panel

# %%
import os
import base64
import requests
import json
import base64 
import tempfile
from urllib.parse import urlparse
from urllib.parse import unquote

import pandas as pd
import numpy as np
from getpass import getpass
from glob import glob
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
import os
import random
import sqlite3 
import numpy as np
import json
import math
from tqdm.notebook import tqdm
from tqdm import tqdm
tqdm.pandas()

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import Advan_operator as ad_op  
from datetime import datetime


pd.set_option('display.max_columns', None)

# access_token = 'ALtAyMZA.Y1sITQvTj6OXSr6XUz31P2ov3XvsdkhpbijDutzY0glCVNohhzM4okEe'
access_token = 'zF889gpF.nHzDh8gDQj7tsWDY7OzerICALSX0OvKDe7AM7Vrdu4b5SZRoo0OVr5KC'


import logging
# Create a logger
logger_name = 'all_logger'
logger = logging.getLogger(logger_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")

def combine_monthly_pattern_home_panel_summary(data_dir, extend='.csv.gz'):
    print(os.path.join(data_dir, f"*{extend}"))
    all_files = glob(os.path.join(data_dir, f"*{extend}"))

    df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])

    return df

# %%
# Lenovo
# save_dir = r'D:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  

# Desktop 2018
# save_dir = r'E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  

#  Dell 2019
save_dir = r'K:\SafeGraph\Advan_2024_API\Weekly_Patterns_visit_panel_summary'


# Weekly home panel summary
# url = r'https://app.deweydata.io/external-api/v3/products/364d4770-9e54-45fc-9298-d669c0dff220/files'

# Weekly visit Panel summary
url = r'https://app.deweydata.io/external-api/v3/products/4f70f3ce-dd55-4041-8e9b-6b39130cfae9/files'

os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# %%
def get_all_download_urls():
    total_pages = 1
    current_page = 1
    df_list = []
    while current_page <= total_pages:
        results = requests.get(url=PRODUCT_API_PATH,
                                   params={'page': current_page,
                                           # 'partition_key_after':  '2018-01-01',   # optionally set date value here
                                           # 'partition_key_before': '2024-12-31', 
                                          }, # optionally set date value here
                                   headers={'X-API-KEY': API_KEY,
                                            'accept': 'application/json'
                                           })

        
        response_json = results.json()

        # return response_json, response_json
        total_pages = response_json['total_pages']
    
        df = pd.DataFrame(response_json)
        df_list.append(df)
        current_page += 1

    
            
    response_df = pd.concat(df_list)
    
    
    df_list2 = []
    for idx, row in response_df.iterrows():
        # print(row['download_links'])
        df = pd.DataFrame.from_dict([row['download_links']])
        for col, value in row.items():
            if col != 'download_links':
                df[col] = value
        df_list2.append(df)
        # break
        
    url_df = pd.concat(df_list2)
    # url_df = url_df.sort_values(["partition_key", 'file_name', 'file_size_bytes'])
    return response_df, url_df

current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime("%Y%m%d_%H%M")

response_df, url_df = get_all_download_urls()
url_df['partition_key'] = url_df['modified_at'].str[:10]
url_df.to_csv(os.path.join(save_dir, f'download_urls_{formatted_datetime}.csv'), index=False)
url_df
# Out:
#                                                 link partition_key  \
# 0  https://s3.us-east-005.backblazeb2.com/amplify...    2024-03-20
#
#                                    file_name file_extension  file_size_bytes  \
# 0  Weekly_Patterns_Visit_Panel_Summary-0.csv           .csv           762132
#
#                 modified_at  page  number_of_files_for_page  \
# 0  2024-03-20T03:41:36.934Z     1                         1
#
#    avg_file_size_for_page partition_column  total_files  total_pages  \
# 0                762132.0             None            1            1
#
#    total_size                expires_at
# 0      762132  2024-03-23T16:20:49.691Z

# %%
processed_cnt = 0

def formart_file_name(row, index):
    # remove file number in the middle
    file_name = row['file_name']
    file_extension = row['file_extension']
    
    hypen_pos_list = [p for p, char in enumerate(file_name) if char == '-']
    
    hyphen_pos1 = hypen_pos_list[0]
    hyphen_pos2 = hypen_pos_list[1]
    new_fname = file_name[:hyphen_pos1] + file_name[hyphen_pos2:]
    new_fname = new_fname[:-len(file_extension)] + f'_{index:02}' + file_extension
    return new_fname 
    
def formart_file_name_v2(row, index):
    # remove file number in the middle
    short_identifer = row['link'].split("?")[0].split("Weekly_Patterns_Visit_Panel_Summary")[-1]
    print(short_identifer)
    file_name = row['file_name']
    file_extension = row['file_extension']
    # print('file_name:', file_name)
    hypen_pos_list = [p for p, char in enumerate(file_name) if char == '-']
    
    hyphen_pos1 = hypen_pos_list[0]
    print('hypen_pos_list:', hypen_pos_list)
    try:
        hyphen_pos2 = hypen_pos_list[1]
    except:
        hyphen_pos2 = -1 - len(file_extension) - 1
    # print('file_name:', file_name)
    # print('row:', row)
    new_fname = file_name[:hyphen_pos1] + file_name[hyphen_pos2:]
    print('new_fname:', new_fname)
    # new_fname = new_fname[:-len(file_extension)] + f'_{index:02}' + file_extension
    new_fname = new_fname[:-len(file_extension)] + f'_{short_identifer}' + file_extension
    
    return new_fname 

processed_cnt = 0
for partition_key, df in url_df.groupby('partition_key'):
   
    df = df.reset_index()
    
    for i, row in df.iterrows():
        try:
            # print('row:', row)
            # print(partition_key, i + 1)
            # print("Downloading: ", row['link'])
            date = row['partition_key']
            file_extension = row['file_extension']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
    
            # base_name = row['file_name']
            # base_name = row['file_name'][0:24] + row['file_name'][-35:-7] + f"_{i + 1}.csv.gz"
            # base_name = formart_file_name(row, i)
            base_name = formart_file_name_v2(row, i)
            print("base_name:", base_name)
            
            file_name = os.path.join(file_dir, base_name)
             
            print(f'Downloading file {file_name}')

            processed_cnt += 1
            
            if os.path.exists(file_name):
                print(f"File exists, skip! The file is: {file_name} \n")
                continue
            
        
            # # loop through download links and save to your computer
            data = requests.get(row['link'], stream=True)
            safe_file_write(file_path=file_name, content=data.content)
              
            
            print(f"    Processed {i + 1} / {len(df)} files for {partition_key}.")
            print(f"Processed {processed_cnt} / {len(url_df)} files in total.")
            # print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
            
            print()
        except Exception as e:
            print("Error:", e)
            continue


print("Done.")
# Out:
# Year, month, day: 2024 03 20
# .csv
# hypen_pos_list: [35]
# new_fname: Weekly_Patterns_Visit_Panel_Summary-0.csv
# base_name: Weekly_Patterns_Visit_Panel_Summary-0_.csv.csv
# Downloading file K:\SafeGraph\Advan_2024_API\Weekly_Patterns_visit_panel_summary\2024\03\20\Weekly_Patterns_Visit_Panel_Summary-0_.csv.csv
# File exists, skip! The file is: K:\SafeGraph\Advan_2024_API\Weekly_Patterns_visit_panel_summary\2024\03\20\Weekly_Patterns_Visit_Panel_Summary-0_.csv.csv
#
# Done.

# %% [markdown]
# # Stop

# %%
Stop

# %% [markdown]
# # Not used below

# %%
import pandas as pd
import numpy as np
import json
import base64
import requests
# from posixpath import basename
import os
import requests
import time
import tempfile

def get_access_token(account="hning@email.sc.edu", password="Nhwwdewey2022,", verbose=True):
    # un =  # Set username
    # pw = # Set password

    credentials = f"{account}:{password}" # Format credentials according to the API's expectations
    # print(credentials)

    credentials_bytes = credentials.encode('ascii')
    base64_credentials_bytes = base64.b64encode(credentials_bytes)
    base64_credentials = base64_credentials_bytes.decode('ascii')
    # print(base64_credentials)


    headers = {
        'accept': 'application/json',
        'Authorization': f'Basic {base64_credentials}'
    }

    response = requests.post("https://marketplace.deweydata.io/api/auth/tks/get_token", headers=headers)
    
    access_token = response.json()['access_token']
    
    if verbose:
        print(response.json())
        print(access_token)
    
    return access_token

def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")
            
            
# Main function
def download_all_files(save_dir, headers, override=False):
 
    init_url = r'/api/data/v2/list'
    home_url = 'https://marketplace.deweydata.io'    
    web_dir_list = [init_url]
    
    print("Started...")
    
    skipped_cnt = 0
    while len(web_dir_list) > 0:
        try:
            # web_dir = web_dir_list.pop()
            # print("web_dir_list:", web_dir_list)
            web_dir = web_dir_list.pop()   # Get the latest file
            
            
            url = home_url + web_dir
            # print(url, web_dir)
            items = requests.get(url, headers=headers).json()
            # print(requests.get(url, headers=headers).url)
            
            items = items[::-1]  # Put the latest file in the end.
 

            for item in items:
                name = item['name']
                if item['directory']:  
                    
                    # skip data
                    # if r'/2021/' not in url:
                    #     # print("Skipped:", url)
                    #     skipped_cnt += 1
                    #     if skipped_cnt % 10 == 0:
                    #         print("skipped un-targeted files:", skipped_cnt)
                    #     continue
                    
                    web_dir = item['url']
                    
                    full_web_dir = home_url + web_dir

                    local_dir = item['parent'].replace(init_url, '').replace(r'/', '\\')[1:] # for windows  
                                        

                    web_dir_list.append(web_dir)
                    print(f"Waiting directories (count: {len(web_dir_list)}):\n", web_dir_list[0], '...', web_dir_list[-1])
                    
                    
                    new_folder = os.path.join(save_dir, local_dir)
                    # os.makedirs(new_folder, exist_ok=True)
                    
                    if not os.path.exists(new_folder):
                         os.makedirs(new_folder, exist_ok=True)    
                    # new_folder = os.path.join(save_dir, save_dir_name)    
                    # os.makedirs(new_folder, exist_ok=True)

                    # print(f'Creaet a folder {new_folder} for web directory: {full_web_dir}')
 
                else:
                    
                    basename = item['name']     
                    # if not 'spend' in basename:
                    #     continue
                    url = home_url + item['url']
                    
                    # skip data
                    # if r'/ADVAN/' not in url:
                    #     # print("Skipped:", url)
                    #     skipped_cnt += 1
                    #     if skipped_cnt % 10 == 0:
                    #         print("skipped un-targeted files:", skipped_cnt)
                    #     continue
                    
                    full_web_dir = home_url + web_dir
                    local_dir = item['parent'].replace(init_url, '').replace(r'/', os.sep)[1:] # for windows  
                    # print("save_dir, local_dir", save_dir, local_dir, os.path.join(save_dir, local_dir))
                    new_folder = os.path.join(save_dir, local_dir)
                    # os.makedirs(new_folder, exist_ok=True)
                    
                    if not os.path.exists(new_folder):
                         os.makedirs(new_folder, exist_ok=True)
                    
                    filename = os.path.join(new_folder, basename).replace(r'/', os.sep)  # for windows
                    # print("new_folder, local_dir, filename, new_folder:", new_folder, local_dir, filename, new_folder)
                    
                    # whether skip existing files:
                    if not override:
                        if os.path.exists(filename):
                            # print("File exists, skipped:", filename)
                            skipped_cnt += 1
                            if skipped_cnt % 50 == 0:
                                print("skipped un-targeted files:", skipped_cnt)
                                print("File exists, skipped:", filename)
                            continue
                            continue
                    
                    new_folder = os.path.dirname(filename)    
                    os.makedirs(new_folder, exist_ok=True)
                    
                    print(f"Downloading: {url}")
                    
#                     with open(filename, 'wb') as f:
                        
#                         r = requests.get(url, stream=True, headers=headers)
#                         f.write(r.content)
                    r = requests.get(url, stream=True, headers=headers)
                    safe_file_write(file_path=filename, content=r.content)
        
                    # with requests.get(url, stream=True, headers=headers) as r:
                    #     # r.raise_for_status()
                    #     with open(filename, 'wb') as f:
                    #         for chunk in r.iter_content(chunk_size=8192):
                    #             if chunk:
                    #                 f.write(chunk)
                    
                    print(f"Saved at  : {filename}")
                    
                    
        except Exception as e:
            print(url, e)
            print("sleeping 5 seconds...")
            time.sleep(5)
            
            access_token = get_access_token()
            headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
              }
            download_all_files(save_dir=save_dir, headers=headers)
            
            continue
            
    print("Done")

# Example usage
# access_token = r'v8-YZaYSs3t9CYkKnYywgfQ8zIs'


access_token = get_access_token()

headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
          }

save_dir = r'G:\SafeGraph_monthly_patterns_2018-2022'

download_all_files(save_dir=save_dir, headers=headers)

# %% [markdown]
# # Stop

# %%
! echo -n "hning@email.sc.edu:Nhww1898," | openssl base64

# %%
! curl -X 'POST' 'https://marketplace.deweydata.io/api/auth/tks/get_token' -H 'accept: application/json' -H 'Authorization: Basic LW4gImhuaW5nQGVtYWlsLnNjLmVkdTpOaHd3MTg5OCwiIA0K'

# %%
! curl -X GET "https://marketplace.deweydata.io/api/data/v2/list" -H "accept: application/json" -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA"

# %%
access_token = r'0c3RBibybyGBMfXjOuCjO8qtxDA'
# ! path = r'api/data/v2/list/2022'
# ! curl -H 'Accept: application/json' -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA" -X GET 'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_home_panel_0' -o test11.csv

# %%
import requests

def get_all_files():
    headers = {
            'Accept': 'application/json',
            'Authorization': 'Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA'
            }
    res = requests.get(
                        'https://marketplace.deweydata.io/api/data/v2/list',                     
                    headers=headers)  
    
    print(res.url)
    return res.json()

dirs = get_all_files()
dirs
# open('visit_panel_summary2.csv', 'wb').write(res.content)
url = r'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_cpgp_part8_0'
res = requests.get(
                    url,                     
                    headers=headers)  
open('visit_panel_summary2.csv', 'wb').write(res.content)

# %%
import requests
import re

def get_filename_from_cd(cd):
    """
    Get filename from content-disposition
    """
    if not cd:
        return None
    fname = re.findall('filename=(.+)', cd)
    print(fname)
    if len(fname) == 0:
        return None
    return fname[0]


url = r'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_cpgp_part8_0'

# url = 'http://google.com/favicon.ico'
r = requests.get(url, allow_redirects=True)
filename = get_filename_from_cd(r.headers.get('content-disposition'))
open(filename, 'wb').write(r.content)

# %%
# from posixpath import basename
import os
import requests
import time

# Main function
def download_all_files(save_dir, headers):
 
    init_url = r'/api/data/v2/list'
    home_url = 'https://marketplace.deweydata.io'    
    web_dir_list = [init_url]
    
    while len(web_dir_list) > 0:
        try:
            web_dir = web_dir_list.pop()
            
            
            url = home_url + web_dir
            # print(url, web_dir)
            items = requests.get(url, headers=headers).json()
            
            items = items[::-1]
            

            for item in items:
                name = item['name']
                if item['directory']:  
                    
                    web_dir = item['url']
                    
                    full_web_dir = home_url + web_dir

                    save_dir_name = full_web_dir.replace(home_url + init_url + '/', "").replace(r'/', '\\')  # for windows

                    new_folder = os.path.join(save_dir, save_dir_name)    
                    os.makedirs(new_folder, exist_ok=True)

                    web_dir_list.append(web_dir)    

                    print(f'Creaet a folder {new_folder} for web directory: {full_web_dir}')
 
                else:
                    
                    basename = item['name']     
                    # if not 'spend' in basename:
                    #     continue
                    url = home_url + item['url']
                    full_web_dir = home_url + web_dir
                    local_dir = item['parent'].replace(init_url, '').replace(r'/', '\\')[1:] # for windows  
                    # print("save_dir, local_dir", save_dir, local_dir, os.path.join(save_dir, local_dir))
                    new_folder = os.path.join(save_dir, local_dir)
                    os.makedirs(new_folder, exist_ok=True)
                    
                    filename = os.path.join(new_folder, basename).replace(r'/', '\\')  # for windows
                    # print("new_folder, local_dir, filename, new_folder:", new_folder, local_dir, filename, new_folder)
                    with requests.get(url, stream=True, headers=headers) as r:
                        # r.raise_for_status()
                        with open(filename, 'wb') as f:
                            for chunk in r.iter_content(chunk_size=8192):
                                if chunk:
                                    f.write(chunk)
                    print(f"Downloaded: {url}")
                    print(f"Saved at  : {filename}")
                    
                    
        except Exception as e:
            print(url, e)
            print("sleeping 6 seconds...")
            time.sleep(6)
            
            continue

# Example usage
access_token = r'v8-YZaYSs3t9CYkKnYywgfQ8zIs'
headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
          }

save_dir = r'L:\SafeGraph_monthly_patterns_2018-2022'

download_all_files(save_dir=save_dir, headers=headers)

# %% [markdown]
# # Stop

# %%
# from posixpath import basename
import os
import requests

# Function to download a file
def download_file(home_url, item, save_folder, headers):

    basename = item['name']
    
    
    
    url = home_url + item['url']
    new_folder = os.path.join(save_folder, url.replace(home_url + '/', ''))
    os.makedirs(new_folder, exist_ok=True)
    
    filename = os.path.join(new_folder, basename)
    
    with requests.get(url, stream=True, headers=headers) as r:
        # r.raise_for_status()
        with open(filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
    print(f"Downloaded: {url}")
    print(f"Saved at  : {filename}")

# Function to download a directory recursively
def download_directory(directory, save_folder, headers):
    home_url = 'https://marketplace.deweydata.io'
    # print("directory: ", directory)
    url = home_url + directory
    # print("url:", url)
    items = requests.get(url, headers=headers).json()
    
    # print("headers:", headers)
    # print(url, items)

    for item in items:
        name = item['name']
        # print(item)
        # item_path = 
        
        if item['directory']:
            save_dir = os.path.join(save_folder, name)
            # directory = home_url + 
            directory = item['url']
            # print("directory: ", directory)
            new_folder = os.path.join(save_folder, directory.replace(home_url, ''))
            
            os.makedirs(new_folder, exist_ok=True)
            download_directory(directory, save_folder, headers=headers)
        else:
            download_file(home_url, item, save_folder, headers=headers)

# Main function
def download_all_files(save_folder):
    headers = {
        'accept': 'application/json',
        'Authorization': 'Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA'
    }


    download_directory(directory='/api/data/v2/list', save_folder=save_folder, headers=headers)


# Example usage
save_dir = r'L:\SafeGraph_monthly_patterns_2018-2022'
download_all_files(save_dir)

# %%
# files = res.json()

type(files)
files[0]

# %%
curl -H "Accept: application/json" -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA" -X GET "/api/data/v2/list/2022/12/01/SAFEGRAPH/MP/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_home_panel_0" -o test42.csv

# %% [markdown]
# # Merge panel CSV files

# %%
import os
import pandas as pd

# %%
data_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23'


def get_all_files(data_dir, exts=['.csv'], verbose=True):
    all_files = []
    for root_dir, folders, files in os.walk(data_dir):
        
        for f in files:
            for ext in exts:
                ext_len = len(ext)
                if ext == f[-ext_len:]:
                    full_name = os.path.join(root_dir, f)
                    all_files.append(full_name)
    if verbose:
        print("Found files:", len(all_files))
    return sorted(all_files)


all_files = get_all_files(data_dir, exts=['.csv.gz'])

# %%
merged_panel_df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])
merged_panel_df = merged_panel_df.sort_values(['YEAR', 'MON', 'CENSUS_BLOCK_GROUP'])  
merged_panel_df

# %%
monthly_device_cnt_df = merged_panel_df.query(f"ISO_COUNTRY_CODE == 'US' ").groupby(['YEAR', 'MON'], as_index=True)['NUMBER_DEVICES_RESIDING'].sum() / 10**6
print("monthly_device_cnt_df   (million):" )
monthly_device_cnt_df = monthly_device_cnt_df.reset_index()
monthly_device_cnt_df['year_month'] = monthly_device_cnt_df['YEAR'].astype(str)  + monthly_device_cnt_df['MON'].astype(str).str.zfill(2)
monthly_device_cnt_df['year_month'] = pd.to_datetime(monthly_device_cnt_df['year_month'], format='%Y%m')
monthly_device_cnt_df = monthly_device_cnt_df.set_index('year_month')
monthly_device_cnt_df

# %%
monthly_device_cnt_df.drop(columns=['YEAR', 'MON']).iloc[48:, :]

# %%
monthly_device_cnt_df['NUMBER_DEVICES_RESIDING'].plot()

# %% [markdown]
# # Help topic in Deweydata community
#
# https://community.deweydata.io/t/residing-device-count-in-2023-07-and-2023-08-surged-abnomorally/26675

# %%
merged_panel_df.query(f"ISO_COUNTRY_CODE == 'US' and YEAR == 2023 and MON ==7 ")
