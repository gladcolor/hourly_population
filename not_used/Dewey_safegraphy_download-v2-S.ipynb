# %% [markdown]
# # Download

# %%
import os
import base64
import requests
import json
import base64 
import tempfile
from urllib.parse import urlparse
from urllib.parse import unquote

import pandas as pd
import numpy as np
from getpass import getpass
from glob import glob
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
import os
import random
import sqlite3 
import numpy as np
import json
import math
from tqdm.notebook import tqdm
from tqdm import tqdm
tqdm.pandas()

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import Advan_operator as ad_op  
from datetime import datetime


pd.set_option('display.max_columns', None)

access_token = 'ALtAyMZA.Y1sITQvTj6OXSr6XUz31P2ov3XvsdkhpbijDutzY0glCVNohhzM4okEe'

import logging
# Create a logger
logger_name = 'all_logger'
logger = logging.getLogger(logger_name)

# %% [markdown]
# # Neighborhood patterns

# %% [markdown]
# ## helper function

# %%
def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")

def combine_monthly_pattern_home_panel_summary(data_dir, extend='.csv.gz'):
    print(os.path.join(data_dir, f"*{extend}"))
    all_files = glob(os.path.join(data_dir, f"*{extend}"))

    df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])

    return df
    
    # print(all_files)

# Merge CSV files
# home_panel_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'
# home_panel_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23'
# df = combine_monthly_pattern_home_panel_summary(data_dir=home_panel_dir)
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)
# df

# %%
# neighborhood patterns:
# url = r'https://app.deweydata.io/external-api/v3/products/2dfcb598-6e30-49f1-bdba-1deae113a951/files'
# save_dir = r'K:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'   # Dell 2019
# save_dir = r'F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'  # Lenova 2018

# Lenovo
# save_dir = r'D:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  

# Desktop 2018
save_dir = r'E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns'  


# monthly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/5acc9f39-1ca6-4535-b3ff-38f6b9baf85e/files"
# save_dir = r'K:\SafeGraph\Advan_2024_API\Monthly_Patterns'

# # weekly patterns:
url = r"https://app.deweydata.io/external-api/v3/products/176f0262-c1f6-4dbe-be43-6a6eb21bcf8a/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Weekly_Patterns'
# save_dir = r'D:\SafeGraph\Advan_2024_API\Weekly_Patterns'    # Lenova 2018

# # hourly weather:
# url = r"https://app.deweydata.io/external-api/v3/products/a6be0385-8820-4943-a509-6eac4154b4f6/files"

# monthly home panel summary
# url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
# save_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'


os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# %%
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)

# %%
# df.sort_values(['YEAR', 'MON'])

# %%
def get_all_download_urls():
    total_pages = 1
    current_page = 0
    df_list = []
    while current_page < total_pages:
        results = requests.get(url=PRODUCT_API_PATH,
                                   params={'page': total_pages,
                                           'partition_key_after':  '2018-01-01',   # optionally set date value here
                                           'partition_key_before': '2024-07-31', 
                                          }, # optionally set date value here
                                   headers={'X-API-KEY': API_KEY,
                                            'accept': 'application/json'
                                           })
        response_json = results.json()
        total_pages = response_json['total_pages']
    
        df = pd.DataFrame(response_json)
        df_list.append(df)
        current_page += 1
            
    response_df = pd.concat(df_list)
    
    
    df_list2 = []
    for idx, row in response_df.iterrows():
        # print(row['download_links'])
        df = pd.DataFrame.from_dict([row['download_links']])
        df_list2.append(df)
        # break
        
    url_df = pd.concat(df_list2)
    # url_df = url_df.sort_values(["partition_key", 'file_name', 'file_size_bytes'])
    return response_df, url_df

current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime("%Y%m%d_%H%M")

response_df, url_df = get_all_download_urls()

url_df.to_csv(os.path.join(save_dir, f'download_urls_{formatted_datetime}.csv'), index=False)
url_df
# Out:
#                                                  link partition_key  \
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2019-01-07
# ..                                                ...           ...
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
# 0   https://s3.us-east-005.backblazeb2.com/amplify...    2023-12-18
#
#                                             file_name file_extension  \
# 0   Weekly_Patterns_Foot_Traffic-0-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-1-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-2-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-3-DATE_RANGE_STAR...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-4-DATE_RANGE_STAR...        .csv.gz
# ..                                                ...            ...
# 0   Weekly_Patterns_Foot_Traffic-326-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-327-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-328-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-329-DATE_RANGE_ST...        .csv.gz
# 0   Weekly_Patterns_Foot_Traffic-330-DATE_RANGE_ST...        .csv.gz
#
#     file_size_bytes               modified_at
# 0         209760374  2023-12-07T23:48:41.183Z
# 0         209747233  2023-12-08T00:08:54.090Z
# 0         209735990  2023-12-08T00:09:59.509Z
# 0         209768862  2023-12-08T00:11:25.218Z
# 0         209763824  2023-12-08T00:12:41.071Z
# ..              ...                       ...
# 0         209730608  2024-01-03T05:08:47.403Z
# 0         209757477  2024-01-03T05:09:05.855Z
# 0         209750096  2024-01-03T05:09:24.274Z
# 0         209723254  2024-01-03T05:09:42.676Z
# 0         209734444  2024-01-03T05:10:00.875Z
#
# [6789 rows x 6 columns]

# %%
processed_cnt = 0

def formart_file_name(row, index):
    # remove file number in the middle
    file_name = row['file_name']
    file_extension = row['file_extension']
    hypen_pos_list = [p for p, char in enumerate(file_name) if char == '-']
    hyphen_pos1 = hypen_pos_list[0]
    hyphen_pos2 = hypen_pos_list[1]
    new_fname = file_name[:hyphen_pos1] + file_name[hyphen_pos2:]
    new_fname = new_fname[:-len(file_extension)] + f'_{index:02}' + file_extension
    return new_fname 
    
for partition_key, df in url_df.groupby('partition_key'):
   
    df = df.reset_index()
    
    for i, row in df.iterrows():
        try:
            
            # print(partition_key, i + 1)
            # print("Downloading: ", row['link'])
            date = row['partition_key']
            file_extension = row['file_extension']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
    
            # base_name = row['file_name']
            # base_name = row['file_name'][0:24] + row['file_name'][-35:-7] + f"_{i + 1}.csv.gz"
            base_name = formart_file_name(row, i)
            # print("base_name:", base_name)
            
            file_name = os.path.join(file_dir, base_name)
             
            print(f'Downloading file {file_name}')

            processed_cnt += 1
            
            if os.path.exists(file_name):
                print(f"File exists, skip! The file is: {file_name} \n")
                continue
            
        
            # # loop through download links and save to your computer
            data = requests.get(row['link'], stream=True)
            safe_file_write(file_path=file_name, content=data.content)
             
            #  += 1
            
            print(f"    Processed {i + 1} / {len(df)} files for {partition_key}.")
            print(f"Processed {processed_cnt} / {len(url_df)} files in total.")
            # print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
            
            print()
        except Exception as e:
            print("Error:", e)
            continue


print("Done.")
# Out:
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_00.csv.gz
# File successfully written.
#     Processed 1 / 40 files for 2019-01-07.
# Processed 1 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_01.csv.gz
# File successfully written.
#     Processed 2 / 40 files for 2019-01-07.
# Processed 2 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_02.csv.gz
# File successfully written.
#     Processed 3 / 40 files for 2019-01-07.
# Processed 3 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_03.csv.gz
# File successfully written.
#     Processed 4 / 40 files for 2019-01-07.
# Processed 4 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_04.csv.gz
# File successfully written.
#     Processed 5 / 40 files for 2019-01-07.
# Processed 5 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_05.csv.gz
# File successfully written.
#     Processed 6 / 40 files for 2019-01-07.
# Processed 6 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_06.csv.gz
# File successfully written.
#     Processed 7 / 40 files for 2019-01-07.
# Processed 7 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_07.csv.gz
# File successfully written.
#     Processed 8 / 40 files for 2019-01-07.
# Processed 8 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_08.csv.gz
# File successfully written.
#     Processed 9 / 40 files for 2019-01-07.
# Processed 9 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_09.csv.gz
# File successfully written.
#     Processed 10 / 40 files for 2019-01-07.
# Processed 10 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_10.csv.gz
# File successfully written.
#     Processed 11 / 40 files for 2019-01-07.
# Processed 11 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_11.csv.gz
# File successfully written.
#     Processed 12 / 40 files for 2019-01-07.
# Processed 12 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_12.csv.gz
# File successfully written.
#     Processed 13 / 40 files for 2019-01-07.
# Processed 13 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_13.csv.gz
# File successfully written.
#     Processed 14 / 40 files for 2019-01-07.
# Processed 14 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_14.csv.gz
# File successfully written.
#     Processed 15 / 40 files for 2019-01-07.
# Processed 15 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_15.csv.gz
# File successfully written.
#     Processed 16 / 40 files for 2019-01-07.
# Processed 16 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_16.csv.gz
# File successfully written.
#     Processed 17 / 40 files for 2019-01-07.
# Processed 17 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_17.csv.gz
# File successfully written.
#     Processed 18 / 40 files for 2019-01-07.
# Processed 18 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_18.csv.gz
# File successfully written.
#     Processed 19 / 40 files for 2019-01-07.
# Processed 19 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_19.csv.gz
# File successfully written.
#     Processed 20 / 40 files for 2019-01-07.
# Processed 20 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_20.csv.gz
# File successfully written.
#     Processed 21 / 40 files for 2019-01-07.
# Processed 21 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_21.csv.gz
# File successfully written.
#     Processed 22 / 40 files for 2019-01-07.
# Processed 22 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_22.csv.gz
# File successfully written.
#     Processed 23 / 40 files for 2019-01-07.
# Processed 23 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_23.csv.gz
# File successfully written.
#     Processed 24 / 40 files for 2019-01-07.
# Processed 24 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_24.csv.gz
# File successfully written.
#     Processed 25 / 40 files for 2019-01-07.
# Processed 25 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_25.csv.gz
# File successfully written.
#     Processed 26 / 40 files for 2019-01-07.
# Processed 26 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_26.csv.gz
# File successfully written.
#     Processed 27 / 40 files for 2019-01-07.
# Processed 27 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_27.csv.gz
# File successfully written.
#     Processed 28 / 40 files for 2019-01-07.
# Processed 28 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_28.csv.gz
# File successfully written.
#     Processed 29 / 40 files for 2019-01-07.
# Processed 29 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_29.csv.gz
# File successfully written.
#     Processed 30 / 40 files for 2019-01-07.
# Processed 30 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_30.csv.gz
# File successfully written.
#     Processed 31 / 40 files for 2019-01-07.
# Processed 31 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_31.csv.gz
# File successfully written.
#     Processed 32 / 40 files for 2019-01-07.
# Processed 32 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_32.csv.gz
# File successfully written.
#     Processed 33 / 40 files for 2019-01-07.
# Processed 33 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_33.csv.gz
# File successfully written.
#     Processed 34 / 40 files for 2019-01-07.
# Processed 34 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_34.csv.gz
# File successfully written.
#     Processed 35 / 40 files for 2019-01-07.
# Processed 35 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_35.csv.gz
# File successfully written.
#     Processed 36 / 40 files for 2019-01-07.
# Processed 36 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_36.csv.gz
# File successfully written.
#     Processed 37 / 40 files for 2019-01-07.
# Processed 37 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_37.csv.gz
# File successfully written.
#     Processed 38 / 40 files for 2019-01-07.
# Processed 38 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_38.csv.gz
# File successfully written.
#     Processed 39 / 40 files for 2019-01-07.
# Processed 39 / 6789 files in total.
#
# Year, month, day: 2019 01 07
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\07\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-07_39.csv.gz
# File successfully written.
#     Processed 40 / 40 files for 2019-01-07.
# Processed 40 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_00.csv.gz
# File successfully written.
#     Processed 1 / 40 files for 2019-01-14.
# Processed 41 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_01.csv.gz
# File successfully written.
#     Processed 2 / 40 files for 2019-01-14.
# Processed 42 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_02.csv.gz
# File successfully written.
#     Processed 3 / 40 files for 2019-01-14.
# Processed 43 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_03.csv.gz
# File successfully written.
#     Processed 4 / 40 files for 2019-01-14.
# Processed 44 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_04.csv.gz
# File successfully written.
#     Processed 5 / 40 files for 2019-01-14.
# Processed 45 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_05.csv.gz
# File successfully written.
#     Processed 6 / 40 files for 2019-01-14.
# Processed 46 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_06.csv.gz
# File successfully written.
#     Processed 7 / 40 files for 2019-01-14.
# Processed 47 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_07.csv.gz
# File successfully written.
#     Processed 8 / 40 files for 2019-01-14.
# Processed 48 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_08.csv.gz
# File successfully written.
#     Processed 9 / 40 files for 2019-01-14.
# Processed 49 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_09.csv.gz
# File successfully written.
#     Processed 10 / 40 files for 2019-01-14.
# Processed 50 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_10.csv.gz
# File successfully written.
#     Processed 11 / 40 files for 2019-01-14.
# Processed 51 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_11.csv.gz
# File successfully written.
#     Processed 12 / 40 files for 2019-01-14.
# Processed 52 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_12.csv.gz
# File successfully written.
#     Processed 13 / 40 files for 2019-01-14.
# Processed 53 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_13.csv.gz
# File successfully written.
#     Processed 14 / 40 files for 2019-01-14.
# Processed 54 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_14.csv.gz
# File successfully written.
#     Processed 15 / 40 files for 2019-01-14.
# Processed 55 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_15.csv.gz
# File successfully written.
#     Processed 16 / 40 files for 2019-01-14.
# Processed 56 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_16.csv.gz
# File successfully written.
#     Processed 17 / 40 files for 2019-01-14.
# Processed 57 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_17.csv.gz
# File successfully written.
#     Processed 18 / 40 files for 2019-01-14.
# Processed 58 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_18.csv.gz
# File successfully written.
#     Processed 19 / 40 files for 2019-01-14.
# Processed 59 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_19.csv.gz
# File successfully written.
#     Processed 20 / 40 files for 2019-01-14.
# Processed 60 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_20.csv.gz
# File successfully written.
#     Processed 21 / 40 files for 2019-01-14.
# Processed 61 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_21.csv.gz
# File successfully written.
#     Processed 22 / 40 files for 2019-01-14.
# Processed 62 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_22.csv.gz
# File successfully written.
#     Processed 23 / 40 files for 2019-01-14.
# Processed 63 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_23.csv.gz
# File successfully written.
#     Processed 24 / 40 files for 2019-01-14.
# Processed 64 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_24.csv.gz
# File successfully written.
#     Processed 25 / 40 files for 2019-01-14.
# Processed 65 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_25.csv.gz
# File successfully written.
#     Processed 26 / 40 files for 2019-01-14.
# Processed 66 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_26.csv.gz
# File successfully written.
#     Processed 27 / 40 files for 2019-01-14.
# Processed 67 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_27.csv.gz
# File successfully written.
#     Processed 28 / 40 files for 2019-01-14.
# Processed 68 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_28.csv.gz
# File successfully written.
#     Processed 29 / 40 files for 2019-01-14.
# Processed 69 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_29.csv.gz
# File successfully written.
#     Processed 30 / 40 files for 2019-01-14.
# Processed 70 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_30.csv.gz
# File successfully written.
#     Processed 31 / 40 files for 2019-01-14.
# Processed 71 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_31.csv.gz
# File successfully written.
#     Processed 32 / 40 files for 2019-01-14.
# Processed 72 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_32.csv.gz
# File successfully written.
#     Processed 33 / 40 files for 2019-01-14.
# Processed 73 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_33.csv.gz
# File successfully written.
#     Processed 34 / 40 files for 2019-01-14.
# Processed 74 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_34.csv.gz
# File successfully written.
#     Processed 35 / 40 files for 2019-01-14.
# Processed 75 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_35.csv.gz
# File successfully written.
#     Processed 36 / 40 files for 2019-01-14.
# Processed 76 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_36.csv.gz
# File successfully written.
#     Processed 37 / 40 files for 2019-01-14.
# Processed 77 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_37.csv.gz
# File successfully written.
#     Processed 38 / 40 files for 2019-01-14.
# Processed 78 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_38.csv.gz
# File successfully written.
#     Processed 39 / 40 files for 2019-01-14.
# Processed 79 / 6789 files in total.
#
# Year, month, day: 2019 01 14
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\14\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-14_39.csv.gz
# File successfully written.
#     Processed 40 / 40 files for 2019-01-14.
# Processed 80 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_00.csv.gz
# File successfully written.
#     Processed 1 / 40 files for 2019-01-21.
# Processed 81 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_01.csv.gz
# File successfully written.
#     Processed 2 / 40 files for 2019-01-21.
# Processed 82 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_02.csv.gz
# File successfully written.
#     Processed 3 / 40 files for 2019-01-21.
# Processed 83 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_03.csv.gz
# File successfully written.
#     Processed 4 / 40 files for 2019-01-21.
# Processed 84 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_04.csv.gz
# File successfully written.
#     Processed 5 / 40 files for 2019-01-21.
# Processed 85 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_05.csv.gz
# File successfully written.
#     Processed 6 / 40 files for 2019-01-21.
# Processed 86 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_06.csv.gz
# File successfully written.
#     Processed 7 / 40 files for 2019-01-21.
# Processed 87 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_07.csv.gz
# File successfully written.
#     Processed 8 / 40 files for 2019-01-21.
# Processed 88 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_08.csv.gz
# File successfully written.
#     Processed 9 / 40 files for 2019-01-21.
# Processed 89 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_09.csv.gz
# File successfully written.
#     Processed 10 / 40 files for 2019-01-21.
# Processed 90 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_10.csv.gz
# File successfully written.
#     Processed 11 / 40 files for 2019-01-21.
# Processed 91 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_11.csv.gz
# File successfully written.
#     Processed 12 / 40 files for 2019-01-21.
# Processed 92 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_12.csv.gz
# File successfully written.
#     Processed 13 / 40 files for 2019-01-21.
# Processed 93 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_13.csv.gz
# File successfully written.
#     Processed 14 / 40 files for 2019-01-21.
# Processed 94 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_14.csv.gz
# File successfully written.
#     Processed 15 / 40 files for 2019-01-21.
# Processed 95 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_15.csv.gz
# File successfully written.
#     Processed 16 / 40 files for 2019-01-21.
# Processed 96 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_16.csv.gz
# File successfully written.
#     Processed 17 / 40 files for 2019-01-21.
# Processed 97 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_17.csv.gz
# File successfully written.
#     Processed 18 / 40 files for 2019-01-21.
# Processed 98 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_18.csv.gz
# File successfully written.
#     Processed 19 / 40 files for 2019-01-21.
# Processed 99 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_19.csv.gz
# File successfully written.
#     Processed 20 / 40 files for 2019-01-21.
# Processed 100 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_20.csv.gz
# File successfully written.
#     Processed 21 / 40 files for 2019-01-21.
# Processed 101 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_21.csv.gz
# File successfully written.
#     Processed 22 / 40 files for 2019-01-21.
# Processed 102 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_22.csv.gz
# File successfully written.
#     Processed 23 / 40 files for 2019-01-21.
# Processed 103 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_23.csv.gz
# File successfully written.
#     Processed 24 / 40 files for 2019-01-21.
# Processed 104 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_24.csv.gz
# File successfully written.
#     Processed 25 / 40 files for 2019-01-21.
# Processed 105 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_25.csv.gz
# File successfully written.
#     Processed 26 / 40 files for 2019-01-21.
# Processed 106 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_26.csv.gz
# File successfully written.
#     Processed 27 / 40 files for 2019-01-21.
# Processed 107 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_27.csv.gz
# File successfully written.
#     Processed 28 / 40 files for 2019-01-21.
# Processed 108 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_28.csv.gz
# File successfully written.
#     Processed 29 / 40 files for 2019-01-21.
# Processed 109 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_29.csv.gz
# File successfully written.
#     Processed 30 / 40 files for 2019-01-21.
# Processed 110 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_30.csv.gz
# File successfully written.
#     Processed 31 / 40 files for 2019-01-21.
# Processed 111 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_31.csv.gz
# File successfully written.
#     Processed 32 / 40 files for 2019-01-21.
# Processed 112 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_32.csv.gz
# File successfully written.
#     Processed 33 / 40 files for 2019-01-21.
# Processed 113 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_33.csv.gz
# File successfully written.
#     Processed 34 / 40 files for 2019-01-21.
# Processed 114 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_34.csv.gz
# File successfully written.
#     Processed 35 / 40 files for 2019-01-21.
# Processed 115 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_35.csv.gz
# File successfully written.
#     Processed 36 / 40 files for 2019-01-21.
# Processed 116 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_36.csv.gz
# File successfully written.
#     Processed 37 / 40 files for 2019-01-21.
# Processed 117 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_37.csv.gz
# File successfully written.
#     Processed 38 / 40 files for 2019-01-21.
# Processed 118 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_38.csv.gz
# File successfully written.
#     Processed 39 / 40 files for 2019-01-21.
# Processed 119 / 6789 files in total.
#
# Year, month, day: 2019 01 21
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\21\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-21_39.csv.gz
# File successfully written.
#     Processed 40 / 40 files for 2019-01-21.
# Processed 120 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_00.csv.gz
# File successfully written.
#     Processed 1 / 40 files for 2019-01-28.
# Processed 121 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_01.csv.gz
# File successfully written.
#     Processed 2 / 40 files for 2019-01-28.
# Processed 122 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_02.csv.gz
# File successfully written.
#     Processed 3 / 40 files for 2019-01-28.
# Processed 123 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_03.csv.gz
# File successfully written.
#     Processed 4 / 40 files for 2019-01-28.
# Processed 124 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_04.csv.gz
# File successfully written.
#     Processed 5 / 40 files for 2019-01-28.
# Processed 125 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_05.csv.gz
# File successfully written.
#     Processed 6 / 40 files for 2019-01-28.
# Processed 126 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_06.csv.gz
# File successfully written.
#     Processed 7 / 40 files for 2019-01-28.
# Processed 127 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_07.csv.gz
# File successfully written.
#     Processed 8 / 40 files for 2019-01-28.
# Processed 128 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_08.csv.gz
# File successfully written.
#     Processed 9 / 40 files for 2019-01-28.
# Processed 129 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_09.csv.gz
# File successfully written.
#     Processed 10 / 40 files for 2019-01-28.
# Processed 130 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_10.csv.gz
# File successfully written.
#     Processed 11 / 40 files for 2019-01-28.
# Processed 131 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_11.csv.gz
# File successfully written.
#     Processed 12 / 40 files for 2019-01-28.
# Processed 132 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_12.csv.gz
# File successfully written.
#     Processed 13 / 40 files for 2019-01-28.
# Processed 133 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_13.csv.gz
# File successfully written.
#     Processed 14 / 40 files for 2019-01-28.
# Processed 134 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_14.csv.gz
# File successfully written.
#     Processed 15 / 40 files for 2019-01-28.
# Processed 135 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_15.csv.gz
# File successfully written.
#     Processed 16 / 40 files for 2019-01-28.
# Processed 136 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_16.csv.gz
# File successfully written.
#     Processed 17 / 40 files for 2019-01-28.
# Processed 137 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_17.csv.gz
# File successfully written.
#     Processed 18 / 40 files for 2019-01-28.
# Processed 138 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_18.csv.gz
# File successfully written.
#     Processed 19 / 40 files for 2019-01-28.
# Processed 139 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_19.csv.gz
# File successfully written.
#     Processed 20 / 40 files for 2019-01-28.
# Processed 140 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_20.csv.gz
# File successfully written.
#     Processed 21 / 40 files for 2019-01-28.
# Processed 141 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_21.csv.gz
# File successfully written.
#     Processed 22 / 40 files for 2019-01-28.
# Processed 142 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_22.csv.gz
# File successfully written.
#     Processed 23 / 40 files for 2019-01-28.
# Processed 143 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_23.csv.gz
# File successfully written.
#     Processed 24 / 40 files for 2019-01-28.
# Processed 144 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_24.csv.gz
# File successfully written.
#     Processed 25 / 40 files for 2019-01-28.
# Processed 145 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_25.csv.gz
# File successfully written.
#     Processed 26 / 40 files for 2019-01-28.
# Processed 146 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_26.csv.gz
# File successfully written.
#     Processed 27 / 40 files for 2019-01-28.
# Processed 147 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_27.csv.gz
# File successfully written.
#     Processed 28 / 40 files for 2019-01-28.
# Processed 148 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_28.csv.gz
# File successfully written.
#     Processed 29 / 40 files for 2019-01-28.
# Processed 149 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_29.csv.gz
# File successfully written.
#     Processed 30 / 40 files for 2019-01-28.
# Processed 150 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_30.csv.gz
# File successfully written.
#     Processed 31 / 40 files for 2019-01-28.
# Processed 151 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_31.csv.gz
# File successfully written.
#     Processed 32 / 40 files for 2019-01-28.
# Processed 152 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_32.csv.gz
# File successfully written.
#     Processed 33 / 40 files for 2019-01-28.
# Processed 153 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_33.csv.gz
# File successfully written.
#     Processed 34 / 40 files for 2019-01-28.
# Processed 154 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_34.csv.gz
# File successfully written.
#     Processed 35 / 40 files for 2019-01-28.
# Processed 155 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_35.csv.gz
# File successfully written.
#     Processed 36 / 40 files for 2019-01-28.
# Processed 156 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_36.csv.gz
# File successfully written.
#     Processed 37 / 40 files for 2019-01-28.
# Processed 157 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_37.csv.gz
# File successfully written.
#     Processed 38 / 40 files for 2019-01-28.
# Processed 158 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_38.csv.gz
# File successfully written.
#     Processed 39 / 40 files for 2019-01-28.
# Processed 159 / 6789 files in total.
#
# Year, month, day: 2019 01 28
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\01\28\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-01-28_39.csv.gz
# File successfully written.
#     Processed 40 / 40 files for 2019-01-28.
# Processed 160 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_00.csv.gz
# File successfully written.
#     Processed 1 / 41 files for 2019-02-04.
# Processed 161 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_01.csv.gz
# File successfully written.
#     Processed 2 / 41 files for 2019-02-04.
# Processed 162 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_02.csv.gz
# File successfully written.
#     Processed 3 / 41 files for 2019-02-04.
# Processed 163 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_03.csv.gz
# File successfully written.
#     Processed 4 / 41 files for 2019-02-04.
# Processed 164 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_04.csv.gz
# File successfully written.
#     Processed 5 / 41 files for 2019-02-04.
# Processed 165 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_05.csv.gz
# File successfully written.
#     Processed 6 / 41 files for 2019-02-04.
# Processed 166 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_06.csv.gz
# File successfully written.
#     Processed 7 / 41 files for 2019-02-04.
# Processed 167 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_07.csv.gz
# File successfully written.
#     Processed 8 / 41 files for 2019-02-04.
# Processed 168 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_08.csv.gz
# File successfully written.
#     Processed 9 / 41 files for 2019-02-04.
# Processed 169 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2019\02\04\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2019-02-04_09.csv.gz
# File successfully written.
#     Processed 10 / 41 files for 2019-02-04.
# Processed 170 / 6789 files in total.
#
# Year, month, day: 2019 02 04
# ...
# Processed 3767 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_645.csv.gz
# File successfully written.
#     Processed 646 / 741 files for 2023-11-20.
# Processed 3768 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_646.csv.gz
# File successfully written.
#     Processed 647 / 741 files for 2023-11-20.
# Processed 3769 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_647.csv.gz
# File successfully written.
#     Processed 648 / 741 files for 2023-11-20.
# Processed 3770 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_648.csv.gz
# File successfully written.
#     Processed 649 / 741 files for 2023-11-20.
# Processed 3771 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_649.csv.gz
# File successfully written.
#     Processed 650 / 741 files for 2023-11-20.
# Processed 3772 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_650.csv.gz
# File successfully written.
#     Processed 651 / 741 files for 2023-11-20.
# Processed 3773 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_651.csv.gz
# File successfully written.
#     Processed 652 / 741 files for 2023-11-20.
# Processed 3774 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_652.csv.gz
# File successfully written.
#     Processed 653 / 741 files for 2023-11-20.
# Processed 3775 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_653.csv.gz
# File successfully written.
#     Processed 654 / 741 files for 2023-11-20.
# Processed 3776 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_654.csv.gz
# File successfully written.
#     Processed 655 / 741 files for 2023-11-20.
# Processed 3777 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_655.csv.gz
# File successfully written.
#     Processed 656 / 741 files for 2023-11-20.
# Processed 3778 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_656.csv.gz
# File successfully written.
#     Processed 657 / 741 files for 2023-11-20.
# Processed 3779 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_657.csv.gz
# File successfully written.
#     Processed 658 / 741 files for 2023-11-20.
# Processed 3780 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_658.csv.gz
# File successfully written.
#     Processed 659 / 741 files for 2023-11-20.
# Processed 3781 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_659.csv.gz
# File successfully written.
#     Processed 660 / 741 files for 2023-11-20.
# Processed 3782 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_660.csv.gz
# File successfully written.
#     Processed 661 / 741 files for 2023-11-20.
# Processed 3783 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_661.csv.gz
# File successfully written.
#     Processed 662 / 741 files for 2023-11-20.
# Processed 3784 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_662.csv.gz
# File successfully written.
#     Processed 663 / 741 files for 2023-11-20.
# Processed 3785 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_663.csv.gz
# File successfully written.
#     Processed 664 / 741 files for 2023-11-20.
# Processed 3786 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_664.csv.gz
# File successfully written.
#     Processed 665 / 741 files for 2023-11-20.
# Processed 3787 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_665.csv.gz
# File successfully written.
#     Processed 666 / 741 files for 2023-11-20.
# Processed 3788 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_666.csv.gz
# File successfully written.
#     Processed 667 / 741 files for 2023-11-20.
# Processed 3789 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_667.csv.gz
# File successfully written.
#     Processed 668 / 741 files for 2023-11-20.
# Processed 3790 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_668.csv.gz
# File successfully written.
#     Processed 669 / 741 files for 2023-11-20.
# Processed 3791 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_669.csv.gz
# File successfully written.
#     Processed 670 / 741 files for 2023-11-20.
# Processed 3792 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_670.csv.gz
# File successfully written.
#     Processed 671 / 741 files for 2023-11-20.
# Processed 3793 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_671.csv.gz
# File successfully written.
#     Processed 672 / 741 files for 2023-11-20.
# Processed 3794 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_672.csv.gz
# File successfully written.
#     Processed 673 / 741 files for 2023-11-20.
# Processed 3795 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_673.csv.gz
# File successfully written.
#     Processed 674 / 741 files for 2023-11-20.
# Processed 3796 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_674.csv.gz
# File successfully written.
#     Processed 675 / 741 files for 2023-11-20.
# Processed 3797 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_675.csv.gz
# File successfully written.
#     Processed 676 / 741 files for 2023-11-20.
# Processed 3798 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_676.csv.gz
# File successfully written.
#     Processed 677 / 741 files for 2023-11-20.
# Processed 3799 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_677.csv.gz
# File successfully written.
#     Processed 678 / 741 files for 2023-11-20.
# Processed 3800 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_678.csv.gz
# File successfully written.
#     Processed 679 / 741 files for 2023-11-20.
# Processed 3801 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_679.csv.gz
# File successfully written.
#     Processed 680 / 741 files for 2023-11-20.
# Processed 3802 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_680.csv.gz
# File successfully written.
#     Processed 681 / 741 files for 2023-11-20.
# Processed 3803 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_681.csv.gz
# File successfully written.
#     Processed 682 / 741 files for 2023-11-20.
# Processed 3804 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_682.csv.gz
# File successfully written.
#     Processed 683 / 741 files for 2023-11-20.
# Processed 3805 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_683.csv.gz
# File successfully written.
#     Processed 684 / 741 files for 2023-11-20.
# Processed 3806 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_684.csv.gz
# File successfully written.
#     Processed 685 / 741 files for 2023-11-20.
# Processed 3807 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_685.csv.gz
# File successfully written.
#     Processed 686 / 741 files for 2023-11-20.
# Processed 3808 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_686.csv.gz
# File successfully written.
#     Processed 687 / 741 files for 2023-11-20.
# Processed 3809 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_687.csv.gz
# File successfully written.
#     Processed 688 / 741 files for 2023-11-20.
# Processed 3810 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_688.csv.gz
# File successfully written.
#     Processed 689 / 741 files for 2023-11-20.
# Processed 3811 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_689.csv.gz
# File successfully written.
#     Processed 690 / 741 files for 2023-11-20.
# Processed 3812 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_690.csv.gz
# File successfully written.
#     Processed 691 / 741 files for 2023-11-20.
# Processed 3813 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_691.csv.gz
# File successfully written.
#     Processed 692 / 741 files for 2023-11-20.
# Processed 3814 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_692.csv.gz
# File successfully written.
#     Processed 693 / 741 files for 2023-11-20.
# Processed 3815 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_693.csv.gz
# File successfully written.
#     Processed 694 / 741 files for 2023-11-20.
# Processed 3816 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_694.csv.gz
# File successfully written.
#     Processed 695 / 741 files for 2023-11-20.
# Processed 3817 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_695.csv.gz
# File successfully written.
#     Processed 696 / 741 files for 2023-11-20.
# Processed 3818 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_696.csv.gz
# File successfully written.
#     Processed 697 / 741 files for 2023-11-20.
# Processed 3819 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_697.csv.gz
# File successfully written.
#     Processed 698 / 741 files for 2023-11-20.
# Processed 3820 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_698.csv.gz
# File successfully written.
#     Processed 699 / 741 files for 2023-11-20.
# Processed 3821 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_699.csv.gz
# File successfully written.
#     Processed 700 / 741 files for 2023-11-20.
# Processed 3822 / 6789 files in total.
#
# Year, month, day: 2023 11 20
# Downloading file E:\SafeGraph\Advan_2024_API\Neighborhood_Patterns\2023\11\20\Weekly_Patterns_Foot_Traffic-DATE_RANGE_START-2023-11-20_700.csv.gz

# %%
Not used below

# %%
# downloaded_cnt = 0
# for partition_key, df in url_df.groupby('partition_key'):
   
#     df = df.reset_index()
#     for i, row in df.iterrows():
#         try:
#             # print(partition_key, i + 1)
#             # print("Downloading: ", row['link'])
#             date = row['partition_key']
#             year = date[:4]
#             month = date[5:7]
#             day = date[-2:]
#             file_dir = os.path.join(save_dir, year, month, day)
#             os.makedirs(file_dir, exist_ok=True)
#             print("Year, month, day:", year, month, day)
    
#             # base_name = row['file_name']
#             base_name = row['file_name'][0:24] + row['file_name'][-35:-7] + f"_{i + 1:02}.csv.gz"
#             # print("base_name:", base_name)
            
#             file_name = os.path.join(file_dir, base_name)
             
#             print(f'Downloading file {file_name}')
        
#             if os.path.exists(file_name):
#                 print(f"File exists, skip! The file is: {file_name} \n")
#                 continue
        
#             # # loop through download links and save to your computer
#             data = requests.get(row['link'], stream=True)
#             safe_file_write(file_path=file_name, content=data.content)
             
#             #  += 1
#             downloaded_cnt += 1
#             print(f"    Downloaded {i + 1} / {len(df)} files for {partition_key}.")
#             print(f"Downloaded {downloaded_cnt} / {len(url_df)} files in total.")
#             # print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
            
#             print()
#         except Exception as e:
#             print("Error:", e)
#             continue

# print("Done.")

# %%
STOP

Not used below

# %%
## api_key = r'J923tlBL.54vRQ2rAhcMc8nhb1v6IZyJwCWUkgG2LA33tHCpJJXhFwilrUhT1ckxJ'

 
# neighborhood patterns:
url = r'https://app.deweydata.io/external-api/v3/products/2dfcb598-6e30-49f1-bdba-1deae113a951/files'
# save_dir = r'K:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'   # Dell 2019
save_dir = r'F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'  # Lenova 2018

# monthly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/5acc9f39-1ca6-4535-b3ff-38f6b9baf85e/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Monthly_Patterns'

# # weekly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/176f0262-c1f6-4dbe-be43-6a6eb21bcf8a/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Weekly_Patterns'

# # hourly weather:
# url = r"https://app.deweydata.io/external-api/v3/products/a6be0385-8820-4943-a509-6eac4154b4f6/files"

# monthly home panel summary
# url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
# save_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'


os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# loop through all API result pages, keeping track of number of downloaded files
page = 1
download_count = 0

while True:
    # get results from API endpoint, using API key for authentication
    results = requests.get(url=PRODUCT_API_PATH,
                           params={'page': page,
                                   'partition_key_after': '2018-01-01',   # optionally set date value here
                                   'partition_key_before': '2023-12-31', 
                                  }, # optionally set date value here
                           headers={'X-API-KEY': API_KEY,
                                    'accept': 'application/json'
                                   })
    response_json = results.json()
    total_pages = response_json['total_pages']

    link_cnt = len(response_json['download_links'])
 
    # for each result page, loop through download links and save to your computer
    for idx, link_data in enumerate(response_json['download_links']):
        # create file name for each link
        print(f"Downloading {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloading {download_count} files in total, Page {page} / {total_pages}.")
        
        if response_json['partition_column']:
            date = link_data['partition_key']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
            # file_name = f"file-{download_count+1}-{response_json['partition_column']}-{link_data['partition_key']}.csv.gz" 
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            # base_name = unquote(base_name) 
            base_name = link_data['file_name']
            base_name = base_name[0:24] + base_name[-35:] 
            
            file_name = os.path.join(file_dir, base_name)
            
        else:
            # not tested
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            # base_name = unquote(base_name) 
            base_name = link_data['file_name']  
            # need to remove the numbers in the result: Neighborhood_Patterns_US-8-DATE_RANGE_START-2020-02-01.csv # 2024-01-05
            base_name = base_name[0:24] + base_name[-35:] 
            # print("base_name:", base_name)
            
            file_name = os.path.join(file_dir, base_name)
            
        print(f'Downloading file {file_name}')

        if os.path.exists(file_name):
            print(f"File exists, skip! The file is: {file_name} \n")
            continue

        # # loop through download links and save to your computer
        data = requests.get(link_data['link'], stream=True)
        safe_file_write(file_path=file_name, content=data.content)
        
  
        download_count += 1
        print(f"Downloaded {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
        
        print()

    # only continue if there are more result pages to process    
    if page >= total_pages:
        break
        
    page += 1
    
    

print(f"Successfully downloaded {download_count} files.")

print("Done")
# returns = results.json()
# print(returns.keys())
# print(len(returns['download_links']))
# del returns['download_links']
# returns

# %%
# response_json

# %% [markdown]
# # Download monthly patterns home panel summary

# %%
api_key = r'J923tlBL.54vRQ2rAhcMc8nhb1v6IZyJwCWUkgG2LA33tHCpJJXhFwilrUhT1ckxJ'

# monthly home panel summary
url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
save_dir = r'D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'
os.makedirs(save_dir, exist_ok=True)

# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# loop through all API result pages, keeping track of number of downloaded files
page = 1
download_count = 0

while True:
    # get results from API endpoint, using API key for authentication
    results = requests.get(url=PRODUCT_API_PATH,
                           params={'page': page,
                                   # 'partition_key_after': '2023-05-30',   # optionally set date value here
                                   # 'partition_key_before': '2023-09-01', 
                                  }, # optionally set date value here
                           headers={'X-API-KEY': API_KEY,
                                    'accept': 'application/json'
                                   })
    response_json = results.json()
    total_pages = response_json['total_pages']

    link_cnt = len(response_json['download_links'])
     
    # for each result page, loop through download links and save to your computer
    for idx, link_data in enumerate(response_json['download_links']):
        # create file name for each link
        print(f"Downloading {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloading {download_count} files in total, Page {page} / {total_pages}.")
        
        if response_json['partition_column']:
            date = link_data['partition_key']
            # year = date[:4]
            # month = date[5:7]
            # day = date[-2:]
     
            
            # print("Year, month, day:", year, month, day)
            # file_name = f"file-{download_count+1}-{response_json['partition_column']}-{link_data['partition_key']}.csv.gz" 
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            base_name = link_data['file_name']
            
            
            
        else:
            # not tested
            url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            base_name = link_data['file_name']
            file_name = os.path.join(save_dir, base_name)
            
            
        print(f'Downloading file {file_name}')

        if os.path.exists(file_name):
            print(f"File exists, skip! The file is: {file_name} \n")
            continue

        # # loop through download links and save to your computer
        data = requests.get(link_data['link'], stream=True)
        safe_file_write(file_path=file_name, content=data.content)
        
        
        # with open(file_name, 'wb') as file:            
        #     file.write(data.content)
             
        download_count += 1
        print(f"Downloaded {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
        
        print()

    # only continue if there are more result pages to process
    
    if page >= total_pages:
        break
        
    page += 1
    
    

print(f"Successfully downloaded {download_count} files.")

print("Done")
# returns = results.json()
# print(returns.keys())
# print(len(returns['download_links']))
# del returns['download_links']
# returns

# %% [markdown]
# # Merge monthly patterns home panel

# %%
folder = r'D:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'

# %%
panel_df = ad_op.load_neighborhood_monthly_folder(folder,  extions=['gz'], start_str='Monthly_Patterns_Home_Panel_Summary', use_cols=None, verbose=True, test=False)
panel_df

# %%
new_fname = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\Wild_fire\home_panel_summary_2019_2023_restated_20240119.csv.gz'
panel_df.to_csv(new_fname, index=False)

# %%
len(panel_df.query(f"ISO_COUNTRY_CODE == 'US' ")) / 6 / 12

# %%
monthly_device_cnt_df = panel_df.query(f"ISO_COUNTRY_CODE == 'US' ").groupby(['YEAR', 'MON'], as_index=True)['NUMBER_DEVICES_RESIDING'].sum() / 10**6
print("monthly_device_cnt_df   (million):" )
monthly_device_cnt_df.reset_index()

# %% [markdown]
# # Stop

# %%
Stop

# %% [markdown]
# # Not used below

# %%
import pandas as pd
import numpy as np
import json
import base64
import requests
# from posixpath import basename
import os
import requests
import time
import tempfile

def get_access_token(account="hning@email.sc.edu", password="Nhwwdewey2022,", verbose=True):
    # un =  # Set username
    # pw = # Set password

    credentials = f"{account}:{password}" # Format credentials according to the API's expectations
    # print(credentials)

    credentials_bytes = credentials.encode('ascii')
    base64_credentials_bytes = base64.b64encode(credentials_bytes)
    base64_credentials = base64_credentials_bytes.decode('ascii')
    # print(base64_credentials)


    headers = {
        'accept': 'application/json',
        'Authorization': f'Basic {base64_credentials}'
    }

    response = requests.post("https://marketplace.deweydata.io/api/auth/tks/get_token", headers=headers)
    
    access_token = response.json()['access_token']
    
    if verbose:
        print(response.json())
        print(access_token)
    
    return access_token

def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")
            
            
# Main function
def download_all_files(save_dir, headers, override=False):
 
    init_url = r'/api/data/v2/list'
    home_url = 'https://marketplace.deweydata.io'    
    web_dir_list = [init_url]
    
    print("Started...")
    
    skipped_cnt = 0
    while len(web_dir_list) > 0:
        try:
            # web_dir = web_dir_list.pop()
            # print("web_dir_list:", web_dir_list)
            web_dir = web_dir_list.pop()   # Get the latest file
            
            
            url = home_url + web_dir
            # print(url, web_dir)
            items = requests.get(url, headers=headers).json()
            # print(requests.get(url, headers=headers).url)
            
            items = items[::-1]  # Put the latest file in the end.
 

            for item in items:
                name = item['name']
                if item['directory']:  
                    
                    # skip data
                    # if r'/2021/' not in url:
                    #     # print("Skipped:", url)
                    #     skipped_cnt += 1
                    #     if skipped_cnt % 10 == 0:
                    #         print("skipped un-targeted files:", skipped_cnt)
                    #     continue
                    
                    web_dir = item['url']
                    
                    full_web_dir = home_url + web_dir

                    local_dir = item['parent'].replace(init_url, '').replace(r'/', '\\')[1:] # for windows  
                                        

                    web_dir_list.append(web_dir)
                    print(f"Waiting directories (count: {len(web_dir_list)}):\n", web_dir_list[0], '...', web_dir_list[-1])
                    
                    
                    new_folder = os.path.join(save_dir, local_dir)
                    # os.makedirs(new_folder, exist_ok=True)
                    
                    if not os.path.exists(new_folder):
                         os.makedirs(new_folder, exist_ok=True)    
                    # new_folder = os.path.join(save_dir, save_dir_name)    
                    # os.makedirs(new_folder, exist_ok=True)

                    # print(f'Creaet a folder {new_folder} for web directory: {full_web_dir}')
 
                else:
                    
                    basename = item['name']     
                    # if not 'spend' in basename:
                    #     continue
                    url = home_url + item['url']
                    
                    # skip data
                    # if r'/ADVAN/' not in url:
                    #     # print("Skipped:", url)
                    #     skipped_cnt += 1
                    #     if skipped_cnt % 10 == 0:
                    #         print("skipped un-targeted files:", skipped_cnt)
                    #     continue
                    
                    full_web_dir = home_url + web_dir
                    local_dir = item['parent'].replace(init_url, '').replace(r'/', os.sep)[1:] # for windows  
                    # print("save_dir, local_dir", save_dir, local_dir, os.path.join(save_dir, local_dir))
                    new_folder = os.path.join(save_dir, local_dir)
                    # os.makedirs(new_folder, exist_ok=True)
                    
                    if not os.path.exists(new_folder):
                         os.makedirs(new_folder, exist_ok=True)
                    
                    filename = os.path.join(new_folder, basename).replace(r'/', os.sep)  # for windows
                    # print("new_folder, local_dir, filename, new_folder:", new_folder, local_dir, filename, new_folder)
                    
                    # whether skip existing files:
                    if not override:
                        if os.path.exists(filename):
                            # print("File exists, skipped:", filename)
                            skipped_cnt += 1
                            if skipped_cnt % 50 == 0:
                                print("skipped un-targeted files:", skipped_cnt)
                                print("File exists, skipped:", filename)
                            continue
                            continue
                    
                    new_folder = os.path.dirname(filename)    
                    os.makedirs(new_folder, exist_ok=True)
                    
                    print(f"Downloading: {url}")
                    
#                     with open(filename, 'wb') as f:
                        
#                         r = requests.get(url, stream=True, headers=headers)
#                         f.write(r.content)
                    r = requests.get(url, stream=True, headers=headers)
                    safe_file_write(file_path=filename, content=r.content)
        
                    # with requests.get(url, stream=True, headers=headers) as r:
                    #     # r.raise_for_status()
                    #     with open(filename, 'wb') as f:
                    #         for chunk in r.iter_content(chunk_size=8192):
                    #             if chunk:
                    #                 f.write(chunk)
                    
                    print(f"Saved at  : {filename}")
                    
                    
        except Exception as e:
            print(url, e)
            print("sleeping 5 seconds...")
            time.sleep(5)
            
            access_token = get_access_token()
            headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
              }
            download_all_files(save_dir=save_dir, headers=headers)
            
            continue
            
    print("Done")

# Example usage
# access_token = r'v8-YZaYSs3t9CYkKnYywgfQ8zIs'


access_token = get_access_token()

headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
          }

save_dir = r'G:\SafeGraph_monthly_patterns_2018-2022'

download_all_files(save_dir=save_dir, headers=headers)

# %% [markdown]
# # Stop

# %%
! echo -n "hning@email.sc.edu:Nhww1898," | openssl base64

# %%
! curl -X 'POST' 'https://marketplace.deweydata.io/api/auth/tks/get_token' -H 'accept: application/json' -H 'Authorization: Basic LW4gImhuaW5nQGVtYWlsLnNjLmVkdTpOaHd3MTg5OCwiIA0K'

# %%
! curl -X GET "https://marketplace.deweydata.io/api/data/v2/list" -H "accept: application/json" -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA"

# %%
access_token = r'0c3RBibybyGBMfXjOuCjO8qtxDA'
# ! path = r'api/data/v2/list/2022'
# ! curl -H 'Accept: application/json' -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA" -X GET 'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_home_panel_0' -o test11.csv

# %%
import requests

def get_all_files():
    headers = {
            'Accept': 'application/json',
            'Authorization': 'Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA'
            }
    res = requests.get(
                        'https://marketplace.deweydata.io/api/data/v2/list',                     
                    headers=headers)  
    
    print(res.url)
    return res.json()

dirs = get_all_files()
dirs
# open('visit_panel_summary2.csv', 'wb').write(res.content)
url = r'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_cpgp_part8_0'
res = requests.get(
                    url,                     
                    headers=headers)  
open('visit_panel_summary2.csv', 'wb').write(res.content)

# %%
import requests
import re

def get_filename_from_cd(cd):
    """
    Get filename from content-disposition
    """
    if not cd:
        return None
    fname = re.findall('filename=(.+)', cd)
    print(fname)
    if len(fname) == 0:
        return None
    return fname[0]


url = r'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_cpgp_part8_0'

# url = 'http://google.com/favicon.ico'
r = requests.get(url, allow_redirects=True)
filename = get_filename_from_cd(r.headers.get('content-disposition'))
open(filename, 'wb').write(r.content)

# %%
# from posixpath import basename
import os
import requests
import time

# Main function
def download_all_files(save_dir, headers):
 
    init_url = r'/api/data/v2/list'
    home_url = 'https://marketplace.deweydata.io'    
    web_dir_list = [init_url]
    
    while len(web_dir_list) > 0:
        try:
            web_dir = web_dir_list.pop()
            
            
            url = home_url + web_dir
            # print(url, web_dir)
            items = requests.get(url, headers=headers).json()
            
            items = items[::-1]
            

            for item in items:
                name = item['name']
                if item['directory']:  
                    
                    web_dir = item['url']
                    
                    full_web_dir = home_url + web_dir

                    save_dir_name = full_web_dir.replace(home_url + init_url + '/', "").replace(r'/', '\\')  # for windows

                    new_folder = os.path.join(save_dir, save_dir_name)    
                    os.makedirs(new_folder, exist_ok=True)

                    web_dir_list.append(web_dir)    

                    print(f'Creaet a folder {new_folder} for web directory: {full_web_dir}')
 
                else:
                    
                    basename = item['name']     
                    # if not 'spend' in basename:
                    #     continue
                    url = home_url + item['url']
                    full_web_dir = home_url + web_dir
                    local_dir = item['parent'].replace(init_url, '').replace(r'/', '\\')[1:] # for windows  
                    # print("save_dir, local_dir", save_dir, local_dir, os.path.join(save_dir, local_dir))
                    new_folder = os.path.join(save_dir, local_dir)
                    os.makedirs(new_folder, exist_ok=True)
                    
                    filename = os.path.join(new_folder, basename).replace(r'/', '\\')  # for windows
                    # print("new_folder, local_dir, filename, new_folder:", new_folder, local_dir, filename, new_folder)
                    with requests.get(url, stream=True, headers=headers) as r:
                        # r.raise_for_status()
                        with open(filename, 'wb') as f:
                            for chunk in r.iter_content(chunk_size=8192):
                                if chunk:
                                    f.write(chunk)
                    print(f"Downloaded: {url}")
                    print(f"Saved at  : {filename}")
                    
                    
        except Exception as e:
            print(url, e)
            print("sleeping 6 seconds...")
            time.sleep(6)
            
            continue

# Example usage
access_token = r'v8-YZaYSs3t9CYkKnYywgfQ8zIs'
headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
          }

save_dir = r'L:\SafeGraph_monthly_patterns_2018-2022'

download_all_files(save_dir=save_dir, headers=headers)

# %% [markdown]
# # Stop

# %%
# from posixpath import basename
import os
import requests

# Function to download a file
def download_file(home_url, item, save_folder, headers):

    basename = item['name']
    
    
    
    url = home_url + item['url']
    new_folder = os.path.join(save_folder, url.replace(home_url + '/', ''))
    os.makedirs(new_folder, exist_ok=True)
    
    filename = os.path.join(new_folder, basename)
    
    with requests.get(url, stream=True, headers=headers) as r:
        # r.raise_for_status()
        with open(filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
    print(f"Downloaded: {url}")
    print(f"Saved at  : {filename}")

# Function to download a directory recursively
def download_directory(directory, save_folder, headers):
    home_url = 'https://marketplace.deweydata.io'
    # print("directory: ", directory)
    url = home_url + directory
    # print("url:", url)
    items = requests.get(url, headers=headers).json()
    
    # print("headers:", headers)
    # print(url, items)

    for item in items:
        name = item['name']
        # print(item)
        # item_path = 
        
        if item['directory']:
            save_dir = os.path.join(save_folder, name)
            # directory = home_url + 
            directory = item['url']
            # print("directory: ", directory)
            new_folder = os.path.join(save_folder, directory.replace(home_url, ''))
            
            os.makedirs(new_folder, exist_ok=True)
            download_directory(directory, save_folder, headers=headers)
        else:
            download_file(home_url, item, save_folder, headers=headers)

# Main function
def download_all_files(save_folder):
    headers = {
        'accept': 'application/json',
        'Authorization': 'Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA'
    }


    download_directory(directory='/api/data/v2/list', save_folder=save_folder, headers=headers)


# Example usage
save_dir = r'L:\SafeGraph_monthly_patterns_2018-2022'
download_all_files(save_dir)

# %%
# files = res.json()

type(files)
files[0]

# %%
curl -H "Accept: application/json" -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA" -X GET "/api/data/v2/list/2022/12/01/SAFEGRAPH/MP/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_home_panel_0" -o test42.csv

# %% [markdown]
# # Merge panel CSV files

# %%
import os
import pandas as pd

# %%
data_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23'


def get_all_files(data_dir, exts=['.csv'], verbose=True):
    all_files = []
    for root_dir, folders, files in os.walk(data_dir):
        
        for f in files:
            for ext in exts:
                ext_len = len(ext)
                if ext == f[-ext_len:]:
                    full_name = os.path.join(root_dir, f)
                    all_files.append(full_name)
    if verbose:
        print("Found files:", len(all_files))
    return sorted(all_files)


all_files = get_all_files(data_dir, exts=['.csv.gz'])

# %%
merged_panel_df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])
merged_panel_df = merged_panel_df.sort_values(['YEAR', 'MON', 'CENSUS_BLOCK_GROUP'])  
merged_panel_df

# %%
monthly_device_cnt_df = merged_panel_df.query(f"ISO_COUNTRY_CODE == 'US' ").groupby(['YEAR', 'MON'], as_index=True)['NUMBER_DEVICES_RESIDING'].sum() / 10**6
print("monthly_device_cnt_df   (million):" )
monthly_device_cnt_df = monthly_device_cnt_df.reset_index()
monthly_device_cnt_df['year_month'] = monthly_device_cnt_df['YEAR'].astype(str)  + monthly_device_cnt_df['MON'].astype(str).str.zfill(2)
monthly_device_cnt_df['year_month'] = pd.to_datetime(monthly_device_cnt_df['year_month'], format='%Y%m')
monthly_device_cnt_df = monthly_device_cnt_df.set_index('year_month')
monthly_device_cnt_df

# %%
monthly_device_cnt_df.drop(columns=['YEAR', 'MON']).iloc[48:, :]

# %%
monthly_device_cnt_df['NUMBER_DEVICES_RESIDING'].plot()

# %% [markdown]
# # Help topic in Deweydata community
#
# https://community.deweydata.io/t/residing-device-count-in-2023-07-and-2023-08-surged-abnomorally/26675

# %%
merged_panel_df.query(f"ISO_COUNTRY_CODE == 'US' and YEAR == 2023 and MON ==7 ")
