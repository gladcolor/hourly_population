# %% [markdown]
# # Download

# %%
import os
import base64
import requests
import json
import base64 
import tempfile
from urllib.parse import urlparse
from urllib.parse import unquote

import pandas as pd
import numpy as np
from getpass import getpass
from glob import glob
from tqdm import tqdm
pd.set_option('display.max_columns', None)

access_token = 'ALtAyMZA.Y1sITQvTj6OXSr6XUz31P2ov3XvsdkhpbijDutzY0glCVNohhzM4okEe'

# %% [markdown]
# # Neighborhood patterns

# %% [markdown]
# ## helper function

# %%
def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")

def combine_monthly_pattern_home_panel_summary(data_dir, extend='.csv.gz'):
    print(os.path.join(data_dir, f"*{extend}"))
    all_files = glob(os.path.join(data_dir, f"*{extend}"))

    df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])

    return df
    
    # print(all_files)

# Merge CSV files
# home_panel_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'
# home_panel_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23'
# df = combine_monthly_pattern_home_panel_summary(data_dir=home_panel_dir)
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)
# df

# %%
# Spend patterns:
# url = r'https://app.deweydata.io/external-api/v3/products/eb6e748a-0fdd-4bc7-9dd7-bbed0890948d/files'
# # save_dir = r'K:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'   # Dell 2019
# save_dir = r'D:\SafeGraph\Advan_2023_API\Spend_Patterns'  # Lenova 2018

# POI
url = r'https://app.deweydata.io/external-api/v3/products/63eeb9d8-8439-42b3-a75e-2d9cbdf64cb8/files'
save_dir = r'D:\SafeGraph\Advan_2023_API\POI'  # Lenova 2018


# neighborhood patterns:
# url = r'https://app.deweydata.io/external-api/v3/products/2dfcb598-6e30-49f1-bdba-1deae113a951/files'
# save_dir = r'K:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'   # Dell 2019
# save_dir = r'F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'  # Lenova 2018

# monthly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/5acc9f39-1ca6-4535-b3ff-38f6b9baf85e/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Monthly_Patterns'

# # weekly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/176f0262-c1f6-4dbe-be43-6a6eb21bcf8a/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Weekly_Patterns'

# # hourly weather:
# url = r"https://app.deweydata.io/external-api/v3/products/a6be0385-8820-4943-a509-6eac4154b4f6/files"

# monthly home panel summary
# url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
# save_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'


os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# %%
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)

# %%
results = requests.get(url=PRODUCT_API_PATH,
                                   params={'page': 1,
                                           # 'partition_key_after': '2019-01-01',   # optionally set date value here
                                           # 'partition_key_before': '2024-01-01', 
                                          }, # optionally set date value here
                                   headers={'X-API-KEY': API_KEY,
                                            'accept': 'application/json'
                                           })
response_json = results.json()
# response_json

# %%
response_json

# %%
def get_all_download_urls():
    total_pages = 1
    current_page = 0
    df_list = []
    while current_page < total_pages:
        results = requests.get(url=PRODUCT_API_PATH,
                                   params={'page': total_pages,
                                           # 'partition_key_after': '2017-01-01',   # optionally set date value here
                                           # 'partition_key_before': '2024-12-31', 
                                          }, # optionally set date value here
                                   headers={'X-API-KEY': API_KEY,
                                            'accept': 'application/json'
                                           })
        response_json = results.json()
        total_pages = response_json['total_pages']
    
        df = pd.DataFrame(response_json)
        df_list.append(df)
        current_page += 1
            
    response_df = pd.concat(df_list)
    
    
    df_list2 = []
    for idx, row in response_df.iterrows():
        # print(row['download_links'])
        df = pd.DataFrame.from_dict([row['download_links']])
        df_list2.append(df)
        # break
        
    url_df = pd.concat(df_list2).sort_values("partition_key")
    return response_df, url_df

response_df, url_df = get_all_download_urls()
url_df
# Out:
#                                                  link partition_key  \
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# ..                                                ...           ...
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
# 0   https://s3.us-east-005.backblazeb2.com/amplify...          None
#
#                            file_name file_extension  file_size_bytes  \
# 0    Global_Places_POI_Data-0.csv.gz        .csv.gz        146193779
# 0    Global_Places_POI_Data-1.csv.gz        .csv.gz        146282352
# 0    Global_Places_POI_Data-2.csv.gz        .csv.gz        154391307
# 0    Global_Places_POI_Data-3.csv.gz        .csv.gz        167781076
# 0    Global_Places_POI_Data-4.csv.gz        .csv.gz        149519890
# ..                               ...            ...              ...
# 0   Global_Places_POI_Data-59.csv.gz        .csv.gz        149649486
# 0   Global_Places_POI_Data-60.csv.gz        .csv.gz        142311650
# 0   Global_Places_POI_Data-61.csv.gz        .csv.gz        127156461
# 0   Global_Places_POI_Data-62.csv.gz        .csv.gz        151423083
# 0   Global_Places_POI_Data-63.csv.gz        .csv.gz        146154685
#
#                  modified_at
# 0   2024-01-07T20:48:47.561Z
# 0   2024-01-07T20:48:47.556Z
# 0   2024-01-07T20:48:47.574Z
# 0   2024-01-07T20:48:47.563Z
# 0   2024-01-07T20:48:47.566Z
# ..                       ...
# 0   2024-01-07T20:48:45.446Z
# 0   2024-01-07T20:48:45.436Z
# 0   2024-01-07T20:48:45.435Z
# 0   2024-01-07T20:48:45.436Z
# 0   2024-01-07T20:48:45.437Z
#
# [64 rows x 6 columns]

# %%
# url_df['partition_key'] = url_df['modified_at'].str[:10]
# url_df

# %%
downloaded_cnt = 0
for partition_key, df in url_df.groupby('partition_key'):
   
    df = df.reset_index()
    for i, row in df.iterrows():
        try:
            # print(partition_key, i + 1)
            # print("Downloading: ", row['link'])
            date = row['partition_key']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
    
            # base_name = row['file_name']
            base_name = row['file_name'][0:24] + row['file_name'][-35:-7] + f"_{i + 1}.csv.gz"
            # print("base_name:", base_name)
            
            file_name = os.path.join(file_dir, base_name)
             
            print(f'Downloading file {file_name}')
        
            if os.path.exists(file_name):
                print(f"File exists, skip! The file is: {file_name} \n")
                continue
        
            # # loop through download links and save to your computer
            data = requests.get(row['link'], stream=True)
            safe_file_write(file_path=file_name, content=data.content)
             
            #  += 1
            downloaded_cnt += 1
            print(f"    Downloaded {i + 1} / {len(df)} files for {partition_key}.")
            print(f"Downloaded {downloaded_cnt} / {len(url_df)} files in total.")
            # print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
            
            print()
        except Exception as e:
            print("Error:", e)
            continue

print("Done.")
# Out:
# Done.

# %%
# STOP

# Not used below
# Out:
#   Cell In[25], line 3
#     Not used below
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Extract POI

# %%
data_dir = r"D:\SafeGraph\Advan_2023_API\POI\2024\01\07"
save_dir = r'D:\SafeGraph\Advan_2023_API\POI\2024\01\07\South_Carolina'

os.makedirs(save_dir, exist_ok=True)

# %%
all_files = glob(os.path.join(data_dir, "*.gz"))
print("File count:", len(all_files))
print(all_files[0])
print(all_files[-1])
# Out:
# File count: 64
# D:\SafeGraph\Advan_2023_API\POI\2024\01\07\Global_Places_POI_Data-0Global_Places_POI_Data-0_1.csv.gz
# D:\SafeGraph\Advan_2023_API\POI\2024\01\07\Global_Places_POI_Data-9Global_Places_POI_Data-9_10.csv.gz

# %%
countries = ['US']
target_region = ['SC']

# %%
df_list = []
# use_cols = ['PLACEKEY', 'TOP_CATEGORY', 'SUB_CATEGORY', 'NAICS_CODE', 'CITY', 'REGION', 'POSTAL_CODE', 'ISO_COUNTRY_CODE']

for idx, f in enumerate(all_files):
    print(f"Processing: {idx + 1} / {len(all_files)}, ", os.path.basename(f))
    # df = pd.read_csv(f, usecols=use_cols)
    df = pd.read_csv(f)
    t_df = df[df['ISO_COUNTRY_CODE'].isin(countries)] 
    # t_df = df[df['NAICS_CODE'].isin(target_NAICS)]
    # t_df = t_df[t_df['CITY'].isin(target_city)]
    t_df = t_df[t_df['REGION'].isin(target_region)]
    mask = np.logical_and(t_df['NAICS_CODE'].astype(str) < "623", t_df['NAICS_CODE'].astype(str) > "619" ) 
    t_df = t_df[mask]
    
    df_list.append(t_df)
    # break

df_all = pd.concat(df_list)
fname = os.path.join(save_dir, 'South_Carolina_POI_20240107.csv')
df_all.to_csv(fname, index=False)
# print("Saved at:", fname)
df_all
# Out:
# Processing: 1 / 64,  Global_Places_POI_Data-0Global_Places_POI_Data-0_1.csv.gz
# Processing: 2 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-10_11.csv.gz
# Processing: 3 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-11_12.csv.gz
# Processing: 4 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-12_13.csv.gz
# Processing: 5 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-13_14.csv.gz
# Processing: 6 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-14_15.csv.gz
# Processing: 7 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-15_16.csv.gz
# Processing: 8 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-16_17.csv.gz
# Processing: 9 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-17_18.csv.gz
# Processing: 10 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-18_19.csv.gz
# Processing: 11 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-19_20.csv.gz
# Processing: 12 / 64,  Global_Places_POI_Data-1Global_Places_POI_Data-1_2.csv.gz
# Processing: 13 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-20_21.csv.gz
# Processing: 14 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-21_22.csv.gz
# Processing: 15 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-22_23.csv.gz
# Processing: 16 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-23_24.csv.gz
# Processing: 17 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-24_25.csv.gz
# Processing: 18 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-25_26.csv.gz
# Processing: 19 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-26_27.csv.gz
# Processing: 20 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-27_28.csv.gz
# Processing: 21 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-28_29.csv.gz
# Processing: 22 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-29_30.csv.gz
# Processing: 23 / 64,  Global_Places_POI_Data-2Global_Places_POI_Data-2_3.csv.gz
# Processing: 24 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-30_31.csv.gz
# Processing: 25 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-31_32.csv.gz
# Processing: 26 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-32_33.csv.gz
# Processing: 27 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-33_34.csv.gz
# Processing: 28 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-34_35.csv.gz
# Processing: 29 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-35_36.csv.gz
# Processing: 30 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-36_37.csv.gz
# Processing: 31 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-37_38.csv.gz
# Processing: 32 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-38_39.csv.gz
# Processing: 33 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-39_40.csv.gz
# Processing: 34 / 64,  Global_Places_POI_Data-3Global_Places_POI_Data-3_4.csv.gz
# Processing: 35 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-40_41.csv.gz
# Processing: 36 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-41_42.csv.gz
# Processing: 37 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-42_43.csv.gz
# Processing: 38 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-43_44.csv.gz
# Processing: 39 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-44_45.csv.gz
# Processing: 40 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-45_46.csv.gz
# Processing: 41 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-46_47.csv.gz
# Processing: 42 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-47_48.csv.gz
# Processing: 43 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-48_49.csv.gz
# Processing: 44 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-49_50.csv.gz
# Processing: 45 / 64,  Global_Places_POI_Data-4Global_Places_POI_Data-4_5.csv.gz
# Processing: 46 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-50_51.csv.gz
# Processing: 47 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-51_52.csv.gz
# Processing: 48 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-52_53.csv.gz
# Processing: 49 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-53_54.csv.gz
# Processing: 50 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-54_55.csv.gz
# Processing: 51 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-55_56.csv.gz
# Processing: 52 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-56_57.csv.gz
# Processing: 53 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-57_58.csv.gz
# Processing: 54 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-58_59.csv.gz
# Processing: 55 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-59_60.csv.gz
# Processing: 56 / 64,  Global_Places_POI_Data-5Global_Places_POI_Data-5_6.csv.gz
# Processing: 57 / 64,  Global_Places_POI_Data-6Global_Places_POI_Data-60_61.csv.gz
# Processing: 58 / 64,  Global_Places_POI_Data-6Global_Places_POI_Data-61_62.csv.gz
# Processing: 59 / 64,  Global_Places_POI_Data-6Global_Places_POI_Data-62_63.csv.gz
# Processing: 60 / 64,  Global_Places_POI_Data-6Global_Places_POI_Data-63_64.csv.gz
# Processing: 61 / 64,  Global_Places_POI_Data-6Global_Places_POI_Data-6_7.csv.gz
# Processing: 62 / 64,  Global_Places_POI_Data-7Global_Places_POI_Data-7_8.csv.gz
# Processing: 63 / 64,  Global_Places_POI_Data-8Global_Places_POI_Data-8_9.csv.gz
# Processing: 64 / 64,  Global_Places_POI_Data-9Global_Places_POI_Data-9_10.csv.gz
#                     PLACEKEY      PARENT_PLACEKEY               LOCATION_NAME  \
# 598      zzy-222@646-66n-jjv  225-224@646-66p-k2k  Susan Mclean Lpc, Ncc, Cch
# 692      zzy-222@8gc-mfq-mtv  223-222@8gc-mfq-mtv        Dr Shayla Coomer Llc
# 1200     zzw-222@8gh-5rv-qfz                  NaN        Sandra E Hennies MED
# 1724     222-229@646-5pm-cyv                  NaN                  Tara Smith
# 3645     227-222@8gg-jdb-zxq                  NaN     Wade D Reynolds D O Llc
# ...                      ...                  ...                         ...
# 1472409  225-226@8gh-55g-d5f  225-223@8gh-55g-d5f              Mary Woods Lpc
# 1472708  222-24z@8gh-5r6-gff                  NaN         John Bullard Jr. MD
# 1473397  22d-222@8gg-sp8-zpv                  NaN      Complete Pro Home Care
# 1473863  222-22d@8gg-sz2-wzf  222-225@8gg-sz2-wzf               Nigh Steven C
# 1474243  227-222@8g7-b62-y9z                  NaN          Afsar M Waraich MD
#
#         SAFEGRAPH_BRAND_IDS BRANDS  STORE_ID  \
# 598                     NaN    NaN       NaN
# 692                     NaN    NaN       NaN
# 1200                    NaN    NaN       NaN
# 1724                    NaN    NaN       NaN
# 3645                    NaN    NaN       NaN
# ...                     ...    ...       ...
# 1472409                 NaN    NaN       NaN
# 1472708                 NaN    NaN       NaN
# 1473397                 NaN    NaN       NaN
# 1473863                 NaN    NaN       NaN
# 1474243                 NaN    NaN       NaN
#
#                                   TOP_CATEGORY  \
# 598                      Offices of Physicians
# 692                      Offices of Physicians
# 1200     Offices of Other Health Practitioners
# 1724     Offices of Other Health Practitioners
# 3645                     Offices of Physicians
# ...                                        ...
# 1472409                  Offices of Physicians
# 1472708                  Offices of Physicians
# 1473397              Home Health Care Services
# 1473863  Offices of Other Health Practitioners
# 1474243                  Offices of Physicians
#
#                                               SUB_CATEGORY  NAICS_CODE  \
# 598       Offices of Physicians, Mental Health Specialists    621112.0
# 692                                  Offices of Physicians     62111.0
# 1200     Offices of Mental Health Practitioners (except...    621330.0
# 1724     Offices of All Other Miscellaneous Health Prac...    621399.0
# 3645                                 Offices of Physicians     62111.0
# ...                                                    ...         ...
# 1472409   Offices of Physicians, Mental Health Specialists    621112.0
# 1472708  Offices of Physicians (except Mental Health Sp...    621111.0
# 1473397                          Home Health Care Services    621610.0
# 1473863                            Offices of Optometrists    621320.0
# 1474243  Offices of Physicians (except Mental Health Sp...    621111.0
#
#           LATITUDE  LONGITUDE                STREET_ADDRESS            CITY  \
# 598      33.787113 -78.999080  172 Waccamaw Medical Park Ct          Conway
# 692      32.910837 -80.667473          1150 Hungryneck Blvd      Walterboro
# 1200     33.994831 -80.970300                906 Burwell Ln        Columbia
# 1724     33.618352 -78.993203            1945 Glenns Bay Rd  Surfside Beach
# 3645     33.989986 -81.246525               111 Ivy Park Ln       Lexington
# ...            ...        ...                           ...             ...
# 1472409  34.093911 -80.924526     9153 Two Notch Rd Ste C11        Columbia
# 1472708  34.030033 -81.028282              3209 Colonial Dr        Columbia
# 1473397  34.977153 -81.950459            102 Metro Dr Ste 9     Spartanburg
# 1473863  34.851861 -82.336418                765 Haywood Rd      Greenville
# 1474243  33.564489 -81.760605              103 Gregg Ave NW           Aiken
#
#         REGION POSTAL_CODE ISO_COUNTRY_CODE  PHONE_NUMBER  \
# 598         SC       29526               US  1.843457e+10
# 692         SC       29488               US           NaN
# 1200        SC       29205               US  1.803787e+10
# 1724        SC       29575               US  1.843650e+10
# 3645        SC       29072               US           NaN
# ...        ...         ...              ...           ...
# 1472409     SC       29223               US  1.803339e+10
# 1472708     SC       29203               US  1.803435e+10
# 1473397     SC       29303               US  1.864310e+10
# 1473863     SC       29607               US  1.864244e+10
# 1474243     SC       29801               US  1.803227e+10
#
#                                                 OPEN_HOURS  \
# 598                                                    NaN
# 692                                                    NaN
# 1200     { "Mon": [], "Tue": [["8:00", "19:00"]], "Wed"...
# 1724                                                   NaN
# 3645                                                   NaN
# ...                                                    ...
# 1472409                                                NaN
# 1472708                                                NaN
# 1473397  { "Mon": [["9:00", "14:30"]], "Tue": [["9:00",...
# 1473863                                                NaN
# 1474243                                                NaN
#
#               CATEGORY_TAGS OPENED_ON CLOSED_ON TRACKING_CLOSED_SINCE  \
# 598                     NaN       NaN       NaN               2019-07
# 692                     NaN       NaN       NaN               2019-07
# 1200          Mental Health       NaN       NaN               2019-07
# 1724                    NaN       NaN       NaN               2019-07
# 3645                    NaN       NaN       NaN               2019-07
# ...                     ...       ...       ...                   ...
# 1472409                 NaN       NaN       NaN               2019-07
# 1472708                 NaN       NaN       NaN               2019-07
# 1473397                 NaN       NaN       NaN               2019-07
# 1473863        Optometrists       NaN       NaN               2019-07
# 1474243  Gastroenterologist       NaN       NaN               2019-07
#
#         GEOMETRY_TYPE                      DOMAINS  \
# 598           POLYGON                           []
# 692           POLYGON                           []
# 1200          POLYGON       ["sandraehennies.com"]
# 1724          POLYGON                           []
# 3645          POLYGON                           []
# ...               ...                          ...
# 1472409       POLYGON                           []
# 1472708       POLYGON                           []
# 1473397       POLYGON  ["completeprohomecare.com"]
# 1473863       POLYGON         ["eyeexamtoday.com"]
# 1474243       POLYGON            ["pghclinic.com"]
#
#                                 WEBSITE
# 598                                 NaN
# 692                                 NaN
# 1200     https://www.sandraehennies.com
# 1724                                NaN
# 3645                                NaN
# ...                                 ...
# 1472409                             NaN
# 1472708                             NaN
# 1473397  http://completeprohomecare.com
# 1473863        http://eyeexamtoday.com/
# 1474243        http://www.pghclinic.com
#
# [128632 rows x 25 columns]

# %%
df_all

# %%
# Do not merge
df_list = []
# use_cols = ['PLACEKEY', 'TOP_CATEGORY', 'SUB_CATEGORY', 'NAICS_CODE', 'CITY', 'REGION', 'POSTAL_CODE', 'ISO_COUNTRY_CODE']

for idx, f in enumerate(all_files):
    print(f"Processing: {idx + 1} / {len(all_files)}, ", os.path.basename(f))
    # df = pd.read_csv(f, usecols=use_cols)
    basename = os.path.basename(f)
    df = pd.read_csv(f)
    t_df = df[df['ISO_COUNTRY_CODE'].isin(countries)] 
    # t_df = df[df['NAICS_CODE'].isin(target_NAICS)]
    # t_df = t_df[t_df['CITY'].isin(target_city)]
    t_df = t_df[t_df['REGION'].isin(target_region)]
    mask = np.logical_and(t_df['NAICS_CODE'].astype(str) < "623", t_df['NAICS_CODE'].astype(str) > "619" ) 
    t_df = t_df[mask]
    
    fname = os.path.join(save_dir, basename)
    t_df.to_csv(fname, index=False)
    
    # df_list.append(t_df)
    break

# df_all = pd.concat(df_list)

# print("Saved at:", fname)
# df_all
# Out:
# Processing: 1 / 64,  Global_Places_POI_Data-0Global_Places_POI_Data-0_1.csv.gz

# %% [markdown]
# # Help topic in Deweydata community
#
# https://community.deweydata.io/t/residing-device-count-in-2023-07-and-2023-08-surged-abnomorally/26675
