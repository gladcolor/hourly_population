# %% [markdown]
# # Download

# %%
import os
import base64
import requests
import json
import base64 
import tempfile
from urllib.parse import urlparse
from urllib.parse import unquote

import pandas as pd
import numpy as np
from getpass import getpass
from glob import glob
from tqdm import tqdm

access_token = 'J923tlBL.54vRQ2rAhcMc8nhb1v6IZyJwCWUkgG2LA33tHCpJJXhFwilrUhT1ckxJ'

# %% [markdown]
# # Neighborhood patterns

# %% [markdown]
# ## helper function

# %%
def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")

def combine_monthly_pattern_home_panel_summary(data_dir, extend='.csv.gz'):
    print(os.path.join(data_dir, f"*{extend}"))
    all_files = glob(os.path.join(data_dir, f"*{extend}"))

    df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])

    return df
    
    # print(all_files)

# home_panel_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'
# df = combine_monthly_pattern_home_panel_summary(data_dir=home_panel_dir)
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)
# df

# %%
# df.to_csv(r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary\Monthly_Patterns_home_panel_summary_2019_2023.csv', index=False)

# %%
# df.sort_values(['YEAR', 'MON'])
# Out:
#         YEAR  MON REGION ISO_COUNTRY_CODE CENSUS_BLOCK_GROUP  \
# 0       2019    1     AB               CA        CA:48100269
# 1       2019    1     AB               CA        CA:48170226
# 2       2019    1     AB               CA        CA:48070141
# 3       2019    1     AB               CA        CA:48150125
# 4       2019    1     AB               CA        CA:48061778
# ...      ...  ...    ...              ...                ...
# 274363  2023    8     MD               US       245100401001
# 274364  2023    8     GA               US       130210123003
# 274365  2023    8     IN               US       180390016013
# 274366  2023    8     IN               US       180973504001
# 274367  2023    8     OR               US       410510012014
#
#         NUMBER_DEVICES_RESIDING  NUMBER_DEVICES_PRIMARY_DAYTIME
# 0                          11.0                             NaN
# 1                           4.0                             NaN
# 2                          12.0                             NaN
# 3                           1.0                             NaN
# 4                          13.0                             NaN
# ...                         ...                             ...
# 274363                 228079.0                        306687.0
# 274364                  51821.0                         52223.0
# 274365                  52727.0                         52223.0
# 274366                  47359.0                         52223.0
# 274367                  65831.0                         62463.0
#
# [15121291 rows x 7 columns]

# %%
## api_key = r'J923tlBL.54vRQ2rAhcMc8nhb1v6IZyJwCWUkgG2LA33tHCpJJXhFwilrUhT1ckxJ'

 
# neighborhood patterns:
url = r'https://app.deweydata.io/external-api/v3/products/2dfcb598-6e30-49f1-bdba-1deae113a951/files'
# save_dir = r'K:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'   # Dell 2019
save_dir = r'F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns'  # Lenova 2018

# monthly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/5acc9f39-1ca6-4535-b3ff-38f6b9baf85e/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Monthly_Patterns'

# # weekly patterns:
# url = r"https://app.deweydata.io/external-api/v3/products/176f0262-c1f6-4dbe-be43-6a6eb21bcf8a/files"
# save_dir = r'K:\SafeGraph\Advan_2023_API\Weekly_Patterns'

# # hourly weather:
# url = r"https://app.deweydata.io/external-api/v3/products/a6be0385-8820-4943-a509-6eac4154b4f6/files"

# monthly home panel summary
# url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
# save_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary'


os.makedirs(save_dir, exist_ok=True)
# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# loop through all API result pages, keeping track of number of downloaded files
page = 1
download_count = 0

while True:
    # get results from API endpoint, using API key for authentication
    results = requests.get(url=PRODUCT_API_PATH,
                           params={'page': page,
                                   'partition_key_after': '2023-05-30',   # optionally set date value here
                                   'partition_key_before': '2023-09-01', 
                                  }, # optionally set date value here
                           headers={'X-API-KEY': API_KEY,
                                    'accept': 'application/json'
                                   })
    response_json = results.json()
    total_pages = response_json['total_pages']

    link_cnt = len(response_json['download_links'])
 
    # for each result page, loop through download links and save to your computer
    for idx, link_data in enumerate(response_json['download_links']):
        # create file name for each link
        print(f"Downloading {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloading {download_count} files in total, Page {page} / {total_pages}.")
        
        if response_json['partition_column']:
            date = link_data['partition_key']
            year = date[:4]
            month = date[5:7]
            day = date[-2:]
            file_dir = os.path.join(save_dir, year, month, day)
            os.makedirs(file_dir, exist_ok=True)
            print("Year, month, day:", year, month, day)
            # file_name = f"file-{download_count+1}-{response_json['partition_column']}-{link_data['partition_key']}.csv.gz" 
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            # base_name = unquote(base_name) 
            base_name = link_data['file_name']
            
            file_name = os.path.join(file_dir, base_name)
            
        else:
            # not tested
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            # base_name = unquote(base_name) 
            base_name = link_data['file_name']
            
            file_name = os.path.join(file_dir, base_name)
            
        print(f'Downloading file {file_name}')

        if os.path.exists(file_name):
            print(f"File exists, skip! The file is: {file_name} \n")
            continue

        # # loop through download links and save to your computer
        data = requests.get(link_data['link'], stream=True)
        safe_file_write(file_path=file_name, content=data.content)
        
 
             
        download_count += 1
        print(f"Downloaded {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
        
        print()

    # only continue if there are more result pages to process    
    if page >= total_pages:
        break
        
    page += 1
    
    

print(f"Successfully downloaded {download_count} files.")

print("Done")
# returns = results.json()
# print(returns.keys())
# print(len(returns['download_links']))
# del returns['download_links']
# returns
# Out:
# Downloading 1 / 44 files, in Page 1.
# Downloading 0 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-0-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 1 / 44 files, in Page 1.
# Downloaded 1 files in total, Page 1 / 1.
#
# Downloading 2 / 44 files, in Page 1.
# Downloading 1 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-1-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 2 / 44 files, in Page 1.
# Downloaded 2 files in total, Page 1 / 1.
#
# Downloading 3 / 44 files, in Page 1.
# Downloading 2 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-2-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 3 / 44 files, in Page 1.
# Downloaded 3 files in total, Page 1 / 1.
#
# Downloading 4 / 44 files, in Page 1.
# Downloading 3 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-3-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 4 / 44 files, in Page 1.
# Downloaded 4 files in total, Page 1 / 1.
#
# Downloading 5 / 44 files, in Page 1.
# Downloading 4 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-4-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 5 / 44 files, in Page 1.
# Downloaded 5 files in total, Page 1 / 1.
#
# Downloading 6 / 44 files, in Page 1.
# Downloading 5 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-5-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 6 / 44 files, in Page 1.
# Downloaded 6 files in total, Page 1 / 1.
#
# Downloading 7 / 44 files, in Page 1.
# Downloading 6 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-6-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 7 / 44 files, in Page 1.
# Downloaded 7 files in total, Page 1 / 1.
#
# Downloading 8 / 44 files, in Page 1.
# Downloading 7 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-7-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 8 / 44 files, in Page 1.
# Downloaded 8 files in total, Page 1 / 1.
#
# Downloading 9 / 44 files, in Page 1.
# Downloading 8 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-8-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 9 / 44 files, in Page 1.
# Downloaded 9 files in total, Page 1 / 1.
#
# Downloading 10 / 44 files, in Page 1.
# Downloading 9 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-9-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 10 / 44 files, in Page 1.
# Downloaded 10 files in total, Page 1 / 1.
#
# Downloading 11 / 44 files, in Page 1.
# Downloading 10 files in total, Page 1 / 1.
# Year, month, day: 2023 06 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\06\01\Neighborhood_Patterns_US-10-DATE_RANGE_START-2023-06-01.csv.gz
# File successfully written.
# Downloaded 11 / 44 files, in Page 1.
# Downloaded 11 files in total, Page 1 / 1.
#
# Downloading 12 / 44 files, in Page 1.
# Downloading 11 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-11-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 12 / 44 files, in Page 1.
# Downloaded 12 files in total, Page 1 / 1.
#
# Downloading 13 / 44 files, in Page 1.
# Downloading 12 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-12-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 13 / 44 files, in Page 1.
# Downloaded 13 files in total, Page 1 / 1.
#
# Downloading 14 / 44 files, in Page 1.
# Downloading 13 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-13-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 14 / 44 files, in Page 1.
# Downloaded 14 files in total, Page 1 / 1.
#
# Downloading 15 / 44 files, in Page 1.
# Downloading 14 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-14-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 15 / 44 files, in Page 1.
# Downloaded 15 files in total, Page 1 / 1.
#
# Downloading 16 / 44 files, in Page 1.
# Downloading 15 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-15-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 16 / 44 files, in Page 1.
# Downloaded 16 files in total, Page 1 / 1.
#
# Downloading 17 / 44 files, in Page 1.
# Downloading 16 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-16-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 17 / 44 files, in Page 1.
# Downloaded 17 files in total, Page 1 / 1.
#
# Downloading 18 / 44 files, in Page 1.
# Downloading 17 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-17-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 18 / 44 files, in Page 1.
# Downloaded 18 files in total, Page 1 / 1.
#
# Downloading 19 / 44 files, in Page 1.
# Downloading 18 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-18-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 19 / 44 files, in Page 1.
# Downloaded 19 files in total, Page 1 / 1.
#
# Downloading 20 / 44 files, in Page 1.
# Downloading 19 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-19-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 20 / 44 files, in Page 1.
# Downloaded 20 files in total, Page 1 / 1.
#
# Downloading 21 / 44 files, in Page 1.
# Downloading 20 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-20-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 21 / 44 files, in Page 1.
# Downloaded 21 files in total, Page 1 / 1.
#
# Downloading 22 / 44 files, in Page 1.
# Downloading 21 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-21-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 22 / 44 files, in Page 1.
# Downloaded 22 files in total, Page 1 / 1.
#
# Downloading 23 / 44 files, in Page 1.
# Downloading 22 files in total, Page 1 / 1.
# Year, month, day: 2023 07 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\07\01\Neighborhood_Patterns_US-22-DATE_RANGE_START-2023-07-01.csv.gz
# File successfully written.
# Downloaded 23 / 44 files, in Page 1.
# Downloaded 23 files in total, Page 1 / 1.
#
# Downloading 24 / 44 files, in Page 1.
# Downloading 23 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-23-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 24 / 44 files, in Page 1.
# Downloaded 24 files in total, Page 1 / 1.
#
# Downloading 25 / 44 files, in Page 1.
# Downloading 24 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-24-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 25 / 44 files, in Page 1.
# Downloaded 25 files in total, Page 1 / 1.
#
# Downloading 26 / 44 files, in Page 1.
# Downloading 25 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-25-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 26 / 44 files, in Page 1.
# Downloaded 26 files in total, Page 1 / 1.
#
# Downloading 27 / 44 files, in Page 1.
# Downloading 26 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-26-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 27 / 44 files, in Page 1.
# Downloaded 27 files in total, Page 1 / 1.
#
# Downloading 28 / 44 files, in Page 1.
# Downloading 27 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-27-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 28 / 44 files, in Page 1.
# Downloaded 28 files in total, Page 1 / 1.
#
# Downloading 29 / 44 files, in Page 1.
# Downloading 28 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-28-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 29 / 44 files, in Page 1.
# Downloaded 29 files in total, Page 1 / 1.
#
# Downloading 30 / 44 files, in Page 1.
# Downloading 29 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-29-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 30 / 44 files, in Page 1.
# Downloaded 30 files in total, Page 1 / 1.
#
# Downloading 31 / 44 files, in Page 1.
# Downloading 30 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-30-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 31 / 44 files, in Page 1.
# Downloaded 31 files in total, Page 1 / 1.
#
# Downloading 32 / 44 files, in Page 1.
# Downloading 31 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-31-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 32 / 44 files, in Page 1.
# Downloaded 32 files in total, Page 1 / 1.
#
# Downloading 33 / 44 files, in Page 1.
# Downloading 32 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-32-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 33 / 44 files, in Page 1.
# Downloaded 33 files in total, Page 1 / 1.
#
# Downloading 34 / 44 files, in Page 1.
# Downloading 33 files in total, Page 1 / 1.
# Year, month, day: 2023 08 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\08\01\Neighborhood_Patterns_US-33-DATE_RANGE_START-2023-08-01.csv.gz
# File successfully written.
# Downloaded 34 / 44 files, in Page 1.
# Downloaded 34 files in total, Page 1 / 1.
#
# Downloading 35 / 44 files, in Page 1.
# Downloading 34 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-34-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 35 / 44 files, in Page 1.
# Downloaded 35 files in total, Page 1 / 1.
#
# Downloading 36 / 44 files, in Page 1.
# Downloading 35 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-35-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 36 / 44 files, in Page 1.
# Downloaded 36 files in total, Page 1 / 1.
#
# Downloading 37 / 44 files, in Page 1.
# Downloading 36 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-36-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 37 / 44 files, in Page 1.
# Downloaded 37 files in total, Page 1 / 1.
#
# Downloading 38 / 44 files, in Page 1.
# Downloading 37 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-37-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 38 / 44 files, in Page 1.
# Downloaded 38 files in total, Page 1 / 1.
#
# Downloading 39 / 44 files, in Page 1.
# Downloading 38 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-38-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 39 / 44 files, in Page 1.
# Downloaded 39 files in total, Page 1 / 1.
#
# Downloading 40 / 44 files, in Page 1.
# Downloading 39 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-39-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 40 / 44 files, in Page 1.
# Downloaded 40 files in total, Page 1 / 1.
#
# Downloading 41 / 44 files, in Page 1.
# Downloading 40 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-40-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 41 / 44 files, in Page 1.
# Downloaded 41 files in total, Page 1 / 1.
#
# Downloading 42 / 44 files, in Page 1.
# Downloading 41 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-41-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 42 / 44 files, in Page 1.
# Downloaded 42 files in total, Page 1 / 1.
#
# Downloading 43 / 44 files, in Page 1.
# Downloading 42 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-42-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 43 / 44 files, in Page 1.
# Downloaded 43 files in total, Page 1 / 1.
#
# Downloading 44 / 44 files, in Page 1.
# Downloading 43 files in total, Page 1 / 1.
# Year, month, day: 2023 09 01
# Downloading file F:\SafeGraph\Advan_2023_API\Neighborhood_Patterns\2023\09\01\Neighborhood_Patterns_US-43-DATE_RANGE_START-2023-09-01.csv.gz
# File successfully written.
# Downloaded 44 / 44 files, in Page 1.
# Downloaded 44 files in total, Page 1 / 1.
#
# Successfully downloaded 44 files.
# Done

# %%
response_json
# Out:
# {'download_links': [{'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-0-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=GZYCZQq3jDtBaklVVdSzeBnmFg4%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-0-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_10.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-1-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=LA1Pyf0JvzlcP4baOJ5e4Q4XXOs%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-1-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_1.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-2-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=sG%2FBGU%2FQt6NcZO6H7nfGbymqBvQ%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-2-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_2.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-3-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=U830juzFohrxB6jpfl%2Fcx4%2Fjuj8%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-3-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_3.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-4-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=VYxGlMoBD0nq6y5YoHR%2B9tp%2FqnU%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-4-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_4.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-5-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=o1mFv1uXw2kluNGQuHXGYVSZobk%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-5-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_5.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-6-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=2ufoCARTqwRMQ6Rb3i0HMbWoUp4%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-6-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_6.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-7-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=9wYMiNN40S8hq4AxH2YEia5SWjs%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-7-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_7.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-8-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=i6t%2Bs6un1HqFwP7OqwJwtQ%2FkEBg%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-8-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_8.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-9-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=Ip3OlgklT9%2BqhcInod%2BsVbzU2rU%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-9-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-06-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_1_9.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-10-DATE_RANGE_START-2023-06-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=lain%2BWTXhnxpkHH7Aig3l4Emz3c%3D&Expires=1697416324',
#    'partition_key': '2023-06-01',
#    'file_name': 'Neighborhood_Patterns_US-10-DATE_RANGE_START-2023-06-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-11-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=%2BONyz0VwiwQa9QONtjAQY%2BkuEN8%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-11-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_10.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-12-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=yMSD8g0tKeoBzJ5Lqn1Hqz17AUI%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-12-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_11.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-13-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=v6uF0Za53v00qCbPM5woTVh6emg%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-13-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_1.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-14-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=mr%2F0vX5r5acsoGyhIJWYv%2FSdVs0%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-14-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_2.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-15-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=jwEFxy4ubleR5uWLsCWvD0uguqA%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-15-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_3.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-16-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=oSzzmRvADzqjWDsS2JqDqBlavhA%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-16-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_4.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-17-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=MUIzd2uAMkg36pn0GO12v2IT%2FiU%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-17-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_5.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-18-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=4VQJwoViy6rVzAUV6MlDpd77szY%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-18-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_6.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-19-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=5YAzjFTuTFOqtbDxueGwgA9sPms%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-19-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_7.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-20-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=NuRq8aMxRdR0twbX%2BeX5KPMRPEI%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-20-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_8.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-21-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=stLo2E14pWbVmirb229KX8b5%2BEY%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-21-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-07-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_23_3_9.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-22-DATE_RANGE_START-2023-07-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=R9mi%2FZ35Sx%2B2Ua2fClqJ1R84DLY%3D&Expires=1697416324',
#    'partition_key': '2023-07-01',
#    'file_name': 'Neighborhood_Patterns_US-22-DATE_RANGE_START-2023-07-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-23-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=6ueYYWgmngV4Ef%2FCRHxKpn4nuSc%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-23-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_10.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-24-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=txAZLRcDf1W4z3j2XxmQHx118R8%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-24-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_1.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-25-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=i2pr5ZdUgO8Gyczg3wUMVfuXODM%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-25-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_2.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-26-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=UWfYUhNzXhc1L4yHTtsAwFn4UtA%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-26-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_3.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-27-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=%2BCeBZnSnYE41u0nGnqzZGuUUKv0%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-27-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_4.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-28-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=L83MZf3th08abvhicuLqPxztSNY%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-28-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_5.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-29-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=vaRdAvtKkGd1owhlkVjGfi3VW1s%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-29-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_6.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-30-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=lbyOOqCOec9RkA%2FCrn9kryOKxsA%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-30-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_7.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-31-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=6Qwc5DiB7QSv1%2Bx3y7%2FdVRpP3BU%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-31-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_8.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-32-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=uz3EWau5V47YBmLKlyhX67c3uk4%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-32-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-08-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_43_5_9.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-33-DATE_RANGE_START-2023-08-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=AP2h02USy5KsC%2Bg3SZoscuvSbqY%3D&Expires=1697416324',
#    'partition_key': '2023-08-01',
#    'file_name': 'Neighborhood_Patterns_US-33-DATE_RANGE_START-2023-08-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-34-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=O3oI4MEr12JU24HosGadJMlOQfU%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-34-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_1.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-35-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=Hh3OElt7hxEQcvcm6s47ugNn3wg%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-35-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_2.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-36-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=rKU%2FOFf4SMi1ackoUWeS%2Fnl%2BX10%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-36-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_3.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-37-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=JlaJoo%2BzzwBRzTOdWm0L5Kd2CX0%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-37-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_4.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-38-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=0Unpq0zmC3d0mQgYOWbhHobyxZ8%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-38-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_5.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-39-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=JiS8%2BL4PWgEKhuGtwXKXzHudrt8%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-39-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_6.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-40-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=BQiK7bAv0zGdCZOJpvOp1K80xqQ%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-40-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_7.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-41-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=yf%2FpWvUvfKNkbwSNVzCDBPdrNzg%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-41-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_8.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-42-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=sotZLdxmF8E1FaPkMb84z%2BpQdSk%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-42-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Neighborhood%20Patterns%20-%20US--2dfcb598-6e30-49f1-bdba-1deae113a951/2023-09-01/data_01af8afd-0604-c38b-0043-0b8700fd8e5a_53_3_9.csv.gz?response-content-disposition=attachment%3B%20filename%3DNeighborhood_Patterns_US-43-DATE_RANGE_START-2023-09-01.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=%2BuaILYJldSlYTMO35Vz9iBc8kdg%3D&Expires=1697416324',
#    'partition_key': '2023-09-01',
#    'file_name': 'Neighborhood_Patterns_US-43-DATE_RANGE_START-2023-09-01.csv.gz',
#    'file_extension': '.csv.gz'}],
#  'page': 1,
#  'number_of_files_for_page': 44,
#  'avg_file_size_for_page': 202277098.8,
#  'partition_column': 'DATE_RANGE_START',
#  'total_files': 44,
#  'total_pages': 1,
#  'total_size': 8900192346,
#  'expires_at': '2023-10-16T00:32:04.130Z'}

# %% [markdown]
# # Download monthly patterns home panel summary

# %%
api_key = r'J923tlBL.54vRQ2rAhcMc8nhb1v6IZyJwCWUkgG2LA33tHCpJJXhFwilrUhT1ckxJ'

# monthly home panel summary
url = r'https://app.deweydata.io/external-api/v3/products/8546740c-b0e9-4556-abb9-4bea2cca9ac9/files'
save_dir = r'F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23'
os.makedirs(save_dir, exist_ok=True)

# set key and API endpoint variables
API_KEY = access_token
PRODUCT_API_PATH = url

# loop through all API result pages, keeping track of number of downloaded files
page = 1
download_count = 0

while True:
    # get results from API endpoint, using API key for authentication
    results = requests.get(url=PRODUCT_API_PATH,
                           params={'page': page,
                                   # 'partition_key_after': '2023-05-30',   # optionally set date value here
                                   # 'partition_key_before': '2023-09-01', 
                                  }, # optionally set date value here
                           headers={'X-API-KEY': API_KEY,
                                    'accept': 'application/json'
                                   })
    response_json = results.json()
    total_pages = response_json['total_pages']

    link_cnt = len(response_json['download_links'])
     
    # for each result page, loop through download links and save to your computer
    for idx, link_data in enumerate(response_json['download_links']):
        # create file name for each link
        print(f"Downloading {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloading {download_count} files in total, Page {page} / {total_pages}.")
        
        if response_json['partition_column']:
            date = link_data['partition_key']
            # year = date[:4]
            # month = date[5:7]
            # day = date[-2:]
     
            
            # print("Year, month, day:", year, month, day)
            # file_name = f"file-{download_count+1}-{response_json['partition_column']}-{link_data['partition_key']}.csv.gz" 
            # url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            # base_name = os.path.basename(path)
            base_name = link_data['file_name']
            
            
            
        else:
            # not tested
            url = link_data['link']
            # parsed_url = urlparse(url)
            # path = parsed_url.path
            base_name = link_data['file_name']
            file_name = os.path.join(save_dir, base_name)
            
            
        print(f'Downloading file {file_name}')

        if os.path.exists(file_name):
            print(f"File exists, skip! The file is: {file_name} \n")
            continue

        # # loop through download links and save to your computer
        data = requests.get(link_data['link'], stream=True)
        safe_file_write(file_path=file_name, content=data.content)
        
        
        # with open(file_name, 'wb') as file:            
        #     file.write(data.content)
             
        download_count += 1
        print(f"Downloaded {idx + 1} / {link_cnt} files, in Page {page}.")
        print(f"Downloaded {download_count} files in total, Page {page} / {total_pages}.")
        
        print()

    # only continue if there are more result pages to process
    
    if page >= total_pages:
        break
        
    page += 1
    
    

print(f"Successfully downloaded {download_count} files.")

print("Done")
# returns = results.json()
# print(returns.keys())
# print(len(returns['download_links']))
# del returns['download_links']
# returns
# Out:
# Downloading 1 / 45 files, in Page 1.
# Downloading 0 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-0.csv.gz
# File successfully written.
# Downloaded 1 / 45 files, in Page 1.
# Downloaded 1 files in total, Page 1 / 1.
#
# Downloading 2 / 45 files, in Page 1.
# Downloading 1 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-1.csv.gz
# File successfully written.
# Downloaded 2 / 45 files, in Page 1.
# Downloaded 2 files in total, Page 1 / 1.
#
# Downloading 3 / 45 files, in Page 1.
# Downloading 2 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-2.csv.gz
# File successfully written.
# Downloaded 3 / 45 files, in Page 1.
# Downloaded 3 files in total, Page 1 / 1.
#
# Downloading 4 / 45 files, in Page 1.
# Downloading 3 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-3.csv.gz
# File successfully written.
# Downloaded 4 / 45 files, in Page 1.
# Downloaded 4 files in total, Page 1 / 1.
#
# Downloading 5 / 45 files, in Page 1.
# Downloading 4 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-4.csv.gz
# File successfully written.
# Downloaded 5 / 45 files, in Page 1.
# Downloaded 5 files in total, Page 1 / 1.
#
# Downloading 6 / 45 files, in Page 1.
# Downloading 5 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-5.csv.gz
# File successfully written.
# Downloaded 6 / 45 files, in Page 1.
# Downloaded 6 files in total, Page 1 / 1.
#
# Downloading 7 / 45 files, in Page 1.
# Downloading 6 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-6.csv.gz
# File successfully written.
# Downloaded 7 / 45 files, in Page 1.
# Downloaded 7 files in total, Page 1 / 1.
#
# Downloading 8 / 45 files, in Page 1.
# Downloading 7 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-7.csv.gz
# File successfully written.
# Downloaded 8 / 45 files, in Page 1.
# Downloaded 8 files in total, Page 1 / 1.
#
# Downloading 9 / 45 files, in Page 1.
# Downloading 8 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-8.csv.gz
# File successfully written.
# Downloaded 9 / 45 files, in Page 1.
# Downloaded 9 files in total, Page 1 / 1.
#
# Downloading 10 / 45 files, in Page 1.
# Downloading 9 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-9.csv.gz
# File successfully written.
# Downloaded 10 / 45 files, in Page 1.
# Downloaded 10 files in total, Page 1 / 1.
#
# Downloading 11 / 45 files, in Page 1.
# Downloading 10 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-10.csv.gz
# File successfully written.
# Downloaded 11 / 45 files, in Page 1.
# Downloaded 11 files in total, Page 1 / 1.
#
# Downloading 12 / 45 files, in Page 1.
# Downloading 11 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-11.csv.gz
# File successfully written.
# Downloaded 12 / 45 files, in Page 1.
# Downloaded 12 files in total, Page 1 / 1.
#
# Downloading 13 / 45 files, in Page 1.
# Downloading 12 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-12.csv.gz
# File successfully written.
# Downloaded 13 / 45 files, in Page 1.
# Downloaded 13 files in total, Page 1 / 1.
#
# Downloading 14 / 45 files, in Page 1.
# Downloading 13 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-13.csv.gz
# File successfully written.
# Downloaded 14 / 45 files, in Page 1.
# Downloaded 14 files in total, Page 1 / 1.
#
# Downloading 15 / 45 files, in Page 1.
# Downloading 14 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-14.csv.gz
# File successfully written.
# Downloaded 15 / 45 files, in Page 1.
# Downloaded 15 files in total, Page 1 / 1.
#
# Downloading 16 / 45 files, in Page 1.
# Downloading 15 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-15.csv.gz
# File successfully written.
# Downloaded 16 / 45 files, in Page 1.
# Downloaded 16 files in total, Page 1 / 1.
#
# Downloading 17 / 45 files, in Page 1.
# Downloading 16 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-16.csv.gz
# File successfully written.
# Downloaded 17 / 45 files, in Page 1.
# Downloaded 17 files in total, Page 1 / 1.
#
# Downloading 18 / 45 files, in Page 1.
# Downloading 17 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-17.csv.gz
# File successfully written.
# Downloaded 18 / 45 files, in Page 1.
# Downloaded 18 files in total, Page 1 / 1.
#
# Downloading 19 / 45 files, in Page 1.
# Downloading 18 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-18.csv.gz
# File successfully written.
# Downloaded 19 / 45 files, in Page 1.
# Downloaded 19 files in total, Page 1 / 1.
#
# Downloading 20 / 45 files, in Page 1.
# Downloading 19 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-19.csv.gz
# File successfully written.
# Downloaded 20 / 45 files, in Page 1.
# Downloaded 20 files in total, Page 1 / 1.
#
# Downloading 21 / 45 files, in Page 1.
# Downloading 20 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-20.csv.gz
# File successfully written.
# Downloaded 21 / 45 files, in Page 1.
# Downloaded 21 files in total, Page 1 / 1.
#
# Downloading 22 / 45 files, in Page 1.
# Downloading 21 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-21.csv.gz
# File successfully written.
# Downloaded 22 / 45 files, in Page 1.
# Downloaded 22 files in total, Page 1 / 1.
#
# Downloading 23 / 45 files, in Page 1.
# Downloading 22 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-22.csv.gz
# File successfully written.
# Downloaded 23 / 45 files, in Page 1.
# Downloaded 23 files in total, Page 1 / 1.
#
# Downloading 24 / 45 files, in Page 1.
# Downloading 23 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-23.csv.gz
# File successfully written.
# Downloaded 24 / 45 files, in Page 1.
# Downloaded 24 files in total, Page 1 / 1.
#
# Downloading 25 / 45 files, in Page 1.
# Downloading 24 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-24.csv.gz
# File successfully written.
# Downloaded 25 / 45 files, in Page 1.
# Downloaded 25 files in total, Page 1 / 1.
#
# Downloading 26 / 45 files, in Page 1.
# Downloading 25 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-25.csv.gz
# File successfully written.
# Downloaded 26 / 45 files, in Page 1.
# Downloaded 26 files in total, Page 1 / 1.
#
# Downloading 27 / 45 files, in Page 1.
# Downloading 26 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-26.csv.gz
# File successfully written.
# Downloaded 27 / 45 files, in Page 1.
# Downloaded 27 files in total, Page 1 / 1.
#
# Downloading 28 / 45 files, in Page 1.
# Downloading 27 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-27.csv.gz
# File successfully written.
# Downloaded 28 / 45 files, in Page 1.
# Downloaded 28 files in total, Page 1 / 1.
#
# Downloading 29 / 45 files, in Page 1.
# Downloading 28 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-28.csv.gz
# File successfully written.
# Downloaded 29 / 45 files, in Page 1.
# Downloaded 29 files in total, Page 1 / 1.
#
# Downloading 30 / 45 files, in Page 1.
# Downloading 29 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-29.csv.gz
# File successfully written.
# Downloaded 30 / 45 files, in Page 1.
# Downloaded 30 files in total, Page 1 / 1.
#
# Downloading 31 / 45 files, in Page 1.
# Downloading 30 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-30.csv.gz
# File successfully written.
# Downloaded 31 / 45 files, in Page 1.
# Downloaded 31 files in total, Page 1 / 1.
#
# Downloading 32 / 45 files, in Page 1.
# Downloading 31 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-31.csv.gz
# File successfully written.
# Downloaded 32 / 45 files, in Page 1.
# Downloaded 32 files in total, Page 1 / 1.
#
# Downloading 33 / 45 files, in Page 1.
# Downloading 32 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-32.csv.gz
# File successfully written.
# Downloaded 33 / 45 files, in Page 1.
# Downloaded 33 files in total, Page 1 / 1.
#
# Downloading 34 / 45 files, in Page 1.
# Downloading 33 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-33.csv.gz
# File successfully written.
# Downloaded 34 / 45 files, in Page 1.
# Downloaded 34 files in total, Page 1 / 1.
#
# Downloading 35 / 45 files, in Page 1.
# Downloading 34 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-34.csv.gz
# File successfully written.
# Downloaded 35 / 45 files, in Page 1.
# Downloaded 35 files in total, Page 1 / 1.
#
# Downloading 36 / 45 files, in Page 1.
# Downloading 35 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-35.csv.gz
# File successfully written.
# Downloaded 36 / 45 files, in Page 1.
# Downloaded 36 files in total, Page 1 / 1.
#
# Downloading 37 / 45 files, in Page 1.
# Downloading 36 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-36.csv.gz
# File successfully written.
# Downloaded 37 / 45 files, in Page 1.
# Downloaded 37 files in total, Page 1 / 1.
#
# Downloading 38 / 45 files, in Page 1.
# Downloading 37 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-37.csv.gz
# File successfully written.
# Downloaded 38 / 45 files, in Page 1.
# Downloaded 38 files in total, Page 1 / 1.
#
# Downloading 39 / 45 files, in Page 1.
# Downloading 38 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-38.csv.gz
# File successfully written.
# Downloaded 39 / 45 files, in Page 1.
# Downloaded 39 files in total, Page 1 / 1.
#
# Downloading 40 / 45 files, in Page 1.
# Downloading 39 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-39.csv.gz
# File successfully written.
# Downloaded 40 / 45 files, in Page 1.
# Downloaded 40 files in total, Page 1 / 1.
#
# Downloading 41 / 45 files, in Page 1.
# Downloading 40 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-40.csv.gz
# File successfully written.
# Downloaded 41 / 45 files, in Page 1.
# Downloaded 41 files in total, Page 1 / 1.
#
# Downloading 42 / 45 files, in Page 1.
# Downloading 41 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-41.csv.gz
# File successfully written.
# Downloaded 42 / 45 files, in Page 1.
# Downloaded 42 files in total, Page 1 / 1.
#
# Downloading 43 / 45 files, in Page 1.
# Downloading 42 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-42.csv.gz
# File successfully written.
# Downloaded 43 / 45 files, in Page 1.
# Downloaded 43 files in total, Page 1 / 1.
#
# Downloading 44 / 45 files, in Page 1.
# Downloading 43 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-43.csv.gz
# File successfully written.
# Downloaded 44 / 45 files, in Page 1.
# Downloaded 44 files in total, Page 1 / 1.
#
# Downloading 45 / 45 files, in Page 1.
# Downloading 44 files in total, Page 1 / 1.
# Downloading file F:\SafeGraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23\Monthly_Patterns_Home_Panel_Summary-44.csv.gz
# File successfully written.
# Downloaded 45 / 45 files, in Page 1.
# Downloaded 45 files in total, Page 1 / 1.
#
# Successfully downloaded 45 files.
# Done

# %%
response_json
# Out:
# {'download_links': [{'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_0_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-0.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=4cgyu7NVnmpsJdAuNdMUNyaYziQ%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-0.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1672997,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_10_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-1.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=5%2B5T7Mt%2BfaUqttGCIcHJmOfc4sA%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-1.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1645829,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_1_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-2.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=BiWiXJtBTLdxCgjKhl9qETMwKSs%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-2.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3266324,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_11_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-3.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=oM4juxFRh0tODk9IU7TQB8DdPhU%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-3.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1580716,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_11_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-4.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=RUzuaRqW6xv2gnbvlAp%2FiW3yyQg%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-4.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3254016,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_1_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-5.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=UyU47JHlPteOZibh9eAGhOnlR1o%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-5.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1556364,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_12_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-6.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=cetIBvHX%2Fd%2Fh1F3T7kDpQrNplYw%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-6.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3396715,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_13_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-7.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=05lEgm8JjvDEY6E4t%2BvTcEDavTU%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-7.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1603612,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_14_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-8.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=jQJsi2X0Lnv4B6xWqRCnKlSeJt4%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-8.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 2404968,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_15_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-9.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=zuko34q3M4Yvf1ZwLryPA0A0h04%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-9.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1582915,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_15_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-10.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=cMMZ%2Fk5HffM%2FKFG4c3ReK3vWbS4%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-10.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1663063,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_16_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-11.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=MiP4%2FHv2tWA0KXTkLaOzappte80%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-11.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1641793,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_16_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-12.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=kbv%2BSG0btGMOXTrKZjlulwPnPGY%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-12.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1588425,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_17_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-13.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=xB%2Fd%2BeFg%2FEvenZc05AJLY6H%2FhKc%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-13.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1582954,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_18_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-14.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=rH%2FhMi7KRvil0eUEfv2mCbhBjA4%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-14.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1816272,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_18_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-15.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=MrlDTMwHiRU%2BNluCjCqchWhW5gk%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-15.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3296368,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_19_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-16.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=l6ehmUQNM3A5Z1bQZ%2BMfBNGJ7k0%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-16.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3321985,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_19_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-17.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=8FHmTpMoVfuX4ujT7NN7C1AxQmA%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-17.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1652253,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_19_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-18.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=HbcWRVdavHvLXs1UXVlaeR2woQE%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-18.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1624877,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_20_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-19.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=3F%2F6COZeuzoX51B1RcFaXdhfvQU%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-19.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1685254,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_20_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-20.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=JjZUYft8VV6iKKQboYuKr7noVsk%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-20.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3385146,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_21_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-21.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=3hnvY7JfulSCvLt2hRi1o1uKz4w%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-21.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1574218,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_2_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-22.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=sACj%2BgJSmAmm5N0j%2FHSAdjW5gcM%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-22.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1591376,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_22_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-23.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=pLiyXeOjYDAwDKAuLFDJgHNquac%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-23.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1566179,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_23_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-24.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=gdXr1wxF%2Fu4yIp4rftMFwy%2ByIs4%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-24.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1638248,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_2_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-25.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=3mZ9YQy3qVgy7zt7PmlEDdojT78%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-25.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1597837,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_23_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-26.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=qxUm%2B0KT%2FA7yKVtEnYitO9EVbUw%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-26.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3338448,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_24_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-27.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=5hZd5NIDJaOYfYvM3ubtnFYTLBo%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-27.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3194880,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_25_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-28.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=YIMaLE7kLA9lurf20O84wxMM378%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-28.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3392858,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_26_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-29.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=6Ue57RKCT0bi9Rp6itAhT7CQmLA%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-29.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1647365,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_27_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-30.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=fC%2B3SWZFaGkMDuocW3%2B66AiAdzY%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-30.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1591695,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_28_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-31.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=7zBiod7GsFnh1y12%2BUt7U0LHXZU%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-31.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3137804,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_28_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-32.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=J3fGBiDUPmLOtHbB%2BCiZ%2Bz6rXCQ%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-32.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1577745,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_29_0_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-33.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=yoqLCsQZB0XdqNYOslkk9Fz48YE%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-33.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3280204,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_29_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-34.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=o2vhVpLDGXT5n%2F5tOE9Q7iBGDL4%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-34.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1603988,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_30_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-35.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=VgoEObWPuLbuiS7%2Fj%2B7B4FIJ2to%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-35.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3399305,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_3_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-36.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=Ix3UAIJeg%2FsNgoh%2FYKzirdVnc7A%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-36.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1633459,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_4_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-37.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=O3IHr1LGHTcyMi5pXrzMD3w165s%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-37.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1667309,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_5_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-38.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=BEYLskH59KpgSt3Cr0dThQWCwSI%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-38.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1623651,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_6_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-39.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=AYPEZe7mwW4qjdexCID%2F5%2B7cQdQ%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-39.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1589475,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_6_3_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-40.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=5DMZ7hUUtT5GyA3pUTTvniYqj6U%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-40.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1606266,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_7_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-41.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=50mQ4W70urzBMMxW60tjpMB%2FRZo%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-41.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 2214532,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_8_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-42.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=dnKSVQy9ftlDdW60CHVKTVmNt7s%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-42.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1625478,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_9_1_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-43.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=9JPiARprlkMBlIDesm5w9sG0JFA%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-43.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 1624423,
#    'modified_at': '2023-11-09T09:03:46Z'},
#   {'link': 'https://amplifydata-production-dewey.s3.amazonaws.com/Monthly%20Patterns%20-%20Home%20Panel%20Summary--8546740c-b0e9-4556-abb9-4bea2cca9ac9/data_9_2_0.csv.gz?response-content-disposition=attachment%3B%20filename%3DMonthly_Patterns_Home_Panel_Summary-44.csv.gz&AWSAccessKeyId=AKIASC5E62QHCPMXWWSX&Signature=iHNoHAiFXJMVa4SUVuDPVoW6EMA%3D&Expires=1700851272',
#    'partition_key': None,
#    'file_name': 'Monthly_Patterns_Home_Panel_Summary-44.csv.gz',
#    'file_extension': '.csv.gz',
#    'file_size_bytes': 3336670,
#    'modified_at': '2023-11-09T09:03:46Z'}],
#  'page': 1,
#  'number_of_files_for_page': 45,
#  'avg_file_size_for_page': 2139472.4,
#  'partition_column': None,
#  'total_files': 45,
#  'total_pages': 1,
#  'total_size': 96276259,
#  'expires_at': '2023-11-24T18:41:12.579Z'}

# %% [markdown]
# # Stop

# %%
Stop

# %% [markdown]
# # Not used below

# %%
import pandas as pd
import numpy as np
import json
import base64
import requests
# from posixpath import basename
import os
import requests
import time
import tempfile

def get_access_token(account="hning@email.sc.edu", password="Nhwwdewey2022,", verbose=True):
    # un =  # Set username
    # pw = # Set password

    credentials = f"{account}:{password}" # Format credentials according to the API's expectations
    # print(credentials)

    credentials_bytes = credentials.encode('ascii')
    base64_credentials_bytes = base64.b64encode(credentials_bytes)
    base64_credentials = base64_credentials_bytes.decode('ascii')
    # print(base64_credentials)


    headers = {
        'accept': 'application/json',
        'Authorization': f'Basic {base64_credentials}'
    }

    response = requests.post("https://marketplace.deweydata.io/api/auth/tks/get_token", headers=headers)
    
    access_token = response.json()['access_token']
    
    if verbose:
        print(response.json())
        print(access_token)
    
    return access_token

def safe_file_write(file_path, content):
    # Create a temporary file in the same directory as the target file
    dir_name = os.path.dirname(file_path)
    with tempfile.NamedTemporaryFile(mode='wb', dir=dir_name, delete=False) as temp_file:
        try:
            # Write the content to the temporary file
            temp_file.write(content)
            temp_file.flush()
            os.fsync(temp_file.fileno())
            temp_file.close()

            # Rename the temporary file to the target file (atomic operation)
            os.replace(temp_file.name, file_path)
        except Exception as e:
            # Handle the exception (e.g., log it, raise it, or silently ignore it)
            print(f"An error occurred while writing the file: {e}")
            os.unlink(temp_file.name)
        else:
            print("File successfully written.")
            
            
# Main function
def download_all_files(save_dir, headers, override=False):
 
    init_url = r'/api/data/v2/list'
    home_url = 'https://marketplace.deweydata.io'    
    web_dir_list = [init_url]
    
    print("Started...")
    
    skipped_cnt = 0
    while len(web_dir_list) > 0:
        try:
            # web_dir = web_dir_list.pop()
            # print("web_dir_list:", web_dir_list)
            web_dir = web_dir_list.pop()   # Get the latest file
            
            
            url = home_url + web_dir
            # print(url, web_dir)
            items = requests.get(url, headers=headers).json()
            # print(requests.get(url, headers=headers).url)
            
            items = items[::-1]  # Put the latest file in the end.
 

            for item in items:
                name = item['name']
                if item['directory']:  
                    
                    # skip data
                    # if r'/2021/' not in url:
                    #     # print("Skipped:", url)
                    #     skipped_cnt += 1
                    #     if skipped_cnt % 10 == 0:
                    #         print("skipped un-targeted files:", skipped_cnt)
                    #     continue
                    
                    web_dir = item['url']
                    
                    full_web_dir = home_url + web_dir

                    local_dir = item['parent'].replace(init_url, '').replace(r'/', '\\')[1:] # for windows  
                                        

                    web_dir_list.append(web_dir)
                    print(f"Waiting directories (count: {len(web_dir_list)}):\n", web_dir_list[0], '...', web_dir_list[-1])
                    
                    
                    new_folder = os.path.join(save_dir, local_dir)
                    # os.makedirs(new_folder, exist_ok=True)
                    
                    if not os.path.exists(new_folder):
                         os.makedirs(new_folder, exist_ok=True)    
                    # new_folder = os.path.join(save_dir, save_dir_name)    
                    # os.makedirs(new_folder, exist_ok=True)

                    # print(f'Creaet a folder {new_folder} for web directory: {full_web_dir}')
 
                else:
                    
                    basename = item['name']     
                    # if not 'spend' in basename:
                    #     continue
                    url = home_url + item['url']
                    
                    # skip data
                    # if r'/ADVAN/' not in url:
                    #     # print("Skipped:", url)
                    #     skipped_cnt += 1
                    #     if skipped_cnt % 10 == 0:
                    #         print("skipped un-targeted files:", skipped_cnt)
                    #     continue
                    
                    full_web_dir = home_url + web_dir
                    local_dir = item['parent'].replace(init_url, '').replace(r'/', os.sep)[1:] # for windows  
                    # print("save_dir, local_dir", save_dir, local_dir, os.path.join(save_dir, local_dir))
                    new_folder = os.path.join(save_dir, local_dir)
                    # os.makedirs(new_folder, exist_ok=True)
                    
                    if not os.path.exists(new_folder):
                         os.makedirs(new_folder, exist_ok=True)
                    
                    filename = os.path.join(new_folder, basename).replace(r'/', os.sep)  # for windows
                    # print("new_folder, local_dir, filename, new_folder:", new_folder, local_dir, filename, new_folder)
                    
                    # whether skip existing files:
                    if not override:
                        if os.path.exists(filename):
                            # print("File exists, skipped:", filename)
                            skipped_cnt += 1
                            if skipped_cnt % 50 == 0:
                                print("skipped un-targeted files:", skipped_cnt)
                                print("File exists, skipped:", filename)
                            continue
                            continue
                    
                    new_folder = os.path.dirname(filename)    
                    os.makedirs(new_folder, exist_ok=True)
                    
                    print(f"Downloading: {url}")
                    
#                     with open(filename, 'wb') as f:
                        
#                         r = requests.get(url, stream=True, headers=headers)
#                         f.write(r.content)
                    r = requests.get(url, stream=True, headers=headers)
                    safe_file_write(file_path=filename, content=r.content)
        
                    # with requests.get(url, stream=True, headers=headers) as r:
                    #     # r.raise_for_status()
                    #     with open(filename, 'wb') as f:
                    #         for chunk in r.iter_content(chunk_size=8192):
                    #             if chunk:
                    #                 f.write(chunk)
                    
                    print(f"Saved at  : {filename}")
                    
                    
        except Exception as e:
            print(url, e)
            print("sleeping 5 seconds...")
            time.sleep(5)
            
            access_token = get_access_token()
            headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
              }
            download_all_files(save_dir=save_dir, headers=headers)
            
            continue
            
    print("Done")

# Example usage
# access_token = r'v8-YZaYSs3t9CYkKnYywgfQ8zIs'


access_token = get_access_token()

headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
          }

save_dir = r'G:\SafeGraph_monthly_patterns_2018-2022'

download_all_files(save_dir=save_dir, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File d:\ProgramData\anaconda3\envs\wildfire\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File d:\ProgramData\anaconda3\envs\wildfire\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File d:\ProgramData\anaconda3\envs\wildfire\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File d:\ProgramData\anaconda3\envs\wildfire\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 4 column 3 (char 7)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[57], line 199
#     193     print("Done")
#     195 # Example usage
#     196 # access_token = r'v8-YZaYSs3t9CYkKnYywgfQ8zIs'
# --> 199 access_token = get_access_token()
#     201 headers = {
#     202             'accept': 'application/json',
#     203             'Authorization': f'Bearer {access_token}'
#     204           }
#     206 save_dir = r'G:\SafeGraph_monthly_patterns_2018-2022'
#
# Cell In[57], line 32, in get_access_token(account, password, verbose)
#      25 headers = {
#      26     'accept': 'application/json',
#      27     'Authorization': f'Basic {base64_credentials}'
#      28 }
#      30 response = requests.post("https://marketplace.deweydata.io/api/auth/tks/get_token", headers=headers)
# ---> 32 access_token = response.json()['access_token']
#      34 if verbose:
#      35     print(response.json())
#
# File d:\ProgramData\anaconda3\envs\wildfire\Lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 4 column 3 (char 7)

# %% [markdown]
# # Stop

# %%
! echo -n "hning@email.sc.edu:Nhww1898," | openssl base64

# %%
! curl -X 'POST' 'https://marketplace.deweydata.io/api/auth/tks/get_token' -H 'accept: application/json' -H 'Authorization: Basic LW4gImhuaW5nQGVtYWlsLnNjLmVkdTpOaHd3MTg5OCwiIA0K'

# %%
! curl -X GET "https://marketplace.deweydata.io/api/data/v2/list" -H "accept: application/json" -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA"

# %%
access_token = r'0c3RBibybyGBMfXjOuCjO8qtxDA'
# ! path = r'api/data/v2/list/2022'
# ! curl -H 'Accept: application/json' -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA" -X GET 'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_home_panel_0' -o test11.csv

# %%
import requests

def get_all_files():
    headers = {
            'Accept': 'application/json',
            'Authorization': 'Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA'
            }
    res = requests.get(
                        'https://marketplace.deweydata.io/api/data/v2/list',                     
                    headers=headers)  
    
    print(res.url)
    return res.json()

dirs = get_all_files()
dirs
# open('visit_panel_summary2.csv', 'wb').write(res.content)
url = r'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_cpgp_part8_0'
res = requests.get(
                    url,                     
                    headers=headers)  
open('visit_panel_summary2.csv', 'wb').write(res.content)

# %%
import requests
import re

def get_filename_from_cd(cd):
    """
    Get filename from content-disposition
    """
    if not cd:
        return None
    fname = re.findall('filename=(.+)', cd)
    print(fname)
    if len(fname) == 0:
        return None
    return fname[0]


url = r'https://marketplace.deweydata.io/api/data/v2/data/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_cpgp_part8_0'

# url = 'http://google.com/favicon.ico'
r = requests.get(url, allow_redirects=True)
filename = get_filename_from_cd(r.headers.get('content-disposition'))
open(filename, 'wb').write(r.content)

# %%
# from posixpath import basename
import os
import requests
import time

# Main function
def download_all_files(save_dir, headers):
 
    init_url = r'/api/data/v2/list'
    home_url = 'https://marketplace.deweydata.io'    
    web_dir_list = [init_url]
    
    while len(web_dir_list) > 0:
        try:
            web_dir = web_dir_list.pop()
            
            
            url = home_url + web_dir
            # print(url, web_dir)
            items = requests.get(url, headers=headers).json()
            
            items = items[::-1]
            

            for item in items:
                name = item['name']
                if item['directory']:  
                    
                    web_dir = item['url']
                    
                    full_web_dir = home_url + web_dir

                    save_dir_name = full_web_dir.replace(home_url + init_url + '/', "").replace(r'/', '\\')  # for windows

                    new_folder = os.path.join(save_dir, save_dir_name)    
                    os.makedirs(new_folder, exist_ok=True)

                    web_dir_list.append(web_dir)    

                    print(f'Creaet a folder {new_folder} for web directory: {full_web_dir}')
 
                else:
                    
                    basename = item['name']     
                    # if not 'spend' in basename:
                    #     continue
                    url = home_url + item['url']
                    full_web_dir = home_url + web_dir
                    local_dir = item['parent'].replace(init_url, '').replace(r'/', '\\')[1:] # for windows  
                    # print("save_dir, local_dir", save_dir, local_dir, os.path.join(save_dir, local_dir))
                    new_folder = os.path.join(save_dir, local_dir)
                    os.makedirs(new_folder, exist_ok=True)
                    
                    filename = os.path.join(new_folder, basename).replace(r'/', '\\')  # for windows
                    # print("new_folder, local_dir, filename, new_folder:", new_folder, local_dir, filename, new_folder)
                    with requests.get(url, stream=True, headers=headers) as r:
                        # r.raise_for_status()
                        with open(filename, 'wb') as f:
                            for chunk in r.iter_content(chunk_size=8192):
                                if chunk:
                                    f.write(chunk)
                    print(f"Downloaded: {url}")
                    print(f"Saved at  : {filename}")
                    
                    
        except Exception as e:
            print(url, e)
            print("sleeping 6 seconds...")
            time.sleep(6)
            
            continue

# Example usage
access_token = r'v8-YZaYSs3t9CYkKnYywgfQ8zIs'
headers = {
            'accept': 'application/json',
            'Authorization': f'Bearer {access_token}'
          }

save_dir = r'L:\SafeGraph_monthly_patterns_2018-2022'

download_all_files(save_dir=save_dir, headers=headers)

# %% [markdown]
# # Stop

# %%
# from posixpath import basename
import os
import requests

# Function to download a file
def download_file(home_url, item, save_folder, headers):

    basename = item['name']
    
    
    
    url = home_url + item['url']
    new_folder = os.path.join(save_folder, url.replace(home_url + '/', ''))
    os.makedirs(new_folder, exist_ok=True)
    
    filename = os.path.join(new_folder, basename)
    
    with requests.get(url, stream=True, headers=headers) as r:
        # r.raise_for_status()
        with open(filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
    print(f"Downloaded: {url}")
    print(f"Saved at  : {filename}")

# Function to download a directory recursively
def download_directory(directory, save_folder, headers):
    home_url = 'https://marketplace.deweydata.io'
    # print("directory: ", directory)
    url = home_url + directory
    # print("url:", url)
    items = requests.get(url, headers=headers).json()
    
    # print("headers:", headers)
    # print(url, items)

    for item in items:
        name = item['name']
        # print(item)
        # item_path = 
        
        if item['directory']:
            save_dir = os.path.join(save_folder, name)
            # directory = home_url + 
            directory = item['url']
            # print("directory: ", directory)
            new_folder = os.path.join(save_folder, directory.replace(home_url, ''))
            
            os.makedirs(new_folder, exist_ok=True)
            download_directory(directory, save_folder, headers=headers)
        else:
            download_file(home_url, item, save_folder, headers=headers)

# Main function
def download_all_files(save_folder):
    headers = {
        'accept': 'application/json',
        'Authorization': 'Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA'
    }


    download_directory(directory='/api/data/v2/list', save_folder=save_folder, headers=headers)


# Example usage
save_dir = r'L:\SafeGraph_monthly_patterns_2018-2022'
download_all_files(save_dir)

# %%
# files = res.json()

type(files)
files[0]

# %%
curl -H "Accept: application/json" -H "Authorization: Bearer 0c3RBibybyGBMfXjOuCjO8qtxDA" -X GET "/api/data/v2/list/2022/12/01/SAFEGRAPH/MP/2022/12/01/SAFEGRAPH/MP/20221201-safegraph_mp_home_panel_0" -o test42.csv

# %% [markdown]
# # Merge panel CSV files

# %%
import os
import pandas as pd

# %%
data_dir = r'F:\Safegraph\Advan_2023_API\Monthly_Patterns_home_panel_summary_2023-11-23'


def get_all_files(data_dir, exts=['.csv'], verbose=True):
    all_files = []
    for root_dir, folders, files in os.walk(data_dir):
        
        for f in files:
            for ext in exts:
                ext_len = len(ext)
                if ext == f[-ext_len:]:
                    full_name = os.path.join(root_dir, f)
                    all_files.append(full_name)
    if verbose:
        print("Found files:", len(all_files))
    return sorted(all_files)


all_files = get_all_files(data_dir, exts=['.csv.gz'])
# Out:
# Found files: 45

# %%
merged_panel_df = pd.concat([pd.read_csv(f) for f in tqdm(all_files)])
merged_panel_df = merged_panel_df.sort_values(['YEAR', 'MON', 'CENSUS_BLOCK_GROUP'])  
merged_panel_df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 45/45 [00:12<00:00,  3.52it/s]
#         YEAR  MON REGION ISO_COUNTRY_CODE CENSUS_BLOCK_GROUP  \
# 9667    2019    1     AL               US       010010201001
# 8035    2019    1     AL               US       010010201002
# 7493    2019    1     AL               US       010010202001
# 8042    2019    1     AL               US       010010202002
# 9090    2019    1     AL               US       010010203001
# ...      ...  ...    ...              ...                ...
# 148639  2023   10     NU               CA        CA:62080023
# 148631  2023   10     NU               CA        CA:62080025
# 148628  2023   10     NU               CA        CA:62080026
# 148612  2023   10     NU               CA        CA:62080027
# 148632  2023   10     NU               CA        CA:62080028
#
#         NUMBER_DEVICES_RESIDING  NUMBER_DEVICES_PRIMARY_DAYTIME
# 9667                      252.0                           423.0
# 8035                      178.0                            58.0
# 7493                      134.0                            42.0
# 8042                      150.0                            58.0
# 9090                      351.0                           109.0
# ...                         ...                             ...
# 148639                     33.0                            33.0
# 148631                     16.0                            22.0
# 148628                     11.0                            16.0
# 148612                      5.0                             5.0
# 148632                     16.0                            22.0
#
# [15661900 rows x 7 columns]

# %%
monthly_device_cnt_df = merged_panel_df.query(f"ISO_COUNTRY_CODE == 'US' ").groupby(['YEAR', 'MON'], as_index=True)['NUMBER_DEVICES_RESIDING'].sum() / 10**6
print("monthly_device_cnt_df   (million):" )
monthly_device_cnt_df = monthly_device_cnt_df.reset_index()
monthly_device_cnt_df['year_month'] = monthly_device_cnt_df['YEAR'].astype(str)  + monthly_device_cnt_df['MON'].astype(str).str.zfill(2)
monthly_device_cnt_df['year_month'] = pd.to_datetime(monthly_device_cnt_df['year_month'], format='%Y%m')
monthly_device_cnt_df = monthly_device_cnt_df.set_index('year_month')
monthly_device_cnt_df
# Out:
# monthly_device_cnt_df   (million):
#             YEAR  MON  NUMBER_DEVICES_RESIDING
# year_month
# 2019-01-01  2019    1                66.145175
# 2019-02-01  2019    2                62.823365
# 2019-03-01  2019    3                66.860446
# 2019-04-01  2019    4                40.499184
# 2019-05-01  2019    5                41.970806
# 2019-06-01  2019    6                41.172800
# 2019-07-01  2019    7                35.953265
# 2019-08-01  2019    8                29.020312
# 2019-09-01  2019    9                29.037359
# 2019-10-01  2019   10                28.627546
# 2019-11-01  2019   11                26.625356
# 2019-12-01  2019   12                26.372042
# 2020-01-01  2020    1                24.715253
# 2020-02-01  2020    2                24.189729
# 2020-03-01  2020    3                24.134373
# 2020-04-01  2020    4                22.267798
# 2020-05-01  2020    5                22.218687
# 2020-06-01  2020    6                22.700255
# 2020-07-01  2020    7                22.581346
# 2020-08-01  2020    8                23.628205
# 2020-09-01  2020    9                23.189349
# 2020-10-01  2020   10                22.952380
# 2020-11-01  2020   11                22.300225
# 2020-12-01  2020   12                21.233045
# 2021-01-01  2021    1                20.569747
# 2021-02-01  2021    2                19.709469
# 2021-03-01  2021    3                18.968102
# 2021-04-01  2021    4                17.255287
# 2021-05-01  2021    5                18.279663
# 2021-06-01  2021    6                17.843876
# 2021-07-01  2021    7                17.241893
# 2021-08-01  2021    8                17.446045
# 2021-09-01  2021    9                17.090689
# 2021-10-01  2021   10                17.006155
# 2021-11-01  2021   11                16.839845
# 2021-12-01  2021   12                16.810387
# 2022-01-01  2022    1                16.496158
# 2022-02-01  2022    2                16.365649
# 2022-03-01  2022    3                20.871826
# 2022-04-01  2022    4                21.104201
# 2022-05-01  2022    5                21.414853
# 2022-06-01  2022    6                27.065404
# 2022-07-01  2022    7                23.421824
# 2022-08-01  2022    8                23.703003
# 2022-09-01  2022    9                23.944498
# 2022-10-01  2022   10                23.582564
# 2022-11-01  2022   11                23.541959
# 2022-12-01  2022   12                23.823517
# 2023-01-01  2023    1               138.778738
# 2023-02-01  2023    2                34.772798
# 2023-03-01  2023    3                38.017521
# 2023-04-01  2023    4                39.872569
# 2023-05-01  2023    5                39.786672
# 2023-06-01  2023    6                45.306844
# 2023-07-01  2023    7               903.736890
# 2023-08-01  2023    8               555.007790
# 2023-09-01  2023    9                46.310648
# 2023-10-01  2023   10                42.262279

# %%
monthly_device_cnt_df.drop(columns=['YEAR', 'MON']).iloc[48:, :]
# Out:
#             NUMBER_DEVICES_RESIDING
# year_month
# 2023-01-01               138.778738
# 2023-02-01                34.772798
# 2023-03-01                38.017521
# 2023-04-01                39.872569
# 2023-05-01                39.786672
# 2023-06-01                45.306844
# 2023-07-01               903.736890
# 2023-08-01               555.007790
# 2023-09-01                46.310648
# 2023-10-01                42.262279

# %%
monthly_device_cnt_df['NUMBER_DEVICES_RESIDING'].plot()
# Out:
# <Axes: xlabel='year_month'>

# %% [markdown]
# # Help topic in Deweydata community
#
# https://community.deweydata.io/t/residing-device-count-in-2023-07-and-2023-08-surged-abnomorally/26675

# %%
merged_panel_df.query(f"ISO_COUNTRY_CODE == 'US' and YEAR == 2023 and MON ==7 ")
# Out:
#         YEAR  MON REGION ISO_COUNTRY_CODE CENSUS_BLOCK_GROUP  \
# 231742  2023    7     AL               US       010010201001
# 70710   2023    7     AL               US       010010201002
# 5883    2023    7     AL               US       010010202001
# 182091  2023    7     AL               US       010010202002
# 107360  2023    7     AL               US       010010203001
# ...      ...  ...    ...              ...                ...
# 58661   2023    7     VI               US       780309611001
# 263493  2023    7     VI               US       780309611002
# 223912  2023    7     VI               US       780309612001
# 243298  2023    7     VI               US       780309612002
# 136847  2023    7     VI               US       780309900000
#
#         NUMBER_DEVICES_RESIDING  NUMBER_DEVICES_PRIMARY_DAYTIME
# 231742                   4207.0                          3287.0
# 70710                    5716.0                          3905.0
# 5883                     2885.0                          2053.0
# 182091                   4811.0                          5032.0
# 107360                   9588.0                          7011.0
# ...                         ...                             ...
# 58661                    1315.0                          1590.0
# 263493                    644.0                          1013.0
# 223912                    248.0                           208.0
# 243298                    543.0                           738.0
# 136847                     93.0                           127.0
#
# [220606 rows x 7 columns]
