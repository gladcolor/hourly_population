# %%
import pandas as pd
import os
from tqdm import tqdm
tqdm.pandas()
import geopandas as gpd
import glob
pd.set_option('display.max_columns', None)
import ast
import numpy as np
import json

# %%
data_dir = r''
df = pd.read_csv(r'L:\SafeGraph\From_Catalog\Social Distancing Metrics v2.1 (formerly Physical Distancing Metrics)\2019\06\04\2019-06-04-social-distancing.csv.gz')
df
# Out:
#         origin_census_block_group           date_range_start  \
# 0                     10330210004  2019-06-04T00:00:00-05:00
# 1                     10730049022  2019-06-04T00:00:00-05:00
# 2                     11210118001  2019-06-04T00:00:00-05:00
# 3                     11250106021  2019-06-04T00:00:00-05:00
# 4                     21880002003  2019-06-04T00:00:00-08:00
# ...                           ...                        ...
# 219472               550590013003  2019-06-04T00:00:00-05:00
# 219473               550590020001  2019-06-04T00:00:00-05:00
# 219474               550679605002  2019-06-04T00:00:00-05:00
# 219475               550730019007  2019-06-04T00:00:00-05:00
# 219476               720291001033  2019-06-04T00:00:00-04:00
#
#                    date_range_end  device_count  distance_traveled_from_home  \
# 0       2019-06-05T00:00:00-05:00            96                         5962
# 1       2019-06-05T00:00:00-05:00           231                         1678
# 2       2019-06-05T00:00:00-05:00            99                         1034
# 3       2019-06-05T00:00:00-05:00           392                         6335
# 4       2019-06-05T00:00:00-08:00            29                          363
# ...                           ...           ...                          ...
# 219472  2019-06-05T00:00:00-05:00            61                         1815
# 219473  2019-06-05T00:00:00-05:00            83                         4314
# 219474  2019-06-05T00:00:00-05:00            50                         2275
# 219475  2019-06-05T00:00:00-05:00            54                         5619
# 219476  2019-06-05T00:00:00-04:00            16                            0
#
#                                bucketed_distance_traveled  \
# 0       {"16001-50000":44,"0":15,">50000":9,"2001-8000...
# 1       {"16001-50000":15,"0":94,">50000":29,"2001-800...
# 2       {"16001-50000":5,"0":29,">50000":11,"2001-8000...
# 3       {"16001-50000":110,"0":98,">50000":52,"2001-80...
# 4            {"1-1000":11,"1001-2000":1,">50000":1,"0":8}
# ...                                                   ...
# 219472  {"16001-50000":6,"0":22,">50000":3,"2001-8000"...
# 219473  {"16001-50000":10,"0":29,">50000":7,"2001-8000...
# 219474  {"16001-50000":11,"0":13,">50000":3,"2001-8000...
# 219475  {"16001-50000":7,"0":17,">50000":1,"2001-8000"...
# 219476  {"16001-50000":1,"0":5,"2001-8000":1,"1-1000":...
#
#                median_dwell_at_bucketed_distance_traveled  \
# 0       {"16001-50000":39,">50000":35,"<1000":18,"2001...
# 1       {"16001-50000":139,">50000":216,"<1000":122,"2...
# 2       {"16001-50000":69,">50000":121,"<1000":73,"200...
# 3       {"16001-50000":52,">50000":25,"<1000":59,"2001...
# 4               {"1001-2000":17,">50000":306,"<1000":112}
# ...                                                   ...
# 219472  {"16001-50000":185,">50000":25,"<1000":92,"200...
# 219473  {"16001-50000":146,">50000":104,"<1000":27,"20...
# 219474  {"16001-50000":63,">50000":156,"<1000":292,"20...
# 219475  {"16001-50000":107,">50000":104,"<1000":110,"2...
# 219476  {"16001-50000":10,"<1000":99,"2001-8000":50,"1...
#
#         completely_home_device_count  median_home_dwell_time  \
# 0                                 21                     695
# 1                                 91                      97
# 2                                 28                     509
# 3                                 98                     627
# 4                                  8                     224
# ...                              ...                     ...
# 219472                            24                     618
# 219473                            29                     542
# 219474                            14                     608
# 219475                            17                     435
# 219476                             6                     694
#
#                                  bucketed_home_dwell_time  \
# 0       {"721-1080":30,"361-720":18,"61-360":10,"<60":...
# 1       {"721-1080":20,"361-720":29,"61-360":45,"<60":...
# 2       {"721-1080":14,"361-720":18,"61-360":11,"<60":...
# 3       {"721-1080":74,"361-720":74,"61-360":47,"<60":...
# 4       {"721-1080":2,"361-720":1,"61-360":7,"<60":8,"...
# ...                                                   ...
# 219472  {"721-1080":16,"361-720":8,"61-360":11,"<60":1...
# 219473  {"721-1080":15,"361-720":21,"61-360":8,"<60":1...
# 219474  {"721-1080":10,"361-720":10,"61-360":11,"<60":...
# 219475  {"721-1080":6,"361-720":13,"61-360":9,"<60":12...
# 219476       {"721-1080":3,">1080":3,"<60":2,"361-720":2}
#
#                                      at_home_by_each_hour  \
# 0       [58,52,52,52,53,45,50,51,40,40,36,39,36,34,29,...
# 1       [73,73,73,76,75,75,70,72,62,57,51,48,42,38,47,...
# 2       [41,40,43,47,47,45,45,45,44,36,32,34,38,34,34,...
# 3       [214,214,214,218,216,214,195,177,153,137,140,1...
# 4       [10,9,12,12,13,10,9,6,5,4,3,9,3,2,3,3,3,6,6,8,...
# ...                                                   ...
# 219472  [27,25,26,22,27,26,28,31,26,27,26,29,26,22,29,...
# 219473  [47,49,48,51,50,49,56,43,37,32,35,26,25,28,25,...
# 219474  [24,25,25,25,19,25,21,20,24,20,10,13,13,15,19,...
# 219475  [29,28,28,27,26,27,23,19,14,20,17,16,14,14,16,...
# 219476  [9,8,7,8,2,8,7,6,5,5,6,3,5,5,4,2,4,3,5,6,3,5,4,5]
#
#         part_time_work_behavior_devices  full_time_work_behavior_devices  \
# 0                                    15                                7
# 1                                    19                                9
# 2                                    11                                5
# 3                                    51                               17
# 4                                     2                                1
# ...                                 ...                              ...
# 219472                                1                                5
# 219473                               10                                4
# 219474                                9                                2
# 219475                                6                                1
# 219476                                2                                1
#
#                                          destination_cbgs  \
# 0       {"011030051012":1,"281419503001":1,"2814195020...
# 1       {"011170302131":1,"010730142031":2,"1321500040...
# 2       {"011150405022":1,"510131014011":1,"0112101200...
# 3       {"010730102002":9,"011250106013":2,"3901701090...
# 4       {"021880002003":20,"021880002001":5,"270539800...
# ...                                                   ...
# 219472  {"550790011001":1,"550590008002":1,"5507900360...
# 219473  {"550590011001":1,"170978654003":1,"5505900260...
# 219474  {"550679606004":2,"550791852002":1,"5506796040...
# 219475  {"550979611004":1,"550730006012":1,"5507300110...
# 219476  {"720291001034":1,"720291001041":1,"7208711030...
#
#         delivery_behavior_devices  median_non_home_dwell_time  \
# 0                              10                         115
# 1                               1                          15
# 2                               1                          73
# 3                              10                         161
# 4                               1                          89
# ...                           ...                         ...
# 219472                          4                          49
# 219473                          1                         106
# 219474                          1                         103
# 219475                          1                         135
# 219476                          1                          18
#
#         candidate_device_count  \
# 0                          213
# 1                         1083
# 2                          259
# 3                         1104
# 4                           48
# ...                        ...
# 219472                     153
# 219473                     176
# 219474                     116
# 219475                     121
# 219476                      40
#
#                              bucketed_away_from_home_time  \
# 0       {"21-45":11,"481-540":2,"541-600":4,"46-60":1,...
# 1       {"21-45":10,"481-540":5,"541-600":3,"46-60":5,...
# 2       {"21-45":10,"481-540":2,"541-600":1,"46-60":5,...
# 3       {"21-45":21,"481-540":14,"541-600":13,"46-60":...
# 4       {"21-45":1,"721-840":1,"301-360":1,"<20":11,"6...
# ...                                                   ...
# 219472  {"21-45":3,"481-540":1,"541-600":6,"46-60":2,"...
# 219473  {"21-45":5,"481-540":4,"541-600":3,"46-60":1,"...
# 219474  {"21-45":2,"481-540":3,"541-600":1,"46-60":1,"...
# 219475  {"21-45":4,"481-540":4,"541-600":2,"46-60":1,"...
# 219476  {"21-45":3,"301-360":1,"<20":3,"61-120":3,"121...
#
#         median_percentage_time_home  \
# 0                                79
# 1                                81
# 2                                67
# 3                                70
# 4                                70
# ...                             ...
# 219472                           92
# 219473                           82
# 219474                           86
# 219475                           75
# 219476                           93
#
#                          bucketed_percentage_time_home  mean_home_dwell_time  \
# 0         {"0-25":27,"76-100":48,"51-75":14,"26-50":4}                   614
# 1       {"0-25":78,"76-100":114,"51-75":16,"26-50":13}                   341
# 2         {"0-25":32,"76-100":46,"51-75":12,"26-50":9}                   546
# 3       {"0-25":97,"76-100":181,"51-75":81,"26-50":28}                   616
# 4           {"0-25":8,"76-100":12,"51-75":4,"26-50":5}                   442
# ...                                                ...                   ...
# 219472     {"0-25":9,"76-100":36,"51-75":10,"26-50":2}                   591
# 219473    {"0-25":18,"76-100":48,"51-75":12,"26-50":4}                   601
# 219474    {"0-25":10,"76-100":25,"51-75":10,"26-50":3}                   607
# 219475    {"0-25":11,"76-100":28,"51-75":11,"26-50":2}                   522
# 219476                 {"0-25":4,"76-100":8,"51-75":2}                   700
#
#         mean_non_home_dwell_time  mean_distance_traveled_from_home
# 0                            219                             13494
# 1                            185                              3735
# 2                            246                             10035
# 3                            283                             20403
# 4                            235                             59318
# ...                          ...                               ...
# 219472                       179                              1567
# 219473                       222                             84590
# 219474                       235                              6592
# 219475                       233                              5008
# 219476                        90                                 0
#
# [219477 rows x 23 columns]

# %%
df['destination_cbgs']
# Out:
# 0         {"011030051012":1,"281419503001":1,"2814195020...
# 1         {"011170302131":1,"010730142031":2,"1321500040...
# 2         {"011150405022":1,"510131014011":1,"0112101200...
# 3         {"010730102002":9,"011250106013":2,"3901701090...
# 4         {"021880002003":20,"021880002001":5,"270539800...
#                                 ...
# 219472    {"550790011001":1,"550590008002":1,"5507900360...
# 219473    {"550590011001":1,"170978654003":1,"5505900260...
# 219474    {"550679606004":2,"550791852002":1,"5506796040...
# 219475    {"550979611004":1,"550730006012":1,"5507300110...
# 219476    {"720291001034":1,"720291001041":1,"7208711030...
# Name: destination_cbgs, Length: 219477, dtype: object

# %%
random_rows_df = df.sample(10)
random_rows_df
# Out:
#         origin_census_block_group           date_range_start  \
# 6543                 171635012001  2019-06-04T00:00:00-05:00
# 108568               390430402002  2019-06-04T00:00:00-04:00
# 5001                 390930502003  2019-06-04T00:00:00-04:00
# 197134                60376213261  2019-06-04T00:00:00-07:00
# 154457               540979670004  2019-06-04T00:00:00-04:00
# 109216               391690029023  2019-06-04T00:00:00-04:00
# 22439                482150235091  2019-06-04T00:00:00-05:00
# 148824                51159511002  2019-06-04T00:00:00-05:00
# 133029               260490125011  2019-06-04T00:00:00-04:00
# 149372               360810329002  2019-06-04T00:00:00-04:00
#
#                    date_range_end  device_count  distance_traveled_from_home  \
# 6543    2019-06-05T00:00:00-05:00            44                         1905
# 108568  2019-06-05T00:00:00-04:00            90                         6939
# 5001    2019-06-05T00:00:00-04:00            45                         2815
# 197134  2019-06-05T00:00:00-07:00            47                         1978
# 154457  2019-06-05T00:00:00-04:00            48                         5965
# 109216  2019-06-05T00:00:00-04:00           114                         3442
# 22439   2019-06-05T00:00:00-05:00           211                         2078
# 148824  2019-06-05T00:00:00-05:00           154                          782
# 133029  2019-06-05T00:00:00-04:00            74                         6936
# 149372  2019-06-05T00:00:00-04:00            66                         2763
#
#                                bucketed_distance_traveled  \
# 6543    {"16001-50000":1,"0":15,">50000":5,"2001-8000"...
# 108568  {"16001-50000":23,"0":30,">50000":19,"2001-800...
# 5001    {"16001-50000":5,"0":14,">50000":3,"2001-8000"...
# 197134  {"16001-50000":7,"0":14,">50000":3,"2001-8000"...
# 154457  {"16001-50000":22,"0":12,">50000":2,"2001-8000...
# 109216  {"16001-50000":22,"0":25,">50000":19,"2001-800...
# 22439   {"16001-50000":3,"0":53,">50000":16,"2001-8000...
# 148824  {"16001-50000":43,"0":27,">50000":12,"2001-800...
# 133029  {"16001-50000":24,"0":18,">50000":6,"2001-8000...
# 149372  {"16001-50000":2,"0":19,">50000":5,"2001-8000"...
#
#                median_dwell_at_bucketed_distance_traveled  \
# 6543    {"16001-50000":65,">50000":19,"<1000":595,"200...
# 108568  {"16001-50000":41,">50000":90,"<1000":178,"200...
# 5001    {"16001-50000":125,">50000":15,"<1000":220,"20...
# 197134  {"16001-50000":98,">50000":27,"<1000":43,"2001...
# 154457  {"16001-50000":18,">50000":232,"<1000":612,"20...
# 109216  {"16001-50000":29,">50000":44,"<1000":284,"200...
# 22439   {"16001-50000":103,">50000":32,"<1000":47,"200...
# 148824  {"16001-50000":58,">50000":64,"<1000":31,"2001...
# 133029  {"16001-50000":56,">50000":10,"<1000":311,"200...
# 149372  {"16001-50000":231,">50000":84,"<1000":18,"200...
#
#         completely_home_device_count  median_home_dwell_time  \
# 6543                              16                     384
# 108568                            29                     596
# 5001                              14                     525
# 197134                            12                     606
# 154457                            12                     577
# 109216                            21                     574
# 22439                             53                     737
# 148824                            28                     731
# 133029                            18                     634
# 149372                            18                     668
#
#                                  bucketed_home_dwell_time  \
# 6543    {"721-1080":4,"361-720":2,"61-360":9,"<60":14,...
# 108568  {"721-1080":14,"361-720":18,"61-360":5,"<60":2...
# 5001    {"721-1080":1,"361-720":15,"61-360":4,"<60":10...
# 197134  {"721-1080":10,"361-720":11,"61-360":2,"<60":1...
# 154457  {"721-1080":15,"361-720":7,"61-360":8,"<60":9,...
# 109216  {"721-1080":15,"361-720":29,"61-360":19,"<60":...
# 22439   {"721-1080":50,"361-720":38,"61-360":23,"<60":...
# 148824  {"721-1080":41,"361-720":27,"61-360":12,"<60":...
# 133029  {"721-1080":15,"361-720":11,"61-360":11,"<60":...
# 149372  {"721-1080":16,"361-720":7,"61-360":6,"<60":15...
#
#                                      at_home_by_each_hour  \
# 6543    [22,21,24,21,23,23,19,18,18,17,15,19,18,15,16,...
# 108568  [47,48,48,51,50,51,54,49,42,41,39,37,36,30,33,...
# 5001    [24,25,26,27,27,26,28,21,15,13,13,15,14,13,14,...
# 197134  [26,26,25,27,26,29,25,24,21,14,10,14,10,12,13,...
# 154457  [25,25,24,24,23,25,24,18,19,12,13,13,15,19,13,...
# 109216  [64,61,63,62,60,59,56,45,41,35,31,27,32,32,36,...
# 22439   [130,133,137,136,138,134,132,117,101,93,87,84,...
# 148824  [99,95,99,99,95,94,92,82,64,63,59,57,52,55,53,...
# 133029  [38,42,40,43,43,45,41,34,28,28,17,24,23,22,23,...
# 149372  [38,39,40,39,37,37,36,33,29,27,23,21,20,21,22,...
#
#         part_time_work_behavior_devices  full_time_work_behavior_devices  \
# 6543                                  3                                1
# 108568                                7                                4
# 5001                                  8                                1
# 197134                                6                                1
# 154457                                3                                9
# 109216                               12                                3
# 22439                                34                                9
# 148824                               24                                8
# 133029                               10                                9
# 149372                               12                                4
#
#                                          destination_cbgs  \
# 6543    {"171635018003":1,"171635017003":1,"1716350450...
# 108568  {"391130503022":1,"121270802012":2,"3909301320...
# 5001    {"390351545014":1,"390930232001":1,"3904101110...
# 197134  {"060376213262":2,"060376208008":1,"0603762100...
# 154457  {"540839665001":1,"540979666002":8,"5409796690...
# 109216  {"391690010002":1,"420490124001":1,"3915350670...
# 22439   {"482150238024":1,"480610123042":1,"4806101200...
# 148824  {"051414604002":1,"471570032001":1,"0514995240...
# 133029  {"260490117142":1,"261550301002":1,"2608733150...
# 149372  {"360810208001":1,"360810713044":1,"3608101400...
#
#         delivery_behavior_devices  median_non_home_dwell_time  \
# 6543                            1                          13
# 108568                          1                          64
# 5001                            2                         147
# 197134                          1                          98
# 154457                          5                         145
# 109216                          1                         172
# 22439                           5                         202
# 148824                          6                         189
# 133029                          3                         209
# 149372                          6                         156
#
#         candidate_device_count  \
# 6543                       189
# 108568                     196
# 5001                       115
# 197134                      90
# 154457                     135
# 109216                     245
# 22439                      417
# 148824                     321
# 133029                     174
# 149372                     178
#
#                              bucketed_away_from_home_time  \
# 6543    {"21-45":1,"481-540":2,"46-60":1,"301-360":1,"...
# 108568  {"21-45":2,"481-540":5,"541-600":1,"721-840":1...
# 5001    {"21-45":1,"481-540":2,"541-600":1,"721-840":1...
# 197134  {"21-45":3,"481-540":1,"541-600":2,"46-60":1,"...
# 154457  {"21-45":1,"481-540":1,"46-60":2,"721-840":2,"...
# 109216  {"21-45":8,"481-540":7,"541-600":8,"46-60":3,"...
# 22439   {"21-45":9,"481-540":8,"541-600":9,"46-60":6,"...
# 148824  {"21-45":8,"481-540":9,"541-600":10,"46-60":9,...
# 133029  {"21-45":1,"481-540":7,"541-600":1,"46-60":2,"...
# 149372  {"21-45":1,"481-540":4,"541-600":4,"46-60":1,"...
#
#         median_percentage_time_home  \
# 6543                             93
# 108568                           85
# 5001                             80
# 197134                           82
# 154457                           65
# 109216                           67
# 22439                            77
# 148824                           70
# 133029                           70
# 149372                           72
#
#                          bucketed_percentage_time_home  mean_home_dwell_time  \
# 6543        {"0-25":8,"76-100":27,"51-75":5,"26-50":1}                   608
# 108568    {"0-25":24,"76-100":49,"51-75":13,"26-50":2}                   621
# 5001        {"0-25":9,"76-100":24,"51-75":9,"26-50":3}                   573
# 197134     {"0-25":12,"76-100":27,"51-75":5,"26-50":2}                   569
# 154457     {"0-25":13,"76-100":21,"51-75":2,"26-50":3}                   543
# 109216   {"0-25":25,"76-100":52,"51-75":22,"26-50":12}                   582
# 22439   {"0-25":38,"76-100":111,"51-75":42,"26-50":20}                   689
# 148824    {"0-25":32,"76-100":73,"51-75":39,"26-50":7}                   652
# 133029    {"0-25":16,"76-100":35,"51-75":19,"26-50":1}                   620
# 149372    {"0-25":15,"76-100":29,"51-75":17,"26-50":1}                   627
#
#         mean_non_home_dwell_time  mean_distance_traveled_from_home
# 6543                         169                              3583
# 108568                       214                             11660
# 5001                         216                             15660
# 197134                       248                              5497
# 154457                       337                              8114
# 109216                       306                              9639
# 22439                        294                             18049
# 148824                       290                              5909
# 133029                       306                              7519
# 149372                       217                             12150

# %%
for idx, row in tqdm(random_rows_df.iterrows()):
    stops_by_each_hour = row['stops_by_each_hour']
    stops_by_each_hour = json.loads(stops_by_each_hour)
    # print(stops_by_each_hour)
    area = row['area']
    raw_device_counts = int(row['raw_device_counts'])
    raw_stop_counts = int(row['raw_stop_counts'])
    stop_per_device = raw_stop_counts / raw_device_counts
    # print(f'area: {area}', f"stop_per_device: {stop_per_device: 0.3f}", )
    print(f'area: {area}', f"sum of stops_by_each_hour: {sum(stops_by_each_hour)}", )
    print(f'area: {area}', f"raw_stop_counts: {raw_stop_counts}, raw_device_counts: {raw_device_counts}, stop_per_device: {stop_per_device:.1f}", )
    
    device_home_areas = row['device_home_areas']
    device_home_areas = json.loads(device_home_areas)
    destination = row['area']
    origins = row['device_home_areas']
    # print(device_home_areas)
    # print(device_home_areas)
    # if origin in device_home_areas.keys():
        # home_device_ratio =  device_home_areas[area] / raw_device_counts
        # print(f"{area} home device count: ", device_home_areas[area], f"{home_device_ratio: 0.3f}")
        # print()
    for index, (origin, stops) in enumerate(device_home_areas.items()):
        try:
            origin_idx = CBG_dict[origin]
            destination_idx = CBG_dict[area]
            # update_stop_value(origin=origin_idx, destination=destination_idx, stop_increment=stops, conn=conn)
        except:
            continue
